# %% [markdown]
# <a href="https://colab.research.google.com/github/gillesretiere/langdeck/blob/novomaster/langdeck_pipe_2024_v1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
#!/usr/bin/env python
# -*- coding: utf8 -*-
import pandas as pd
pd.set_option("display.width",1000)
pd.options.mode.chained_assignment = None  # default='warn'

import numpy as np
import requests
import json
import uuid
from datetime import datetime
import datetime
import re
import string
import unicodedata
import ast

# !pip3 install pyclean

# Gspread  API for Google sheets
# !pip install gspread --upgrade
# fix here => https://stackoverflow.com/questions/71347973/modulenotfounderror-no-module-named-gspread-models
# !pip uninstall -y gspread-dataframe
# !pip install gspread-dataframe
# !pip install gspread-formatting

#==== Google Drive
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/langdeck/
from google.colab import files
from google.colab import auth
auth.authenticate_user()

#====== Google Credentials ================
from oauth2client.client import GoogleCredentials
# fix here => https://github.com/burnash/gspread/issues/1014
from google.auth import default
creds, _ = default()

# python .env see -> https://saurabh-kumar.com/python-dotenv/
# !pip install python-dotenv
from dotenv import load_dotenv
from dotenv import dotenv_values
load_dotenv()
dotenv_config = dotenv_values(".env")
app_path = dotenv_config["APP_PATH"]

#====== GSpread is a Python API for Google Sheets.================
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from gspread_formatting import *
gc = gspread.authorize(creds)

#====== Airtable ================
# !pip install airtable-python-wrapper
from airtable import Airtable

#====== Deep Translate ================
# !pip install -U deep-translator
# !pip install --upgrade deepl

#====== Dictionaries ================
# larousse API
# !pip install larousse-api-sunbro

#====== Lemmatizers ================
# https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer
# !pip install git+https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git
from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer
lemmatizer = FrenchLefffLemmatizer()

#====== Text To Speech
# about quotas : https://stackoverflow.com/questions/65980562/gtts-tts-gttserror-429-too-many-requests-from-tts-api-probable-cause-unknow
import os
# !pip install gtts --upgrade
from gtts import gTTS

# CDN Cloudinary for upload
# !pip3 install cloudinary
import cloudinary
import cloudinary.uploader
import cloudinary.api
from cloudinary.uploader import upload
from cloudinary.utils import cloudinary_url

# !export PYTHONIOENCODING=utf8

# %load_ext autoreload
# %autoreload 2
# %cd /content/drive/MyDrive/langdeck/
# !pyclean .
import sys, os
sys.path.append('/content/drive/MyDrive/langdeck/py_modules')
import py_modules
py_modules.test()

# .env
from dotenv import load_dotenv
from dotenv import dotenv_values
# %cd /content/drive/MyDrive/langdeck/
load_dotenv()
dotenv_config = dotenv_values(".env")

# Config CDN
cloudinary.config(
  cloud_name = dotenv_config["CLOUDINARY_CLOUD_NAME"],
  api_key = dotenv_config["CLOUDINARY_API_KEY"],
  api_secret = dotenv_config["CLOUDINARY_API_SECRET"],
  secure = True
)

load_dotenv()
dotenv_config = dotenv_values(".env")

print ("Environnement prêt.")
# Out:
# Collecting pyclean
#   Downloading pyclean-2.7.6-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 783.2 kB/s eta 0:00:00
# Installing collected packages: pyclean
# Successfully installed pyclean-2.7.6
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (3.4.2)
# Collecting gspread
#   Downloading gspread-5.12.4-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 277.3 kB/s eta 0:00:00
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2023.11.17)
# Installing collected packages: gspread
#   Attempting uninstall: gspread
#     Found existing installation: gspread 3.4.2
#     Uninstalling gspread-3.4.2:
#       Successfully uninstalled gspread-3.4.2
# Successfully installed gspread-5.12.4
# Found existing installation: gspread-dataframe 3.3.1
# Uninstalling gspread-dataframe-3.3.1:
#   Successfully uninstalled gspread-dataframe-3.3.1
# Collecting gspread-dataframe
#   Downloading gspread_dataframe-3.3.1-py2.py3-none-any.whl (8.0 kB)
# Requirement already satisfied: gspread>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from gspread-dataframe) (5.12.4)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from gspread-dataframe) (1.5.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread-dataframe) (1.16.0)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread>=3.0.0->gspread-dataframe) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread>=3.0.0->gspread-dataframe) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->gspread-dataframe) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->gspread-dataframe) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->gspread-dataframe) (1.23.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2023.11.17)
# Installing collected packages: gspread-dataframe
# Successfully installed gspread-dataframe-3.3.1
# Collecting gspread-formatting
#   Downloading gspread_formatting-1.1.2-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: gspread>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from gspread-formatting) (5.12.4)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread>=3.0.0->gspread-formatting) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread>=3.0.0->gspread-formatting) (1.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-formatting) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-formatting) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-formatting) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-formatting) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-formatting) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread>=3.0.0->gspread-formatting) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-formatting) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-formatting) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-formatting) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-formatting) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-formatting) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-formatting) (2023.11.17)
# Installing collected packages: gspread-formatting
# Successfully installed gspread-formatting-1.1.2
# Mounted at /content/drive
# /content/drive/MyDrive/langdeck
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# Collecting airtable-python-wrapper
#   Downloading airtable_python_wrapper-0.15.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: requests>=2 in /usr/local/lib/python3.10/dist-packages (from airtable-python-wrapper) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2->airtable-python-wrapper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2->airtable-python-wrapper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2->airtable-python-wrapper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2->airtable-python-wrapper) (2023.11.17)
# Installing collected packages: airtable-python-wrapper
# Successfully installed airtable-python-wrapper-0.15.3
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (4.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2023.11.17)
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4
# Collecting deepl
#   Downloading deepl-1.16.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from deepl) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->deepl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->deepl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->deepl) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->deepl) (2023.11.17)
# Installing collected packages: deepl
# Successfully installed deepl-1.16.1
# Collecting larousse-api-sunbro
#   Downloading larousse_api_sunbro-0.0.5-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from larousse-api-sunbro) (2.31.0)
# Collecting bs4>=0.0.1 (from larousse-api-sunbro)
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4>=0.0.1->larousse-api-sunbro) (4.11.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->larousse-api-sunbro) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->larousse-api-sunbro) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->larousse-api-sunbro) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->larousse-api-sunbro) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4>=0.0.1->larousse-api-sunbro) (2.5)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=4eebe6fd2bf3f2bedda3ee1494820ee57535de55428119a17c4a930a0eddb90b
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4, larousse-api-sunbro
# Successfully installed bs4-0.0.1 larousse-api-sunbro-0.0.5
# Collecting git+https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git
#   Cloning https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git to /tmp/pip-req-build-6rllpnnc
#   Running command git clone --filter=blob:none --quiet https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git /tmp/pip-req-build-6rllpnnc
#   Resolved https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git to commit bc0ebd0135a6cc78f48ddf184069b4c0b9c017d8
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: FrenchLefffLemmatizer
#   Building wheel for FrenchLefffLemmatizer (setup.py) ... done
#   Created wheel for FrenchLefffLemmatizer: filename=FrenchLefffLemmatizer-0.3-py3-none-any.whl size=3533514 sha256=e19105d2729bf8432fcd89fd6b10fe8fe0d6409d37c30c6e0f7cc65d9ff23f23
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1rxqitq6/wheels/99/54/81/553bffdc8e0781c925f9a26606894935adb29b56175a9a358b
# Successfully built FrenchLefffLemmatizer
# Installing collected packages: FrenchLefffLemmatizer
# Successfully installed FrenchLefffLemmatizer-0.3
# Collecting gtts
#   Downloading gTTS-2.5.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2023.11.17)
# Installing collected packages: gtts
# Successfully installed gtts-2.5.0
# Collecting cloudinary
#   Downloading cloudinary-1.37.0.tar.gz (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cloudinary) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.10/dist-packages (from cloudinary) (2.0.7)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from cloudinary) (2023.11.17)
# Building wheels for collected packages: cloudinary
#   Building wheel for cloudinary (pyproject.toml) ... done
#   Created wheel for cloudinary: filename=cloudinary-1.37.0-py3-none-any.whl size=139047 sha256=2275b5c6a7c780eac40b0c21c599f79096cb94fe67620c2c0aa897aaf7a8ea4c
#   Stored in directory: /root/.cache/pip/wheels/34/4f/50/a6e6956b061adaebd2d0762a224de428891cc097100d21d6b9
# Successfully built cloudinary
# Installing collected packages: cloudinary
# Successfully installed cloudinary-1.37.0
# /content/drive/MyDrive/langdeck
# Cleaning directory .
# Total 2 files, 1 directories removed.
# Version : 20231011-180000
# /content/drive/MyDrive/langdeck
# Environnement prêt.

# %% [markdown]
# # Cnx Google Sheet DB
# Ici on teste la cnx avec la base d'intégration qui est une table GSHEET

# %%
db_lgdk_intgr = dotenv_config["DB_LGDK_INTGR"]
#--- integration database
sheet = db_lgdk_intgr
wb_intgr  = gc.open_by_url(sheet)
#--- Liste des codes ISO639-3
df_lang_alpha3 = py_modules.load_df_from_gsheet (wb_intgr, "ref_iso-639-3")
#--- Liste des langues (issues d'un Corpus)
df_lang_corpus = py_modules.load_df_from_gsheet (wb_intgr, "ref_lang_corpus")
# df_lang_corpus.head()

# %% [markdown]
# # Cnx Airtable DB
# Ici on teste la cnx avec la base de DESIGN qui est une table Airtable
# ##### doc : https://airtable-python-wrapper.readthedocs.io/en/airtable-python-wrapper/index.html

# %%
#---- Base Airtable 2023
api_key_airtable = dotenv_config["AIRTABLE_PIPE23_API_KEY"]
headers = {"Authorization": "Bearer " + api_key_airtable,"Content-Type" : "application/json"}
base_id = dotenv_config["AIRTABLE_PIPE23_BASE_ID"]
table_name = dotenv_config["AIRTABLE_PIPE23_TBL_NAME"]
airtable = Airtable(base_id, table_name, api_key_airtable)
active_filter = "{Status}='Done'"

# %% [markdown]
# # Langues

# %%
tbd_languages = Airtable(base_id, "languages", api_key_airtable)
lang_filter = "{lang_is_available}='TRUE'"
vw_lang_grid = tbd_languages.get_all(
    view='view_grid',
    sort=['lang_id','lang_is_available'],
    formula=lang_filter,
    )

# %% [markdown]
# # Thèmes

# %% [markdown]
# ## Intégration

# %%
tbd_themes = Airtable(base_id, "themes", api_key_airtable)
vw_themes_grid = tbd_themes.get_all(
    view='view_grid',
    sort=['theme_name'],
    formula=active_filter,
    )

#=======================================================
# Transfo en dataframe
#=======================================================
df_themes = pd.DataFrame.from_records((r['fields'] for r in vw_themes_grid))
df_themes = df_themes[["theme_rec_id",
                 "theme_name",
                 "theme_desc",
                 "lessons",
                 "stories",
                 "theme_illustration",
                 ]]


#=======================================================
# Ajout des langues en colonnes
#=======================================================
df_languages = pd.DataFrame.from_records((r['fields'] for r in vw_lang_grid))
df_languages["lang_is_tts"] = df_languages["lang_is_tts"].map(lambda x:True if x=="TRUE" else False)
df_languages["lang_is_available"] = df_languages["lang_is_available"].map(lambda x:True if x=="TRUE" else False)
py_modules.save_df_to_gsheet (wb_intgr, "tbl_languages", df_languages)

# on transpose chaque trigramme de langue en une colonne supplémentaire (values n'a pas d'importance car on vide la table ensuite)
df_t = df_languages.pivot(columns='lang_id', values='lang_alpha3')
df_t = df_t[0:0]
df_themes = pd.concat([df_themes, df_t.reindex(df_themes.index)], axis=1)
#=======================================================
#---- Transposition des colonnes de langues en lignes
#=======================================================
df_w_temp = pd.melt(df_themes,
        id_vars=["theme_rec_id",
                 "theme_name",
                 "theme_desc",
                 "lessons",
                 "stories",
                 "theme_illustration",
                 ],
        var_name="theme_language",
        value_name="translation")
# hash incl. language iso3
df_w_temp["theme_translation_id"] = df_w_temp[['theme_rec_id', 'theme_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
# left join to include translations
df_w_temp.drop(columns=["translation",], axis=1, inplace=True)


#=======================================================
#---- Merge avec les traductions existantes
#=======================================================
df_tbl_themes = py_modules.load_df_from_gsheet (wb_intgr, "tbl_themes")
df_w_tr = pd.merge(
    df_w_temp,
    df_tbl_themes[["theme_translation_id",
                  "theme_translation",
                  "theme_translation_status",
                  "theme_audio",
                  "theme_audio_url",
                  "theme_audio_url_fr"]],
    on="theme_translation_id",
    how="left")

# %% [markdown]
# ## Traduction

# %%
df_w_tr["theme_translation"] = df_w_tr["theme_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["theme_translation_status"] = df_w_tr["theme_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# translate if necessary # status == NaN OR START
df_w_tr[["theme_translation","theme_translation_status"]] = df_w_tr[["theme_translation",
                                                                   "theme_name",
                                                                   "theme_language",
                                                                   "theme_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3].lower()=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# emplacement du fichier audio correspondant au mot traduit
df_w_tr["theme_audio"] = df_w_tr[["theme_translation_id","theme_language"]].apply(
    lambda x:"assets/audio/ai/"+x[1]+"/"+str(x[0])+".mp3",
    axis=1)

# %% [markdown]
# ## Text To Speech

# %%
# check language directories
audio_path = "/content/drive/MyDrive/langdeck/assets/audio/ai/"
df_languages["lang_id"].map(lambda x:py_modules.create_gdrive_folder(audio_path, x))
# filtre sur les langues disponibles pour TTS (subset)

vk_tts = df_languages.loc[df_languages["lang_is_tts"]]["lang_id"].to_list()
df_tts = df_w_tr.loc[df_w_tr["theme_language"].isin(vk_tts)]
# Appel TTS sur le subset (ex) : text2speech("Diet", "et", audio_path +"est" + "/" + "recIFmq8UmSGnpw0v-est.mp3", False)
df_tts[["theme_translation","theme_language","theme_audio","theme_translation_status"]].apply(
    lambda x:py_modules.text2speech(
    x[0],
    df_languages.loc[df_languages["lang_id"]==x[1].lower()]["lang_alpha2"].values.item(),
    audio_path + x[1] + "/" + x[2].split("/")[-1],
    False)
if py_modules.is_audio(audio_path + x[1] + "/", x[2].split("/")[-1])==False
or x[3].lower()=="update"
else None,
    axis=1)

# replace spaces or empty string by Nan
df_tts['theme_audio_url'] = df_tts['theme_audio_url'].map(
    lambda x: np.nan
    if isinstance(x, str) and (x.isspace() or not x)
    else x)

#=======================================================
# UPLOAD TO CLOUDINARY
#=======================================================

# upload only if audio_public_url equals NaN (if url exists, file has yet been uploaded)
#df_tts.loc[pd.isna(df_tts["audio_public_url"])]
df_tts["theme_audio_url"] = df_tts[["theme_language","theme_audio","theme_audio_url","theme_translation_status"]].apply(
    lambda x: py_modules.upload_to_cdn(
    cloudinary,
    x[0],
    audio_path + x[0]+"/",
    x[1].split("/")[-1],
    x[3])
    if pd.isna(x[2]) or x[3].lower() == "update"
    else x[2],
    axis=1)

# cette fonction donne pour le mot l'url de la version en français
df_tts["theme_audio_url_fr"] = df_tts["theme_rec_id"].map(
    lambda x:py_modules.theme_get_audio_url_fr(x, df_tts))
# Out:
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger

# %%
py_modules.save_df_to_gsheet (wb_intgr, "tbl_themes", df_tts)

# %% [markdown]
# # Lessons

# %% [markdown]
# ## Intégration

# %%
tbd_lessons = Airtable(base_id, "lessons", api_key_airtable)
vw_lessons_grid = tbd_lessons.get_all(
    view='view_grid',
    sort=['lesson'],
    formula=active_filter,
    )

#=======================================================
# Transfo en dataframe
#=======================================================
vk_col_lessons = ["lesson_rec_id",
      "lesson",
      "lesson_story",
      "lesson_pictorial",
      "lesson_quiz",
      "lesson_number",
      "lesson_illustration",
      "lesson_related_theme",
      "Status",
      ]
df_lessons = pd.DataFrame.from_records((r['fields'] for r in vw_lessons_grid))
df_lessons = df_lessons[vk_col_lessons]

# %%
#=======================================================
# Ajout des langues en colonnes
#=======================================================
# on transpose chaque trigramme de langue en une colonne supplémentaire (values n'a pas d'importance car on vide la table ensuite)
df_t = df_languages.pivot(columns='lang_id', values='lang_alpha3')
df_t = df_t[0:0]
df_lessons = pd.concat([df_lessons, df_t.reindex(df_lessons.index)], axis=1)

#=======================================================
#---- Transposition des colonnes de langues en lignes
#=======================================================
df_w_temp = pd.melt(df_lessons,
        id_vars=vk_col_lessons,
        var_name="lesson_language",
        value_name="translation")
# hash incl. language iso3
df_w_temp["lesson_translation_id"] = df_w_temp[['lesson_rec_id', 'lesson_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
# left join to include translations
df_w_temp.drop(columns=["translation",], axis=1, inplace=True)

#=======================================================
#---- Merge avec les traductions existantes
#=======================================================
vk_col_t_lessons = [
    "lesson_translation_id",
    "lesson_translation",
    "lesson_translation_status",
    "lesson_audio",
    "lesson_audio_url",
    "lesson_audio_url_fr"
    ]
df_tbl_lessons = py_modules.load_df_from_gsheet (wb_intgr, "tbl_lessons")
df_w_tr = pd.merge(
    df_w_temp,
    df_tbl_lessons[vk_col_t_lessons],
    on="lesson_translation_id",
    how="left")

# %% [markdown]
# ## Traduction

# %%
df_w_tr["lesson_translation"] = df_w_tr["lesson_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["lesson_translation_status"] = df_w_tr["lesson_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# translate if necessary # status == NaN OR START
df_w_tr[["lesson_translation","lesson_translation_status"]] = df_w_tr[["lesson_translation",
                                                                   "lesson",
                                                                   "lesson_language",
                                                                   "lesson_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3].lower()=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# emplacement du fichier audio correspondant au mot traduit
df_w_tr["lesson_audio"] = df_w_tr[["lesson_translation_id","lesson_language"]].apply(
    lambda x:"assets/audio/ai/"+x[1]+"/"+str(x[0])+".mp3",
    axis=1)

# %% [markdown]
# ## Text To Speech

# %%
# check language directories
audio_path = "/content/drive/MyDrive/langdeck/assets/audio/ai/"
df_languages["lang_id"].map(lambda x:py_modules.create_gdrive_folder(audio_path, x))
# filtre sur les langues disponibles pour TTS (subset)

vk_tts = df_languages.loc[df_languages["lang_is_tts"]]["lang_id"].to_list()
df_tts = df_w_tr.loc[df_w_tr["lesson_language"].isin(vk_tts)]
# Appel TTS sur le subset (ex) : text2speech("Diet", "et", audio_path +"est" + "/" + "recIFmq8UmSGnpw0v-est.mp3", False)
df_tts[["lesson_translation","lesson_language","lesson_audio","lesson_translation_status"]].apply(
    lambda x:py_modules.text2speech(
    x[0],
    df_languages.loc[df_languages["lang_id"]==x[1].lower()]["lang_alpha2"].values.item(),
    audio_path + x[1] + "/" + x[2].split("/")[-1],
    False)
if py_modules.is_audio(audio_path + x[1] + "/", x[2].split("/")[-1])==False
or x[3].lower()=="update"
else None,
    axis=1)

# replace spaces or empty string by Nan
df_tts['lesson_audio_url'] = df_tts['lesson_audio_url'].map(
    lambda x: np.nan
    if isinstance(x, str) and (x.isspace() or not x)
    else x)

#=======================================================
# UPLOAD TO CLOUDINARY
#=======================================================

# upload only if audio_public_url equals NaN (if url exists, file has yet been uploaded)
df_tts["lesson_audio_url"] = df_tts[["lesson_language","lesson_audio","lesson_audio_url","lesson_translation_status"]].apply(
    lambda x: py_modules.upload_to_cdn(
    cloudinary,
    x[0],
    audio_path + x[0]+"/",
    x[1].split("/")[-1],
    x[3])
    if pd.isna(x[2]) or x[3].lower() == "update"
    else x[2],
    axis=1)

# cette fonction donne pour le mot l'url de la version en français
df_tts["lesson_audio_url_fr"] = df_tts["lesson_rec_id"].map(
    lambda x:py_modules.table_get_audio_url_fr(x,
                                    df_tts,
                                    "lesson_translation_id",
                                    "lesson_audio_url",
                                    ))
# Out:
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger

# %%
py_modules.save_df_to_gsheet (wb_intgr, "tbl_lessons", df_tts)

# %% [markdown]
# # Stories

# %% [markdown]
# ## Intégration

# %%
tbd_stories = Airtable(base_id, "stories", api_key_airtable)
vw_stories_grid = tbd_stories.get_all(
    view='view_grid',
    sort=['story_name','story_level'],
    formula=active_filter,
    )
#=======================================================
# Transfo en dataframe
#=======================================================
df_stories = pd.DataFrame.from_records((r['fields'] for r in vw_stories_grid))
df_stories.rename(columns={'story_theme': 'story_theme_rec_id'}, inplace=True)
df_stories["story_theme"] = df_stories["story_theme_rec_id"].map(
    lambda x:py_modules.get_airtable_column_by_id(tbd_themes, x, "theme_name"),
    na_action="ignore"
)
vk_col_stories = ["story_rec_id",
                 "story_name",
                 "story_episode",
                 "story_level",
                 "story_theme",
                 "story_illustration",
                 "paragraphs",
                 "story_desc",
                 "story_desc_tr_status",
                 "story_synopsis",
                 "story_synopsis_tr_status",
                 "story_lesson_header",
                 "story_related_lesson",
                 ]
df_stories = df_stories[vk_col_stories]
#=======================================================
# Ajout des langues en colonnes
#=======================================================
# df_languages = pd.DataFrame.from_records((r['fields'] for r in vw_lang_grid))
df_languages = py_modules.load_df_from_gsheet (wb_intgr, "tbl_languages")
df_languages["lang_is_tts"] = df_languages["lang_is_tts"].map(lambda x:True if x=="TRUE" else False)
df_languages["lang_is_available"] = df_languages["lang_is_available"].map(lambda x:True if x=="TRUE" else False)

# on transpose chaque trigramme de langue en une colonne supplémentaire (values n'a pas d'importance car on vide la table ensuite)
df_t = df_languages.pivot(columns='lang_id', values='lang_alpha3')
df_t = df_t[0:0]
df_stories = pd.concat([df_stories, df_t.reindex(df_stories.index)], axis=1)
#=======================================================
#---- Transposition des colonnes de langues en lignes
#=======================================================
df_w_temp = pd.melt(df_stories,
        id_vars=vk_col_stories,
        var_name="story_language",
        value_name="translation")
# hash incl. language iso3
df_w_temp["story_translation_id"] = df_w_temp[['story_rec_id', 'story_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
# left join to include translations
df_w_temp.drop(columns=["translation",], axis=1, inplace=True)
#=======================================================
#---- Merge avec les traductions existantes
#=======================================================
df_tbl_stories = py_modules.load_df_from_gsheet (wb_intgr, "tbl_stories")
df_w_tr = pd.merge(
    df_w_temp,
    df_tbl_stories[["story_translation_id",
                  "story_translation",
                  "story_translation_status",
                  "story_audio",
                  "story_audio_url",
                  "story_audio_url_fr",
                  "story_desc_translation",
                  "story_synopsis_translation",
                  ]],
    on="story_translation_id",
    how="left")

# %% [markdown]
# ## Traduction

# %%
df_w_tr["story_translation"] = df_w_tr["story_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["story_translation_status"] = df_w_tr["story_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# translate if necessary # status == NaN OR START
df_w_tr[["story_translation","story_translation_status"]] = df_w_tr[["story_translation",
                                                                   "story_name",
                                                                   "story_language",
                                                                   "story_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3].lower()=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# emplacement du fichier audio correspondant au mot traduit
df_w_tr["story_audio"] = df_w_tr[["story_translation_id","story_language"]].apply(
    lambda x:"assets/audio/ai/"+x[1]+"/"+str(x[0])+".mp3",
    axis=1)

# %% [markdown]
# ## Text To Speech

# %%
# check language directories
audio_path = "/content/drive/MyDrive/langdeck/assets/audio/ai/"
df_languages["lang_id"].map(lambda x:py_modules.create_gdrive_folder(audio_path, x))
# filtre sur les langues disponibles pour TTS (subset)

vk_tts = df_languages.loc[df_languages["lang_is_tts"]]["lang_id"].to_list()
df_tts = df_w_tr.loc[df_w_tr["story_language"].isin(vk_tts)]
# Appel TTS sur le subset (ex) : text2speech("Diet", "et", audio_path +"est" + "/" + "recIFmq8UmSGnpw0v-est.mp3", False)
df_tts[["story_translation","story_language","story_audio","story_translation_status"]].apply(
    lambda x:py_modules.text2speech(
    x[0],
    df_languages.loc[df_languages["lang_id"]==x[1].lower()]["lang_alpha2"].values.item(),
    audio_path + x[1] + "/" + x[2].split("/")[-1],
    False)
if py_modules.is_audio(audio_path + x[1] + "/", x[2].split("/")[-1])==False
or x[3].lower()=="update"
else None,
    axis=1)

# replace spaces or empty string by Nan
df_tts['story_audio_url'] = df_tts['story_audio_url'].map(
    lambda x: np.nan
    if isinstance(x, str) and (x.isspace() or not x)
    else x)

#=======================================================
# UPLOAD TO CLOUDINARY
#=======================================================

# upload only if audio_public_url equals NaN (if url exists, file has yet been uploaded)
#df_tts.loc[pd.isna(df_tts["audio_public_url"])]
df_tts["story_audio_url"] = df_tts[["story_language","story_audio","story_audio_url","story_translation_status"]].apply(
    lambda x: py_modules.upload_to_cdn(
    cloudinary,
    x[0],
    audio_path + x[0]+"/",
    x[1].split("/")[-1],
    x[3])
    if pd.isna(x[2]) or x[3].lower() == "update"
    else x[2],
    axis=1)

# cette fonction donne pour le mot l'url de la version en français
df_tts["story_audio_url_fr"] = df_tts["story_rec_id"].map(
    lambda x:py_modules.story_get_audio_url_fr(x, df_tts))
# Out:
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger

# %% [markdown]
# ### Translation of story description

# %%
# translate if necessary # status == NaN OR START
df_tts["story_synopsis_translation"] = df_tts["story_synopsis_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_tts[["story_synopsis_translation","story_synopsis_tr_status"]] = df_tts[
    ["story_synopsis_translation",
     "story_synopsis",
     "story_language",
     "story_synopsis_tr_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if ((pd.isna(x[0]) and not pd.isna(x[1])) or x[3]=='update')
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# translate if necessary # status == NaN OR START
df_tts["story_desc_translation"] = df_tts["story_desc_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)

df_tts[["story_desc_translation","story_desc_tr_status"]] = df_tts[
    ["story_desc_translation",
     "story_desc",
     "story_language",
     "story_desc_tr_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if ((pd.isna(x[0]) and not pd.isna(x[1])) or x[3]=='update')
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# if (pd.isna(x[0]) or pd.isna(x[3]) or x[3].lower()=="update")

# %%
py_modules.save_df_to_gsheet (wb_intgr, "tbl_stories", df_tts)

# %% [markdown]
# # Words

# %%
tbd_words = Airtable(base_id, "words", api_key_airtable)
vw_words_grid = tbd_words.get_all(
    view='view_grid',
    sort=['word','word_type'],
    formula=active_filter,
    )

# %% [markdown]
# ## Intégration

# %%
#=======================================================
# Transfo en dataframe
#=======================================================
df_words = pd.DataFrame.from_records((r['fields'] for r in vw_words_grid))
# on ne garde que les colonnes utiles
df_words = df_words[["word_rec_id",
                     "word",
                     "word_type",
                     "word_lemmas",
                     "word_notes",
                     "word_nutri_notes",
                     "word_notes_status",
                     "word_nutri_notes_status",
                     ]]
# Capitalisation
df_words["word"]=df_words["word"].map(lambda x:x[:1].upper() + x[1:])
# on convertit les rec_id en valeur litérale
df_words.rename(columns={'word_lemmas': 'word_lemmas_rec_id'}, inplace=True)
# on convertit les rec_id en valeur litérale
df_words["word_lemmas"] = df_words["word_lemmas_rec_id"].map(
    lambda x:py_modules.get_word_lemma_by_id(tbd_words, x),
    na_action="ignore")

#=======================================================
# Ajout des langues en colonnes
#=======================================================
df_languages = pd.DataFrame.from_records((r['fields'] for r in vw_lang_grid))
# on transpose chaque trigramme de langue en une colonne supplémentaire (values n'a pas d'importance car on vide la table ensuite)
df_t = df_languages.pivot(columns='lang_id', values='lang_alpha3')
df_t = df_t[0:0]
df_words = pd.concat([df_words, df_t.reindex(df_words.index)], axis=1)

#=======================================================
#---- Transposition des colonnes de langues en lignes
#=======================================================
df_w_temp = pd.melt(df_words,
        id_vars=["word_rec_id",
                 "word",
                 "word_type",
                 "word_lemmas",
                 "word_lemmas_rec_id",
                 "word_notes",
                 "word_nutri_notes",
                 "word_notes_status",
                 "word_nutri_notes_status",
                 ],
        var_name="word_language",
        value_name="translation")
# hash incl. language iso3
df_w_temp["word_translation_id"] = df_w_temp[['word_rec_id', 'word_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
# left join to include translations
df_w_temp.drop(columns=["translation",], axis=1, inplace=True)
#=======================================================
#---- Merge avec les traductions existantes
#=======================================================
df_tbl_words = py_modules.load_df_from_gsheet (wb_intgr, "tbl_words")
df_w_tr = pd.merge(
    df_w_temp,
    df_tbl_words[["word_translation_id",
                  "word_translation",
                  "word_translation_status",
                  "word_audio",
                  "word_audio_url",
                  "word_audio_url_fr",
                  "word_notes_translation",
                  "word_notes_translation_status",
                  "word_nutri_notes_translation",
                  "word_nutri_notes_translation_status",
                  ]],
    on="word_translation_id",
    how="left")

# %% [markdown]
# ## Traduction

# %%
df_w_tr["word_translation"] = df_w_tr["word_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["word_translation_status"] = df_w_tr["word_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# il faut forcer la maj car les lemmes ont peut-être changé => on recrée la colonne from scratch
df_w_tr["word_lemmas_tr_rec_id"]=df_w_tr[["word_lemmas_rec_id","word_language"]].apply(
    lambda x:py_modules.f_word_lemmas_tr_rec_id(x[0],x[1]) if type(x[0])==list else np.nan,
    axis=1)
# translate if necessary # status == NaN OR START
df_w_tr[["word_translation","word_translation_status"]] = df_w_tr[["word_translation",
                                                                   "word",
                                                                   "word_language",
                                                                   "word_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3].lower()=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# on convertit les rec_id en valeur litérale
df_w_tr["word_lemmas_tr"] = df_w_tr["word_lemmas_tr_rec_id"].map(
    lambda x:py_modules.f_word_lemmas_tr(x, df_w_tr),
    na_action="ignore")

# emplacement du fichier audio correspondant au mot traduit
df_w_tr["word_audio"] = df_w_tr[["word_translation_id","word_language"]].apply(
    lambda x:"assets/audio/ai/"+x[1]+"/"+str(x[0])+".mp3",
    axis=1)
# Out:
# Translated Consultati... from fre to nl >>> Overleg...
# Translated Consultati... from fre to en >>> Consultati...
# Translated Consultati... from fre to fr >>> Consultati...
# Translated Consultati... from fre to de >>> Beratung...

# %% [markdown]
# ## Notes and Nutri notes

# %%
df_w_tr["word_notes_translation"] = df_w_tr["word_notes_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["word_notes_translation_status"] = df_w_tr["word_notes_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)

# %%
# notes et nutri-notes
# translate if necessary # status == NaN OR START
df_w_tr[["word_notes_translation","word_notes_translation_status"]] = df_w_tr[
    ["word_notes_translation",
     "word_notes",
     "word_language",
     "word_notes_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if ((pd.isna(x[0]) and not pd.isna(x[1])) or x[3]=='update')
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# %%
df_w_tr["word_nutri_notes_translation"] = df_w_tr["word_nutri_notes_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["word_nutri_notes_translation_status"] = df_w_tr["word_nutri_notes_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)

# %%
# notes et nutri-notes
# translate if necessary # status == NaN OR START
df_w_tr[["word_nutri_notes_translation","word_nutri_notes_translation_status"]] = df_w_tr[
    ["word_nutri_notes_translation",
     "word_nutri_notes",
     "word_language",
     "word_nutri_notes_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if ((pd.isna(x[0]) and not pd.isna(x[1])) or x[3]=='update')
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# %% [markdown]
# ## Text To Speech

# %%
# check language directories
audio_path = "/content/drive/MyDrive/langdeck/assets/audio/ai/"
df_languages["lang_id"].map(lambda x:py_modules.create_gdrive_folder(audio_path, x))
# filtre sur les langues disponibles pour TTS (subset)
df_languages["lang_is_tts"] = df_languages["lang_is_tts"].map(lambda x:True if x=="TRUE" else False)
vk_tts = df_languages.loc[df_languages["lang_is_tts"]]["lang_id"].to_list()
df_tts = df_w_tr.loc[df_w_tr["word_language"].isin(vk_tts)]
# Appel TTS sur le subset (ex) : text2speech("Diet", "et", audio_path +"est" + "/" + "recIFmq8UmSGnpw0v-est.mp3", False)
df_tts[["word_translation","word_language","word_audio","word_translation_status"]].apply(
    lambda x:py_modules.text2speech(
    x[0],
    df_languages.loc[df_languages["lang_id"]==x[1].lower()]["lang_alpha2"].values.item(),
    audio_path + x[1] + "/" + x[2].split("/")[-1],
    False)
if py_modules.is_audio(audio_path + x[1] + "/", x[2].split("/")[-1])==False
or x[3].lower()=="update"
else None,
    axis=1)

# replace spaces or empty string by Nan
df_tts['word_audio_url'] = df_tts['word_audio_url'].map(
    lambda x: np.nan
    if isinstance(x, str) and (x.isspace() or not x)
    else x)

#=======================================================
# UPLOAD TO CLOUDINARY
#=======================================================

# upload only if audio_public_url equals NaN (if url exists, file has yet been uploaded)
#df_tts.loc[pd.isna(df_tts["audio_public_url"])]
df_tts["word_audio_url"] = df_tts[["word_language","word_audio","word_audio_url","word_translation_status"]].apply(
    lambda x: py_modules.upload_to_cdn(
    cloudinary,
    x[0],
    audio_path + x[0]+"/",
    x[1].split("/")[-1],
    x[3])
    if pd.isna(x[2]) or x[3].lower() == "update"
    else x[2],
    axis=1)

# cette fonction donne pour le mot l'url de la version en français
df_tts["word_audio_url_fr"] = df_tts["word_rec_id"].map(
    lambda x:py_modules.word_get_audio_url_fr(x, df_tts))

py_modules.save_df_to_gsheet (wb_intgr, "tbl_words", df_tts)
# Out:
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut/recRUrPp0aC5oNvVc-dut.mp3(nl) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng/recRUrPp0aC5oNvVc-eng.mp3(en) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre/recRUrPp0aC5oNvVc-fre.mp3(fr) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger/recRUrPp0aC5oNvVc-ger.mp3(de) : okay
# iso3:dut ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/dut/ ; path:recRUrPp0aC5oNvVc-dut.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293003/langdeck/assets/audio/ai/dut/recRUrPp0aC5oNvVc-dut.mp3
# iso3:eng ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/eng/ ; path:recRUrPp0aC5oNvVc-eng.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293004/langdeck/assets/audio/ai/eng/recRUrPp0aC5oNvVc-eng.mp3
# iso3:fre ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/fre/ ; path:recRUrPp0aC5oNvVc-fre.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293005/langdeck/assets/audio/ai/fre/recRUrPp0aC5oNvVc-fre.mp3
# iso3:ger ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/ger/ ; path:recRUrPp0aC5oNvVc-ger.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293006/langdeck/assets/audio/ai/ger/recRUrPp0aC5oNvVc-ger.mp3

# %% [markdown]
# # Phrases

# %% [markdown]
# ## Intégration

# %%
tbd_phrases = Airtable(base_id, "phrases", api_key_airtable)
vw_phrases_grid = tbd_phrases.get_all(
    view='view_grid',
    sort=['phrase_related_story','phrase_paragraph','phrase_position'],
    formula=active_filter,
    )

#=======================================================
# Transfo en dataframe
#=======================================================
df_phrases = pd.DataFrame.from_records((r['fields'] for r in vw_phrases_grid))
df_phrases.rename(columns={'phrase_words': 'phrase_words_rec_id'}, inplace=True)
df_phrases["phrase_words"] = df_phrases["phrase_words_rec_id"].map(
    lambda x:py_modules.get_word_lemma_by_id(tbd_words, x),
    na_action="ignore")
# récupérer la saynète à partir de son id
df_phrases.rename(columns={'phrase_related_story': 'phrase_related_story_rec_id'}, inplace=True)
df_phrases["phrase_related_story"] = df_phrases["phrase_related_story_rec_id"].map(
    lambda x:py_modules.get_airtable_column_by_id(tbd_stories, x, "story_name"),
    na_action="ignore")

df_phrases["phrase_html"] = df_phrases[["phrase_rtf","phrase_rec_id"]].apply(
    lambda x:py_modules.phrase_words_markdown_to_html(x[0], x[1]),
    axis=1)

df_phrases["phrase_html"] = df_phrases[["phrase_html","phrase_words_rec_id"]].apply(
    lambda x:py_modules.phrase_words_span_rec_id(x[0], x[1])
    if type(x[1])==list
    else np.nan,
    axis=1)

df_phrases["phrase_html_rec_id"] = df_phrases[["phrase_rtf","phrase_rec_id"]].apply(
    lambda x:py_modules.phrase_words_markdown_to_html_kw(x[0], x[1]),
    axis=1)

df_phrases["phrase_html_rec_id"] = df_phrases[["phrase_html_rec_id","phrase_words_rec_id"]].apply(
    lambda x:py_modules.phrase_words_span_rec_id_kw(x[0], x[1])
    if type(x[1])==list
    else np.nan,
    axis=1)

df_phrases["phrase_html_kw"] = df_phrases[["phrase_rtf","phrase_rec_id"]].apply(
    lambda x:py_modules.phrase_words_markdown_to_html_kw(x[0], x[1]),
    axis=1)

# %%
vk_col_phrases = [
    "phrase_rec_id",
    "phrase",
    "phrase_words",
    "phrase_words_rec_id",
    "phrase_html",
    "phrase_html_rec_id",
    "phrase_html_kw",
    "phrase_related_story",
    "phrase_related_story_rec_id",
    "phrase_paragraph",
    "phrase_position",
    "phrase_status",
    "phrase_notes",
    "phrase_notes_2",
    "phrase_notes_status",
    "phrase_notes_2_status",
    ]
df_phrases = df_phrases[vk_col_phrases]

#=======================================================
# Ajout des langues en colonnes
#=======================================================
# df_languages = pd.DataFrame.from_records((r['fields'] for r in vw_lang_grid))
# on transpose chaque trigramme de langue en une colonne supplémentaire (values n'a pas d'importance car on vide la table ensuite)
df_t = df_languages.pivot(columns='lang_id', values='lang_alpha3')
df_t = df_t[0:0]
df_phrases = pd.concat([df_phrases, df_t.reindex(df_phrases.index)], axis=1)
#=======================================================
#---- Transposition des colonnes de langues en lignes
#=======================================================
df_phr_temp = pd.melt(df_phrases,
        id_vars = vk_col_phrases,
        var_name = "phrase_language",
        value_name = "translation")
# hash incl. language iso3
df_phr_temp["phrase_translation_id"] = df_phr_temp[['phrase_rec_id', 'phrase_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
# left join to include translations
df_phr_temp.drop(columns=["translation",], axis=1, inplace=True)

#=======================================================
#---- Merge avec les traductions existantes
#=======================================================
df_tbl_phrases = py_modules.load_df_from_gsheet (wb_intgr, "tbl_phrases")
df_phr_tr = pd.merge(
    df_phr_temp,
    df_tbl_phrases[[
        "phrase_translation_id",
        "phrase_translation",
        "phrase_translation_status",
        "phrase_audio",
        "phrase_audio_url",
        "phrase_audio_url_fr",
        "phrase_notes_translation",
        "phrase_notes_translation_status",
        "phrase_notes_2_translation",
        "phrase_notes_2_translation_status",
        ]],
    on="phrase_translation_id",
    how="left")

# %%
df_phr_tr["phrase_notes_translation"] = df_phr_tr["phrase_notes_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_phr_tr["phrase_notes_translation_status"] = df_phr_tr["phrase_notes_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_phr_tr["phrase_notes_2_translation"] = df_phr_tr["phrase_notes_2_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_phr_tr["phrase_notes_2_translation_status"] = df_phr_tr["phrase_notes_2_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)

# %% [markdown]
# ## Traduction

# %% [markdown]
# ### Traductions : mots à ne pas traduire
# En attendant d'avoir les fonctionnalités de DeepL, on ignore les tags
# ```
# def phrase_notes_markdown_to_html_kw (source):
#   temp = re.sub(r'\n', '', source)
#   temp = re.sub(r'\*+\`', f'<span translate="no">', temp)
#   target = re.sub(r'\`\*+', '</span>', temp)
#   return target
#
# def phrase_notes_markdown_to_html_kw_2 (source):
#   temp = re.sub(r'\n', '', source)
#   temp = re.sub(r'\*+\`', f'<code>', temp)
#   target = re.sub(r'\`\*+', '</code>', temp)
#   return target
# ```

# %%
df_phr_tr["phrase_notes"] = df_phr_tr["phrase_notes"].map(lambda x:py_modules.phrase_notes_markdown_to_html_kw_2(x) if not pd.isna(x) else np.nan)
df_phr_tr["phrase_notes_2"] = df_phr_tr["phrase_notes_2"].map(lambda x:py_modules.phrase_notes_markdown_to_html_kw_2(x) if not pd.isna(x) else np.nan)

# %%
# notes
# translate if necessary # status == NaN OR START
df_phr_tr[["phrase_notes_translation","phrase_notes_translation_status"]] = df_phr_tr[
    ["phrase_notes_translation",
     "phrase_notes",
     "phrase_language",
     "phrase_notes_translation_status",
     "phrase_notes_status",
     ]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if ((pd.isna(x[0]) and not pd.isna(x[1])) or x[3]=='Start' or x[4]=='update')
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# %%
# notes
# translate if necessary # status == NaN OR START
df_phr_tr[["phrase_notes_2_translation","phrase_notes_2_translation_status"]] = df_phr_tr[
    ["phrase_notes_2_translation",
     "phrase_notes_2",
     "phrase_language",
     "phrase_notes_2_translation_status",
     "phrase_notes_2_status",
     ]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if ((pd.isna(x[0]) and not pd.isna(x[1])) or x[3]=='Start' or x[4]=='update')
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# %%
df_phr_tr["phrase_translation"] = df_phr_tr["phrase_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_phr_tr["phrase_translation_status"] = df_phr_tr["phrase_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# translate if necessary # status == NaN OR START
df_phr_tr[["phrase_translation","phrase_translation_status"]] = df_phr_tr[[
    "phrase_translation",
    "phrase",
    "phrase_language",
    "phrase_translation_status",
    "phrase_status",
    ]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3]=='Start' or x[4]=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# emplacement du fichier audio correspondant au mot traduit
df_phr_tr["phrase_audio"] = df_phr_tr[["phrase_translation_id","phrase_language"]].apply(
    lambda x:"assets/audio/ai/"+x[1]+"/"+str(x[0])+".mp3",
    axis=1)

# %% [markdown]
# ## Text To Speech

# %%
# check language directories
audio_path = "/content/drive/MyDrive/langdeck/assets/audio/ai/"
df_languages = pd.DataFrame.from_records((r['fields'] for r in vw_lang_grid))
df_languages["lang_id"].map(lambda x:py_modules.create_gdrive_folder(audio_path, x))
# filtre sur les langues disponibles pour TTS (subset)
df_languages["lang_is_tts"] = df_languages["lang_is_tts"].map(lambda x:True if x.upper()=="TRUE" else False)
vk_tts = df_languages.loc[df_languages["lang_is_tts"]]["lang_id"].to_list()
df_tts = df_phr_tr.loc[df_phr_tr["phrase_language"].isin(vk_tts)]
df_tts["phrase_translation_status"] = df_tts[["phrase_translation_status","phrase_status"]].apply(
    lambda x:
    x[1] if x[1].lower() == "update" else x[0],
    axis=1)
# Appel TTS sur le subset (ex) : text2speech("Diet", "et", audio_path +"est" + "/" + "recIFmq8UmSGnpw0v-est.mp3", False)
df_tts[[
    "phrase_translation",
    "phrase_language",
    "phrase_audio",
    "phrase_translation_status",
    ]].apply(
    lambda x:py_modules.text2speech(
      x[0],
      df_languages.loc[df_languages["lang_id"]==x[1].lower()]["lang_alpha2"].values.item(),
      audio_path + x[1] + "/" + x[2].split("/")[-1],
      False
    )
    if py_modules.is_audio(audio_path + x[1] + "/", x[2].split("/")[-1])==False
      or x[3].lower()=="update"
    else None,
    axis=1)

# replace spaces or empty string by Nan
df_tts['phrase_audio_url'] = df_tts['phrase_audio_url'].map(
    lambda x: np.nan
    if isinstance(x, str) and (x.isspace() or not x)
    else x)

#=======================================================
# UPLOAD TO CLOUDINARY
#=======================================================

# upload only if audio_public_url equals NaN (if url exists, file has yet been uploaded)
#df_tts.loc[pd.isna(df_tts["audio_public_url"])]
df_tts["phrase_audio_url"] = df_tts[[
    "phrase_language",
    "phrase_audio",
    "phrase_audio_url",
    "phrase_translation_status",
    ]].apply(
    lambda x: py_modules.upload_to_cdn(
    cloudinary,
    x[0],
    audio_path + x[0]+"/",
    x[1].split("/")[-1],
    x[3])
    if pd.isna(x[2])
      or x[3].lower() == "update"
    else x[2],
    axis=1)

# cette fonction donne pour le mot l'url de la version en français
df_tts["phrase_audio_url_fr"] = df_tts["phrase_rec_id"].map(
    lambda x:py_modules.phrase_get_audio_url_fr(x, df_tts))
# Out:
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger

# %%
#=======================================================
# TRADUCTION DES MOTS ASSOCIES
#=======================================================
df_tbl_stories = py_modules.load_df_from_gsheet (wb_intgr, "tbl_stories")
df_tbl_words = py_modules.load_df_from_gsheet (wb_intgr, "tbl_words")
# # construit un id concaténé avec le code langue pour chaque element du vecteur
df_tts["phrase_words_tr_rec_id"] = df_tts[["phrase_words_rec_id","phrase_language"]].apply(
    lambda x:py_modules.set_phrase_words_tr_rec_id(
        x[0],
        x[1])
    if type(x[0])==list
    else np.nan,
    axis=1)
# récupère le mot traduit depuis son identifiant
df_tts["phrase_words_tr"] = df_tts["phrase_words_tr_rec_id"].map(
    lambda x:py_modules.set_phrase_words_tr(x, df_tbl_words),
    na_action='ignore')
#=======================================================
# TRADUCTION DES META DONNEES (STORY, THEME, ETC.)
#=======================================================
df_tts["phrase_related_story_tr_rec_id"] = df_tts[["phrase_related_story_rec_id","phrase_language"]].apply(
    lambda x:py_modules.set_phrase_words_tr_rec_id(
        x[0],
        x[1])
    if type(x[0])==list
    else np.nan,
    axis=1)

# récupère le mot traduit depuis son identifiant
df_tts["phrase_related_story_tr"] = df_tts["phrase_related_story_tr_rec_id"].map(
    lambda x:py_modules.get_story_tr(x, df_tbl_stories),
    na_action='ignore')

# %%
# on rebascule les états si il y a eu update
df_tts["phrase_translation_status"] = df_tts[["phrase_translation_status","phrase_status"]].apply(
    lambda x:
    "Pending" if x[1].lower() == "update" else x[0],
    axis=1)

py_modules.save_df_to_gsheet (wb_intgr, "tbl_phrases", df_tts)

# %% [markdown]
# # Supplement (TPs)

# %% [markdown]
# ## Intégration

# %%
tbd_tps = Airtable(base_id, "tps", api_key_airtable)
vw_tps_grid = tbd_tps.get_all(
    view='view_grid',
    sort=['tp_name',],
    formula=active_filter,
    )
#=======================================================
# Transfo en dataframe
#=======================================================
df_tps = pd.DataFrame.from_records((r['fields'] for r in vw_tps_grid))
df_tps.rename(columns={'tp_rel_story': 'tp_rel_story_rec_id'}, inplace=True)
df_tps["tp_rel_story"] = df_tps["tp_rel_story_rec_id"].map(
    lambda x:py_modules.get_airtable_column_by_id(tbd_stories, x, "story_name"),
    na_action="ignore"
)

vk_col_tps = ["tp_rec_id",
              "tp_name",
              "tp_rel_story_rec_id",
              "tp_rel_story",
              "tp_illustration",
              "tp_summary",
              "tp_lesson_header",
              ]
df_tps = df_tps[vk_col_tps]

#=======================================================
# Ajout des langues en colonnes
#=======================================================
# df_languages = pd.DataFrame.from_records((r['fields'] for r in vw_lang_grid))
df_languages = py_modules.load_df_from_gsheet (wb_intgr, "tbl_languages")
df_languages["lang_is_tts"] = df_languages["lang_is_tts"].map(lambda x:True if x=="TRUE" else False)
df_languages["lang_is_available"] = df_languages["lang_is_available"].map(lambda x:True if x=="TRUE" else False)

# on transpose chaque trigramme de langue en une colonne supplémentaire (values n'a pas d'importance car on vide la table ensuite)
df_t = df_languages.pivot(columns='lang_id', values='lang_alpha3')
df_t = df_t[0:0]
df_tps = pd.concat([df_tps, df_t.reindex(df_tps.index)], axis=1)
#=======================================================
#---- Transposition des colonnes de langues en lignes
#=======================================================
df_w_temp = pd.melt(df_tps,
        id_vars=vk_col_tps,
        var_name="tp_language",
        value_name="translation")
# hash incl. language iso3
df_w_temp["tp_translation_id"] = df_w_temp[['tp_rec_id', 'tp_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
# left join to include translations
df_w_temp.drop(columns=["translation",], axis=1, inplace=True)

#=======================================================
#---- Merge avec les traductions existantes
#=======================================================
df_tbl_tps = py_modules.load_df_from_gsheet (wb_intgr, "tbl_tps")
df_w_tr = pd.merge(
    df_w_temp,
    df_tbl_tps[["tp_translation_id",
                  "tp_translation",
                  "tp_translation_status",
                  "tp_audio",
                  "tp_audio_url",
                  "tp_audio_url_fr",
                  "tp_summary_translation",
                  "tp_summary_translation_status",
                  ]],
    on="tp_translation_id",
    how="left")

# %% [markdown]
# ## Traduction

# %%
df_w_tr["tp_translation"] = df_w_tr["tp_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["tp_translation_status"] = df_w_tr["tp_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# translate if necessary # status == NaN OR START
df_w_tr[["tp_translation","tp_translation_status"]] = df_w_tr[["tp_translation",
                                                                   "tp_name",
                                                                   "tp_language",
                                                                   "tp_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3].lower()=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# emplacement du fichier audio correspondant au mot traduit
df_w_tr["tp_audio"] = df_w_tr[["tp_translation_id","tp_language"]].apply(
    lambda x:"assets/audio/ai/"+x[1]+"/"+str(x[0])+".mp3",
    axis=1)

# %%
df_w_tr["tp_summary_translation"] = df_w_tr["tp_summary_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["tp_summary_translation_status"] = df_w_tr["tp_summary_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# translate if necessary # status == NaN OR START
df_w_tr[["tp_summary_translation","tp_summary_translation_status"]] = df_w_tr[["tp_summary_translation",
                                                                   "tp_summary",
                                                                   "tp_language",
                                                                   "tp_summary_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3].lower()=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# %% [markdown]
# ## TTS

# %%
# check language directories
audio_path = "/content/drive/MyDrive/langdeck/assets/audio/ai/"
df_languages["lang_id"].map(lambda x:py_modules.create_gdrive_folder(audio_path, x))
# filtre sur les langues disponibles pour TTS (subset)

vk_tts = df_languages.loc[df_languages["lang_is_tts"]]["lang_id"].to_list()
df_tts = df_w_tr.loc[df_w_tr["tp_language"].isin(vk_tts)]
# Appel TTS sur le subset (ex) : text2speech("Diet", "et", audio_path +"est" + "/" + "recIFmq8UmSGnpw0v-est.mp3", False)
df_tts[["tp_translation","tp_language","tp_audio","tp_translation_status"]].apply(
    lambda x:py_modules.text2speech(
    x[0],
    df_languages.loc[df_languages["lang_id"]==x[1].lower()]["lang_alpha2"].values.item(),
    audio_path + x[1] + "/" + x[2].split("/")[-1],
    False)
if py_modules.is_audio(audio_path + x[1] + "/", x[2].split("/")[-1])==False
or x[3].lower()=="update"
else None,
    axis=1)

# replace spaces or empty string by Nan
df_tts['tp_audio_url'] = df_tts['tp_audio_url'].map(
    lambda x: np.nan
    if isinstance(x, str) and (x.isspace() or not x)
    else x)

#=======================================================
# UPLOAD TO CLOUDINARY
#=======================================================

# upload only if audio_public_url equals NaN (if url exists, file has yet been uploaded)
df_tts["tp_audio_url"] = df_tts[["tp_language","tp_audio","tp_audio_url","tp_translation_status"]].apply(
    lambda x: py_modules.upload_to_cdn(
    cloudinary,
    x[0],
    audio_path + x[0]+"/",
    x[1].split("/")[-1],
    x[3])
    if pd.isna(x[2]) or x[3].lower() == "update"
    else x[2],
    axis=1)

# cette fonction donne pour le mot l'url de la version en français
df_tts["tp_audio_url_fr"] = df_tts["tp_rec_id"].map(
    lambda x:py_modules.table_get_audio_url_fr(x,
                                    df_tts,
                                    "tp_translation_id",
                                    "tp_audio_url",
                                    ))
# Out:
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger

# %%
py_modules.save_df_to_gsheet (wb_intgr, "tbl_tps", df_tts)

# %% [markdown]
# # TP Phrases

# %% [markdown]
# ## Intégration

# %%
tbd_tp_phrases = Airtable(base_id, "tp_phrases", api_key_airtable)
vw_tp_phrases_grid = tbd_tp_phrases.get_all(
    view='view_grid',
    sort=['tp_phrase_rel_tp','tp_phrase_order',],
    formula=active_filter,
    )
#=======================================================
# Transfo en dataframe
#=======================================================
df_tp_phrases = pd.DataFrame.from_records((r['fields'] for r in vw_tp_phrases_grid))
df_tp_phrases.rename(columns={'tp_phrase_words': 'tp_phrase_words_rec_id'}, inplace=True)
df_tp_phrases["tp_phrase_words"] = df_tp_phrases["tp_phrase_words_rec_id"].map(
    lambda x:py_modules.get_word_lemma_by_id(tbd_words, x),
    na_action="ignore")
# récupérer la saynète à partir de son id
df_tp_phrases.rename(columns={'tp_phrase_rel_tp': 'tp_phrase_rel_tp_rec_id'}, inplace=True)
df_tp_phrases["tp_phrase_rel_tp"] = df_tp_phrases["tp_phrase_rel_tp_rec_id"].map(
    lambda x:py_modules.get_airtable_column_by_id(tbd_tps, x, "tp_name"),
    na_action="ignore")

df_tp_phrases["tp_phrase_html"] = df_tp_phrases[["tp_phrase_rtf","tp_phrase_rec_id"]].apply(
    lambda x:py_modules.phrase_words_markdown_to_html(x[0], x[1]),
    axis=1)

df_tp_phrases["tp_phrase_html"] = df_tp_phrases[["tp_phrase_html","tp_phrase_words_rec_id"]].apply(
    lambda x:py_modules.phrase_words_span_rec_id(x[0], x[1])
    if type(x[1])==list
    else np.nan,
    axis=1)

df_tp_phrases["tp_phrase_html_rec_id"] = df_tp_phrases[["tp_phrase_rtf","tp_phrase_rec_id"]].apply(
    lambda x:py_modules.phrase_words_markdown_to_html_kw(x[0], x[1]),
    axis=1)

df_tp_phrases["tp_phrase_html_rec_id"] = df_tp_phrases[["tp_phrase_html_rec_id","tp_phrase_words_rec_id"]].apply(
    lambda x:py_modules.phrase_words_span_rec_id_kw(x[0], x[1])
    if type(x[1])==list
    else np.nan,
    axis=1)

df_tp_phrases["tp_phrase_html_kw"] = df_tp_phrases[["tp_phrase_rtf","tp_phrase_rec_id"]].apply(
    lambda x:py_modules.phrase_words_markdown_to_html_kw(x[0], x[1]),
    axis=1)

# %% [markdown]
# ## Traduction

# %%
vk_col_tp_phrases = [
    "tp_phrase_rec_id",
    "tp_phrase",
    "tp_phrase_words_rec_id",
    "tp_phrase_words",
    "tp_phrase_html",
    "tp_phrase_html_rec_id",
    "tp_phrase_html_kw",
    "tp_phrase_rel_tp",
    "tp_phrase_rel_tp_rec_id",
    "tp_phrase_order",
    "tp_phrase_status",
    ]
df_tp_phrases = df_tp_phrases[vk_col_tp_phrases]
#=======================================================
# Ajout des langues en colonnes
#=======================================================
# df_languages = pd.DataFrame.from_records((r['fields'] for r in vw_lang_grid))
# on transpose chaque trigramme de langue en une colonne supplémentaire (values n'a pas d'importance car on vide la table ensuite)
df_t = df_languages.pivot(columns='lang_id', values='lang_alpha3')
df_t = df_t[0:0]
df_tp_phrases = pd.concat([df_tp_phrases, df_t.reindex(df_tp_phrases.index)], axis=1)
#=======================================================
#---- Transposition des colonnes de langues en lignes
#=======================================================
df_phr_temp = pd.melt(df_tp_phrases,
        id_vars = vk_col_tp_phrases,
        var_name = "tp_phrase_language",
        value_name = "translation")
# hash incl. language iso3
df_phr_temp["tp_phrase_translation_id"] = df_phr_temp[['tp_phrase_rec_id', 'tp_phrase_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
# left join to include translations
df_phr_temp.drop(columns=["translation",], axis=1, inplace=True)
#=======================================================
#---- Merge avec les traductions existantes
#=======================================================
df_tbl_tp_phrases = py_modules.load_df_from_gsheet (wb_intgr, "tbl_tp_phrases")
df_phr_tr = pd.merge(
    df_phr_temp,
    df_tbl_tp_phrases[[
        "tp_phrase_translation_id",
        "tp_phrase_translation",
        "tp_phrase_translation_status",
        "tp_phrase_audio",
        "tp_phrase_audio_url",
        "tp_phrase_audio_url_fr",
        ]],
    on="tp_phrase_translation_id",
    how="left")

# %%
df_phr_tr["tp_phrase_translation"] = df_phr_tr["tp_phrase_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_phr_tr["tp_phrase_translation_status"] = df_phr_tr["tp_phrase_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# translate if necessary # status == NaN OR START
df_phr_tr[["tp_phrase_translation","tp_phrase_translation_status"]] = df_phr_tr[[
    "tp_phrase_translation",
    "tp_phrase",
    "tp_phrase_language",
    "tp_phrase_translation_status",
    "tp_phrase_status",
    ]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3]=='Start' or x[4]=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# emplacement du fichier audio correspondant au mot traduit
df_phr_tr["tp_phrase_audio"] = df_phr_tr[["tp_phrase_translation_id","tp_phrase_language"]].apply(
    lambda x:"assets/audio/ai/"+x[1]+"/"+str(x[0])+".mp3",
    axis=1)
# Out:
# Translated Quel est v... from fre to nl >>> Wat is de ...
# Translated Veuillez p... from fre to nl >>> Specificee...
# Translated Où avez-vo... from fre to nl >>> Waar doet ...
# Translated Quel est v... from fre to en >>> What is yo...
# Translated Veuillez p... from fre to en >>> Please spe...
# Translated Où avez-vo... from fre to en >>> Where does...
# Translated Quel est v... from fre to fr >>> Quel est v...
# Translated Veuillez p... from fre to fr >>> Veuillez p...
# Translated Où avez-vo... from fre to fr >>> Où avez-vo...
# Translated Quel est v... from fre to de >>> Was ist Ih...
# Translated Veuillez p... from fre to de >>> Bitte gebe...
# Translated Où avez-vo... from fre to de >>> Wo tut es ...

# %% [markdown]
# ## TTS

# %%
# check language directories
audio_path = "/content/drive/MyDrive/langdeck/assets/audio/ai/"
df_languages = pd.DataFrame.from_records((r['fields'] for r in vw_lang_grid))
df_languages["lang_id"].map(lambda x:py_modules.create_gdrive_folder(audio_path, x))
# filtre sur les langues disponibles pour TTS (subset)
df_languages["lang_is_tts"] = df_languages["lang_is_tts"].map(lambda x:True if x.upper()=="TRUE" else False)
vk_tts = df_languages.loc[df_languages["lang_is_tts"]]["lang_id"].to_list()

df_tts = df_phr_tr.loc[df_phr_tr["tp_phrase_language"].isin(vk_tts)]
df_tts["tp_phrase_translation_status"] = df_tts[["tp_phrase_translation_status","tp_phrase_status"]].apply(
    lambda x:
    x[1] if x[1].lower() == "update" else x[0],
    axis=1)
# Appel TTS sur le subset (ex) : text2speech("Diet", "et", audio_path +"est" + "/" + "recIFmq8UmSGnpw0v-est.mp3", False)
df_tts[[
    "tp_phrase_translation",
    "tp_phrase_language",
    "tp_phrase_audio",
    "tp_phrase_translation_status",
    ]].apply(
    lambda x:py_modules.text2speech(
      x[0],
      df_languages.loc[df_languages["lang_id"]==x[1].lower()]["lang_alpha2"].values.item(),
      audio_path + x[1] + "/" + x[2].split("/")[-1],
      False
    )
    if py_modules.is_audio(audio_path + x[1] + "/", x[2].split("/")[-1])==False
      or x[3].lower()=="update"
    else None,
    axis=1)

# replace spaces or empty string by Nan
df_tts['tp_phrase_audio_url'] = df_tts['tp_phrase_audio_url'].map(
    lambda x: np.nan
    if isinstance(x, str) and (x.isspace() or not x)
    else x)

#=======================================================
# UPLOAD TO CLOUDINARY
#=======================================================

# upload only if audio_public_url equals NaN (if url exists, file has yet been uploaded)
#df_tts.loc[pd.isna(df_tts["audio_public_url"])]
df_tts["tp_phrase_audio_url"] = df_tts[[
    "tp_phrase_language",
    "tp_phrase_audio",
    "tp_phrase_audio_url",
    "tp_phrase_translation_status",
    ]].apply(
    lambda x: py_modules.upload_to_cdn(
    cloudinary,
    x[0],
    audio_path + x[0]+"/",
    x[1].split("/")[-1],
    x[3])
    if pd.isna(x[2])
      or x[3].lower() == "update"
    else x[2],
    axis=1)

df_tts["tp_phrase_audio_url_fr"] = df_tts["tp_phrase_rec_id"].map(
    lambda x:py_modules.table_get_audio_url_fr(x,
                                    df_tts,
                                    "tp_phrase_translation_id",
                                    "tp_phrase_audio_url",
                                    ))
#=======================================================
# TRADUCTION DES MOTS ASSOCIES
#=======================================================
df_tbl_stories = py_modules.load_df_from_gsheet (wb_intgr, "tbl_stories")
df_tbl_words = py_modules.load_df_from_gsheet (wb_intgr, "tbl_words")
# # construit un id concaténé avec le code langue pour chaque element du vecteur
df_tts["tp_phrase_words_tr_rec_id"] = df_tts[["tp_phrase_words_rec_id","tp_phrase_language"]].apply(
    lambda x:py_modules.set_phrase_words_tr_rec_id(
        x[0],
        x[1])
    if type(x[0])==list
    else np.nan,
    axis=1)

# récupère le mot traduit depuis son identifiant
df_tts["tp_phrase_words_tr"] = df_tts["tp_phrase_words_tr_rec_id"].map(
    lambda x:py_modules.set_phrase_words_tr(x, df_tbl_words),
    na_action='ignore')
#=======================================================
# TRADUCTION DES META DONNEES (STORY, THEME, ETC.)
#=======================================================
df_tts["tp_phrase_rel_tp_rec_id"] = df_tts[["tp_phrase_rel_tp_rec_id","tp_phrase_language"]].apply(
    lambda x:py_modules.set_phrase_words_tr_rec_id(
        x[0],
        x[1])
    if type(x[0])==list
    else np.nan,
    axis=1)
# Out:
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut/recHPZM2bhuSgikRX-dut.mp3(nl) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut/rec8WSW27ktZD4Gcw-dut.mp3(nl) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut/recAFEMFQvJXhOxJn-dut.mp3(nl) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng/recHPZM2bhuSgikRX-eng.mp3(en) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng/rec8WSW27ktZD4Gcw-eng.mp3(en) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng/recAFEMFQvJXhOxJn-eng.mp3(en) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre/recHPZM2bhuSgikRX-fre.mp3(fr) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre/rec8WSW27ktZD4Gcw-fre.mp3(fr) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre/recAFEMFQvJXhOxJn-fre.mp3(fr) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger/recHPZM2bhuSgikRX-ger.mp3(de) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger/rec8WSW27ktZD4Gcw-ger.mp3(de) : okay
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger/recAFEMFQvJXhOxJn-ger.mp3(de) : okay
# iso3:dut ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/dut/ ; path:recHPZM2bhuSgikRX-dut.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293077/langdeck/assets/audio/ai/dut/recHPZM2bhuSgikRX-dut.mp3
# iso3:dut ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/dut/ ; path:rec8WSW27ktZD4Gcw-dut.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293078/langdeck/assets/audio/ai/dut/rec8WSW27ktZD4Gcw-dut.mp3
# iso3:dut ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/dut/ ; path:recAFEMFQvJXhOxJn-dut.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293078/langdeck/assets/audio/ai/dut/recAFEMFQvJXhOxJn-dut.mp3
# iso3:eng ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/eng/ ; path:recHPZM2bhuSgikRX-eng.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293079/langdeck/assets/audio/ai/eng/recHPZM2bhuSgikRX-eng.mp3
# iso3:eng ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/eng/ ; path:rec8WSW27ktZD4Gcw-eng.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293080/langdeck/assets/audio/ai/eng/rec8WSW27ktZD4Gcw-eng.mp3
# iso3:eng ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/eng/ ; path:recAFEMFQvJXhOxJn-eng.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293081/langdeck/assets/audio/ai/eng/recAFEMFQvJXhOxJn-eng.mp3
# iso3:fre ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/fre/ ; path:recHPZM2bhuSgikRX-fre.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293082/langdeck/assets/audio/ai/fre/recHPZM2bhuSgikRX-fre.mp3
# iso3:fre ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/fre/ ; path:rec8WSW27ktZD4Gcw-fre.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/rec8WSW27ktZD4Gcw-fre.mp3
# iso3:fre ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/fre/ ; path:recAFEMFQvJXhOxJn-fre.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/recAFEMFQvJXhOxJn-fre.mp3
# iso3:ger ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/ger/ ; path:recHPZM2bhuSgikRX-ger.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293085/langdeck/assets/audio/ai/ger/recHPZM2bhuSgikRX-ger.mp3
# iso3:ger ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/ger/ ; path:rec8WSW27ktZD4Gcw-ger.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293085/langdeck/assets/audio/ai/ger/rec8WSW27ktZD4Gcw-ger.mp3
# iso3:ger ; local_folder:/content/drive/MyDrive/langdeck/assets/audio/ai/ger/ ; path:recAFEMFQvJXhOxJn-ger.mp3
# http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293086/langdeck/assets/audio/ai/ger/recAFEMFQvJXhOxJn-ger.mp3

# %%
# récupère le mot traduit depuis son identifiant
def get_tp_tr(rec_id, df):
  vk = []
  for elem in rec_id:
    vk.append(df.loc[df["tp_translation_id"]==elem]["tp_translation"].values.item())
  return vk

# %%
# récupère le mot traduit depuis son identifiant
df_tts["phrase_related_tp_tr"] = df_tts["tp_phrase_rel_tp_rec_id"].map(
    lambda x:get_tp_tr(x, df_tbl_tps),
    na_action='ignore')
# on rebascule les états si il y a eu update
df_tts["tp_phrase_translation_status"] = df_tts[["tp_phrase_translation_status","tp_phrase_status"]].apply(
    lambda x:
    "Pending" if x[1].lower() == "update" else x[0],
    axis=1)
py_modules.save_df_to_gsheet (wb_intgr, "tbl_tp_phrases", df_tts)

# %% [markdown]
# # Quiz

# %% [markdown]
# ### Intégration

# %%
tbd_quiz = Airtable(base_id, "quiz", api_key_airtable)
vw_quiz_grid = tbd_quiz.get_all(
    view='view_grid',
    sort=['quiz_name',],
    formula=active_filter,
    )
#=======================================================
# Transfo en dataframe
#=======================================================
df_quiz = pd.DataFrame.from_records((r['fields'] for r in vw_quiz_grid))
df_quiz.rename(columns={'quiz_rel_tp': 'quiz_rel_tp_rec_id'}, inplace=True)
df_quiz["quiz_rel_tp"] = df_quiz["quiz_rel_tp_rec_id"].map(
    lambda x:py_modules.get_airtable_column_by_id(tbd_tps, x, "tp_name"),
    na_action="ignore"
)
df_quiz.rename(columns={'quiz_rel_story': 'quiz_rel_story_rec_id'}, inplace=True)
df_quiz["quiz_rel_story"] = df_quiz["quiz_rel_story_rec_id"].map(
    lambda x:py_modules.get_airtable_column_by_id(tbd_stories, x, "story_name"),
    na_action="ignore"
)

# on caste le string en dict
df_quiz["quiz_form_dict"] = df_quiz["quiz_form"].map (lambda x:ast.literal_eval(x))

vk_col_quiz = ["quiz_rec_id",
              "quiz_name",
              "quiz_rel_tp_rec_id",
              "quiz_rel_tp",
              "quiz_rel_story",
              "quiz_rel_story_rec_id",
              "quiz_illustration",
              "quiz_summary",
              "quiz_lesson_header",
              "quiz_form",
              "quiz_form_dict",
              "quiz_form_translation_status",
              ]
df_quiz = df_quiz[vk_col_quiz]

#=======================================================
# Ajout des langues en colonnes
#=======================================================
# df_languages = pd.DataFrame.from_records((r['fields'] for r in vw_lang_grid))
df_languages = py_modules.load_df_from_gsheet (wb_intgr, "tbl_languages")
df_languages["lang_is_tts"] = df_languages["lang_is_tts"].map(lambda x:True if x=="TRUE" else False)
df_languages["lang_is_available"] = df_languages["lang_is_available"].map(lambda x:True if x=="TRUE" else False)

# on transpose chaque trigramme de langue en une colonne supplémentaire (values n'a pas d'importance car on vide la table ensuite)
df_t = df_languages.pivot(columns='lang_id', values='lang_alpha3')
df_t = df_t[0:0]
df_quiz = pd.concat([df_quiz, df_t.reindex(df_quiz.index)], axis=1)
#=======================================================
#---- Transposition des colonnes de langues en lignes
#=======================================================
df_w_temp = pd.melt(df_quiz,
        id_vars=vk_col_quiz,
        var_name="quiz_language",
        value_name="translation")
# hash incl. language iso3
df_w_temp["quiz_translation_id"] = df_w_temp[['quiz_rec_id', 'quiz_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
# left join to include translations
df_w_temp.drop(columns=["translation",], axis=1, inplace=True)
#=======================================================
#---- Merge avec les traductions existantes
#=======================================================
df_tbl_quiz = py_modules.load_df_from_gsheet (wb_intgr, "tbl_quiz")
df_w_tr = pd.merge(
    df_w_temp,
    df_tbl_quiz[["quiz_translation_id",
                  "quiz_translation",
                  "quiz_translation_status",
                  "quiz_audio",
                  "quiz_audio_url",
                  "quiz_audio_url_fr",
                  "quiz_summary_translation",
                  "quiz_summary_translation_status",
                  "quiz_form_translation"
                  ]],
    on="quiz_translation_id",
    how="left")

# %%
df_w_tr['quiz_form_translation']
# Out:
# 0    {'quizTitle': 'Bij de dokter', 'quizSynopsis':...
# 1    {'quizTitle': 'De ontbijtbuffetquiz', 'quizSyn...
# 2    {'quizTitle': 'At the doctor', 'quizSynopsis':...
# 3    {'quizTitle': 'The breakfast buffet quiz', 'qu...
# 4    {'quizTitle': 'Chez le médecin', 'quizSynopsis...
# 5    {'quizTitle': 'Le quiz du buffet du petit-déje...
# 6    {'quizTitle': 'Beim Arzt', 'quizSynopsis': 'Me...
# 7    {'quizTitle': 'Das Frühstücksbuffet-Quiz', 'qu...
# Name: quiz_form_translation, dtype: object

# %%
def translate_quiz_form_dict (fr_dict, language):
  tr_dict = {}
  tr_dict['quizTitle'] = py_modules.word_translate_update_status(fr_dict['quizTitle'], "fre", language, "", df_languages)[0]
  tr_dict['quizSynopsis'] = py_modules.word_translate_update_status(fr_dict['quizSynopsis'], "fre", language, "", df_languages)[0]
  tr_dict['questions'] = []
  vk_questions = []
  for q in fr_dict["questions"]:
    tr_dict_q = {}
    tr_dict_q['question'] = py_modules.word_translate_update_status(q['question'], "fre", language, "", df_languages)[0]
    tr_dict_q["questionType"] = q["questionType"]
    vk_answers = []
    for a in q["answers"]:
      vk_answers.append(py_modules.word_translate_update_status(a, "fre", language, "", df_languages)[0])
    tr_dict_q["answers"] = vk_answers
    vk_questions.append (tr_dict_q)
    tr_dict_q["correctAnswer"] = q["correctAnswer"]
  tr_dict['questions'] = vk_questions
  print (tr_dict)
  return tr_dict

# %%
df_w_tr["quiz_form_translation"] = df_w_tr[
    ["quiz_form_dict",
     "quiz_language",]].apply(
      lambda x:translate_quiz_form_dict(x[0],x[1]), axis=1,)

# %% [markdown]
# ### Traduction

# %%
df_w_tr["quiz_translation"] = df_w_tr["quiz_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["quiz_translation_status"] = df_w_tr["quiz_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# translate if necessary # status == NaN OR START
df_w_tr[["quiz_translation","quiz_translation_status"]] = df_w_tr[["quiz_translation",
                                                                   "quiz_name",
                                                                   "quiz_language",
                                                                   "quiz_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3].lower()=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# emplacement du fichier audio correspondant au mot traduit
df_w_tr["quiz_audio"] = df_w_tr[["quiz_translation_id","quiz_language"]].apply(
    lambda x:"assets/audio/ai/"+x[1]+"/"+str(x[0])+".mp3",
    axis=1)

df_w_tr["quiz_summary_translation"] = df_w_tr["quiz_summary_translation"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
df_w_tr["quiz_summary_translation_status"] = df_w_tr["quiz_summary_translation_status"].map(
    lambda x: np.nan if isinstance(x, str) and (x.isspace() or not x) else x)
# translate if necessary # status == NaN OR START
df_w_tr[["quiz_summary_translation","quiz_summary_translation_status"]] = df_w_tr[["quiz_summary_translation",
                                                                   "quiz_summary",
                                                                   "quiz_language",
                                                                   "quiz_summary_translation_status"]].apply(
    lambda x:py_modules.word_translate_update_status(
        x[1],
        "fre",
        x[2],
        x[3],
        df_languages)
    if (pd.isna(x[0]) or pd.isna(x[3]) or x[3].lower()=="update")
    else (x[0],x[3]),
    axis=1,
    result_type="expand"
    )

# %% [markdown]
# ### TTS

# %%
# check language directories
audio_path = "/content/drive/MyDrive/langdeck/assets/audio/ai/"
df_languages["lang_id"].map(lambda x:py_modules.create_gdrive_folder(audio_path, x))
# filtre sur les langues disponibles pour TTS (subset)

vk_tts = df_languages.loc[df_languages["lang_is_tts"]]["lang_id"].to_list()
df_tts = df_w_tr.loc[df_w_tr["quiz_language"].isin(vk_tts)]
# Appel TTS sur le subset (ex) : text2speech("Diet", "et", audio_path +"est" + "/" + "recIFmq8UmSGnpw0v-est.mp3", False)
df_tts[["quiz_translation","quiz_language","quiz_audio","quiz_translation_status"]].apply(
    lambda x:py_modules.text2speech(
    x[0],
    df_languages.loc[df_languages["lang_id"]==x[1].lower()]["lang_alpha2"].values.item(),
    audio_path + x[1] + "/" + x[2].split("/")[-1],
    False)
if py_modules.is_audio(audio_path + x[1] + "/", x[2].split("/")[-1])==False
or x[3].lower()=="update"
else None,
    axis=1)

# replace spaces or empty string by Nan
df_tts['quiz_audio_url'] = df_tts['quiz_audio_url'].map(
    lambda x: np.nan
    if isinstance(x, str) and (x.isspace() or not x)
    else x)

#=======================================================
# UPLOAD TO CLOUDINARY
#=======================================================

# upload only if audio_public_url equals NaN (if url exists, file has yet been uploaded)
df_tts["quiz_audio_url"] = df_tts[["quiz_language","quiz_audio","quiz_audio_url","quiz_translation_status"]].apply(
    lambda x: py_modules.upload_to_cdn(
    cloudinary,
    x[0],
    audio_path + x[0]+"/",
    x[1].split("/")[-1],
    x[3])
    if pd.isna(x[2]) or x[3].lower() == "update"
    else x[2],
    axis=1)

# cette fonction donne pour le mot l'url de la version en français
df_tts["quiz_audio_url_fr"] = df_tts["quiz_rec_id"].map(
    lambda x:py_modules.table_get_audio_url_fr(x,
                                    df_tts,
                                    "quiz_translation_id",
                                    "quiz_audio_url",
                                    ))
# Out:
# /content/drive/MyDrive/langdeck/assets/audio/ai/dut
# /content/drive/MyDrive/langdeck/assets/audio/ai/eng
# /content/drive/MyDrive/langdeck/assets/audio/ai/fre
# /content/drive/MyDrive/langdeck/assets/audio/ai/ger

# %%
py_modules.save_df_to_gsheet (wb_intgr, "tbl_quiz", df_tts)

# %% [markdown]
# # Transformation format JSON
# Chargement et transformation des tables en dictionnaires JSON

# %% [markdown]
# ## Langues

# %%
df_languages = py_modules.load_df_from_gsheet (wb_intgr, "tbl_languages")
df_languages["lang_is_tts"] = df_languages["lang_is_tts"].map(lambda x:True if x=="TRUE" else False)
df_languages["lang_is_available"] = df_languages["lang_is_available"].map(lambda x:True if x=="TRUE" else False)
df_ref_lang = py_modules.load_df_from_gsheet (wb_intgr, "ref_languages")
# merge pour récupérer des infos de référentiels
df_languages = pd.merge (df_languages,
          df_ref_lang[["language_uid","country_ref","flag_icon"]],
          left_on="lang_id",
          right_on="language_uid",
          how="left")
df_languages.drop(columns=["language_uid",], axis=1, inplace=True)
df_languages.rename(
    columns={"country_ref":"lang_country_ref",
             "flag_icon":"lang_flag_icon"},
    inplace=True)
# merge pour récupérer des infos de référentiels
df_ref_lang = py_modules.load_df_from_gsheet (wb_intgr, "ref_languages_countries")
df_languages = pd.merge (df_languages,
          df_ref_lang[["language_uid","language_countries",]],
          left_on="lang_id",
          right_on="language_uid",
          how="left")
df_languages.drop(columns=["language_uid","lang_countries_vk",], axis=1, inplace=True)
df_languages.rename(
    columns={"language_countries":"lang_countries_vk",},
    inplace=True)
# Liste des colonnes pour le dict
vk_language_cols = [
    "lang_id",
    "lang_alpha3",
    "lang_alpha2_google",
    "lang_alpha2",
    "lang_wals",
    "lang_name_native",
    "lang_name_en",
    "lang_name_fr",
    "lang_is_available",
    "lang_is_tts",
    "lang_countries_vk",
    "lang_country_ref",
    "lang_flag_icon",
]
vk_lang_vals = df_languages.groupby(["lang_id"])[vk_language_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Themes

# %%
df_themes = py_modules.load_df_from_gsheet(wb_intgr, "tbl_themes")
df_themes.sort_values (
    by=["theme_name",
        "theme_language",
        ],
    inplace=True)

vk_themes_cols = [
    "theme_rec_id",
    "theme_name",
    "theme_language",
    "theme_translation",
    "theme_audio",
    "theme_audio_url",
    "theme_audio_url_fr",
    "theme_illustration",
    ]

vk_themes_vals = df_themes.groupby(["theme_rec_id"])[vk_themes_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Lessons

# %%
df_lessons = py_modules.load_df_from_gsheet(wb_intgr, "tbl_lessons")
df_lessons.sort_values (
    by=["lesson_number",
        "lesson_language",
        ],
    inplace=True)

df_lessons['lesson_related_theme'] = df_lessons['lesson_related_theme'].map(lambda x:ast.literal_eval(x) if x else [])
df_lessons['lesson_related_theme'] = df_lessons['lesson_related_theme'].map(lambda x:''.join (x))

vk_lessons_cols = [
    "lesson_rec_id",
    "lesson",
    "lesson_language",
    "lesson_story",
    "lesson_pictorial",
    "lesson_quiz",
    "lesson_number",
    "lesson_translation",
    "lesson_audio",
    "lesson_audio_url",
    "lesson_audio_url_fr",
    "lesson_illustration",
    "lesson_related_theme",
    ]

vk_lessons_vals = df_lessons.groupby(["lesson_rec_id"])[vk_lessons_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Stories

# %%
df_stories = py_modules.load_df_from_gsheet(wb_intgr, "tbl_stories")
df_stories.sort_values (
    by=["story_language",
        "story_level",
        "story_name",
        "story_episode",],
    inplace=True)

df_stories['story_related_lesson'] = df_stories['story_related_lesson'].map(lambda x:ast.literal_eval(x) if x else [])
df_stories['story_related_lesson'] = df_stories['story_related_lesson'].map(lambda x:''.join (x))

vk_stories_cols = [
    "story_rec_id",
    "story_translation_id",
    "story_name",
    "story_language",
    "story_translation",
    "story_level",
    "story_episode",
    "story_audio_url",
    "story_audio_url_fr",
    "story_illustration",
    "story_desc",
    "story_desc_translation",
    "story_synopsis",
    "story_synopsis_translation",
    "story_lesson_header",
    "story_related_lesson",
    ]

vk_stories_vals = df_stories.groupby(["story_rec_id"])[vk_stories_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Phrases

# %%
df_phrases = py_modules.load_df_from_gsheet(wb_intgr, "tbl_phrases") # load source sheet
df_phrases["phrase_related_story"] = df_phrases["phrase_related_story"].map(lambda x:ast.literal_eval(x)[0])
df_phrases["phrase_related_story_rec_id"] = df_phrases["phrase_related_story_rec_id"].map(lambda x:ast.literal_eval(x)[0])
df_phrases["phrase_related_story_tr"] = df_phrases["phrase_related_story_tr"].map(lambda x:ast.literal_eval(x)[0])
df_phrases["phrase_related_story_tr_rec_id"] = df_phrases["phrase_related_story_tr_rec_id"].map(lambda x:ast.literal_eval(x)[0])
df_themes = py_modules.load_df_from_gsheet(wb_intgr, "tbl_themes") # load source sheet
df_phrases.sort_values(by=['phrase_language','phrase_related_story','phrase_paragraph','phrase_position'], inplace=True)

# merge phrases + story => vue à plat avec les données étendues
df_phr_ext = pd.merge(df_phrases, df_stories[vk_stories_cols],
         left_on="phrase_related_story_tr_rec_id",
         right_on="story_translation_id",
         how="left")

# vector of columns
vk_phrases_cols = [
    "phrase_language",
    "phrase_related_story",
    "phrase_related_story_rec_id",
    "phrase_paragraph",
    "phrase_position",
    "phrase_rec_id",
    "phrase",
    "phrase_words",
    "phrase_words_rec_id",
    "phrase_words_tr",
    "phrase_words_tr_rec_id",
    "phrase_html",
    "phrase_html_rec_id",
    "phrase_html_kw",
    "phrase_translation",
    "phrase_audio",
    "phrase_audio_url",
    "phrase_audio_url_fr",
    "phrase_related_story_tr",
    "phrase_notes",
    "phrase_notes_2",
    "phrase_notes_translation",
    "phrase_notes_2_translation",
    ] + vk_stories_cols

    # fields (columns)

# vector of values grouped by language
vk_phrases_vals = df_phr_ext.groupby(["phrase_language","phrase_related_story"])[vk_phrases_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Words

# %%
df_words = py_modules.load_df_from_gsheet(wb_intgr, "tbl_words")
df_words["order"] = df_words["word_type"].map(lambda x:1 if x=="Lemma" else 2 if x=="Expression" else 3)
df_words.sort_values(by=['word_language','word','order',], inplace=True)
vk_word_cols = [
    "word_language",
    "word",
    "word_rec_id",
    "order",
    "word_type",
    "word_translation_id",
    "word_translation",
    "word_lemmas",
    "word_lemmas_rec_id",
    "word_audio",
    "word_audio_url",
    "word_audio_url_fr",
    "word_lemmas_tr_rec_id",
    "word_lemmas_tr",
    "word_notes",
    "word_nutri_notes",
    "word_notes_translation",
    "word_nutri_notes_translation",
    ] # fields (columns)

vk_word_vals = df_words.groupby(["word_language"])[vk_word_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## TPs

# %%
df_tps = py_modules.load_df_from_gsheet(wb_intgr, "tbl_tps")
df_tps.sort_values (
    by=["tp_name",
        "tp_language",
        ],
    inplace=True)

vk_tps_cols = [
    "tp_rec_id",
    "tp_name",
    "tp_language",
    "tp_rel_story",
    "tp_rel_story_rec_id",
    "tp_illustration",
    "tp_translation",
    "tp_translation_id",
    "tp_audio",
    "tp_audio_url",
    "tp_audio_url_fr",
    "tp_lesson_header",
    "tp_summary",
    "tp_summary_translation",
    ]

#vk_tps_vals = df_tps.groupby(["tp_rec_id"])[vk_tps_cols].apply(
#      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# on passe le string contenant le vecteur en un vrai vecteur puis en string (ouf...)
df_tps["tp_rel_story_rec_id"] = df_tps['tp_rel_story_rec_id'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_tps["tp_rel_story"] = df_tps['tp_rel_story'].map(lambda x: "".join(map(str, ast.literal_eval(x))))

df_tps["tp_rel_story_tr_rec_id"] = df_tps[['tp_rel_story_rec_id', 'tp_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)

# merge phrases + story => vue à plat avec les données étendues
df_tps_ext = pd.merge(df_tps, df_stories[vk_stories_cols],
         left_on="tp_rel_story_tr_rec_id",
         right_on="story_translation_id",
         how="left")

# vector of values grouped by language
vk_tps_vals = df_tps_ext.groupby(["tp_language","tp_name"])[vk_tps_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Phrases des TPs

# %%
df_tp_phrases = py_modules.load_df_from_gsheet(wb_intgr, "tbl_tp_phrases")
df_tp_phrases.sort_values (
    by=["tp_phrase_language",
        "tp_phrase_order",
        ],
    inplace=True)

vk_tp_p_cols = [
    "tp_phrase_rec_id",
    "tp_phrase",
    "tp_phrase_html",
    "tp_phrase_html_rec_id",
    "tp_phrase_html_kw",
    "tp_phrase_rel_tp",
    "tp_phrase_rel_tp_rec_id",
    "tp_phrase_order",
    "tp_phrase_language",
    "tp_phrase_translation_id",
    "tp_phrase_translation",
    "tp_phrase_audio",
    "tp_phrase_audio_url",
    "tp_phrase_audio_url_fr",
    "tp_phrase_words_rec_id",
    "tp_phrase_words",
    "tp_phrase_words_tr_rec_id",
    "tp_phrase_words_tr",
    "phrase_related_tp_tr",
    ]

vk_tp_p_vals = df_tp_phrases.groupby(["tp_phrase_rec_id"])[vk_tp_p_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# on passe le string contenant le vecteur en un vrai vecteur puis en string (ouf...)
df_tp_phrases["tp_phrase_rel_tp_rec_id"] = df_tp_phrases['tp_phrase_rel_tp_rec_id'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_tp_phrases["tp_phrase_rel_tp"] = df_tp_phrases['tp_phrase_rel_tp'].map(lambda x: "".join(map(str, ast.literal_eval(x))))

# merge phrases + story => vue à plat avec les données étendues
df_tp_p_ext = pd.merge(df_tp_phrases, df_tps,
         left_on="tp_phrase_rel_tp_rec_id",
         right_on="tp_translation_id",
         how="left")

vk_col_tp_p_ext = vk_tp_p_cols + vk_tps_cols + [
  "tp_phrase_words_tr_rec_id",
  "tp_phrase_words_tr",
  "tp_rel_story_tr_rec_id",
  ]

# vector of values grouped by language
vk_tp_p_vals = df_tp_p_ext.groupby(["tp_phrase_language","tp_phrase_rel_tp"])[vk_col_tp_p_ext].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Quiz

# %%
df_quiz = py_modules.load_df_from_gsheet(wb_intgr, "tbl_quiz")
df_quiz.sort_values (
    by=["quiz_name",
        "quiz_language",
        ],
    inplace=True)

vk_quiz_cols = [
    "quiz_rec_id",
    "quiz_name",
    "quiz_language",
    "quiz_rel_tp",
    "quiz_rel_tp_rec_id",
    "quiz_rel_story",
    "quiz_rel_story_rec_id",
    "quiz_illustration",
    "quiz_translation",
    "quiz_translation_id",
    "quiz_audio",
    "quiz_audio_url",
    "quiz_audio_url_fr",
    "quiz_summary_translation",
    "quiz_form",
    "quiz_form_translation",
    "quiz_lesson_header",
    ] + vk_stories_cols

df_quiz["quiz_rel_tp_rec_id"] = df_quiz['quiz_rel_tp_rec_id'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_quiz["quiz_rel_tp"] = df_quiz['quiz_rel_tp'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_quiz["quiz_rel_story_rec_id"] = df_quiz['quiz_rel_story_rec_id'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_quiz["quiz_rel_story"] = df_quiz['quiz_rel_story'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_quiz["quiz_form"] = df_quiz["quiz_form"].map (lambda x:ast.literal_eval(x))
df_quiz["quiz_form_translation"] = df_quiz["quiz_form_translation"].map (lambda x:ast.literal_eval(x))

df_quiz["quiz_rel_tp_tr_rec_id"] = df_quiz[['quiz_rel_tp_rec_id', 'quiz_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
df_quiz["quiz_rel_story_tr_rec_id"] = df_quiz[['quiz_rel_story_rec_id', 'quiz_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)

df_quiz_ext = pd.merge(df_quiz, df_stories[vk_stories_cols],
         left_on="quiz_rel_story_tr_rec_id",
         right_on="story_translation_id",
         how="left")

# vector of values grouped by language
vk_quiz_vals = df_quiz_ext.groupby(["quiz_language"])[vk_quiz_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Fonctions de remplissage au format JSON

# %%
def add_dict_of_words (df_words,vk_word_cols, filter_language, vk_filter_words):
  vk_dict_story_phrase_words = []    # on crée un vecteur (liste) pour recevoir les mots de la phrase
  # on filtre sur langue ET identifiants des mots
  # print (len(vk_filter_words))
  if vk_filter_words :
    df_story_phrase_words_filtered = df_words.loc[
        (df_words['word_language']==filter_language) &
        (df_words['word_rec_id'].isin(vk_filter_words))
        ]
      # on créé un vecteur de tuples sur cette liste filtrée
    vk_story_phrase_words = df_story_phrase_words_filtered.groupby(["word_language",])[vk_word_cols].apply(
        lambda x: list(map(tuple, x.values.tolist()))).to_list()
    # on itère le vecteur de mots => transforme le vecteur de tuples en liste de dicts
    for vk_w in vk_story_phrase_words:
      # print (f'phrase={vk_w}')
      vk_w_dict = list(map(lambda x: dict(zip(vk_word_cols,x)), vk_w))
      # on affecte chaque k/v au dict de destination d_word
      for vk_w_kv in vk_w_dict:
        d_word = {}
        # clé kv
        d_word["word_rec_id"] = vk_w_kv['word_rec_id']
        d_word["word"] = vk_w_kv['word']
        d_word["word_translation"] = vk_w_kv['word_translation']
        vk_dict_story_phrase_words.append(d_word)
  return vk_dict_story_phrase_words

# %%
def add_dict_of_story_phrases(df_phr_ext, vk_phrases_cols, filter_language, filter_story):
  debug = False
  #print (f'{df_phr_ext} {vk_phrases_cols} filter_language={filter_language} filter_story={filter_story}')
  vk_dict_story_phrases = []    # on crée un vecteur (liste) pour recevoir les phrases
  # on filtre sur langue ET story
  df_story_phrases_filtered = df_phr_ext.loc[(df_phr_ext['phrase_language']==filter_language) & (df_phr_ext['phrase_related_story']==filter_story)]
  # on créé un vecteur de tuples sur cette liste filtrée
  vk_story_phrases_vals = df_story_phrases_filtered.groupby(["phrase_language","phrase_related_story"])[vk_phrases_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()
  # on itère le vecteur de phrases => transforme le vecteur de tuples en liste de dicts
  for vk_phr in vk_story_phrases_vals:
    # print (f'phrase={vk_phr}')
    vk_phr_dict = list(map(lambda x: dict(zip(vk_phrases_cols,x)), vk_phr))
    # on affecte chaque k/v au dict de destination d_phrase
    for vk_phr_kv in vk_phr_dict:
      d_phrase = {}
      # clé kv
      d_phrase["phrase_rec_id"] = vk_phr_kv['phrase_rec_id']
      if not debug:
        # on ajoute les autres colonnes
        for vkcol in vk_phrases_cols:
          d_phrase[vkcol] = vk_phr_kv[vkcol]
      ## on ajoute les mots
      list_words = ast.literal_eval(d_phrase["phrase_words_rec_id"])
      d_phrase["words"] = add_dict_of_words (df_words, vk_word_cols, filter_language, list_words)
      vk_dict_story_phrases.append(d_phrase)

  return vk_dict_story_phrases

# %%
def add_dict_of_tp_phrases (df_tp_p_ext, vk_col_tp_p_ext, filter_language, filter_story):
  vk_dict_of_tp_phrases = []    # on crée un vecteur (liste) pour recevoir les phrases
  # on filtre sur langue ET story
  df_tp_phrases_filtered = df_tp_p_ext.loc[(df_tp_p_ext['tp_phrase_language']==filter_language) & (df_tp_p_ext['tp_phrase_rel_tp']==filter_story)]
  # si le vecteur de mots est vide, liste vide plutôt que NaN
  df_tp_phrases_filtered['tp_phrase_words_rec_id'] = df_tp_phrases_filtered['tp_phrase_words_rec_id'].map(lambda x:ast.literal_eval(x) if x else [])
  # on créé un vecteur de tuples sur cette liste filtrée
  vk_tp_phrases_vals = df_tp_phrases_filtered.groupby(["tp_phrase_language","tp_phrase_rel_tp"])[vk_col_tp_p_ext].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()
  # on itère le vecteur de phrases => transforme le vecteur de tuples en liste de dicts
  for vk_phr in vk_tp_phrases_vals:
    print (f'phrase={vk_phr}')
    vk_phr_dict = list(map(lambda x: dict(zip(vk_col_tp_p_ext,x)), vk_phr))
    # on affecte chaque k/v au dict de destination d_phrase
    for vk_phr_kv in vk_phr_dict:
      d_phrase = {}
      # clé kv
      d_phrase["tp_phrase_rec_id"] = vk_phr_kv['tp_phrase_rec_id']
      d_phrase["tp_phrase_words_rec_id"] = vk_phr_kv['tp_phrase_words_rec_id']
      ## on ajoute les mots
      list_words = d_phrase['tp_phrase_words_rec_id']
      d_phrase["words"] = add_dict_of_words (df_words, vk_word_cols, filter_language, list_words)
      vk_dict_of_tp_phrases.append(d_phrase)
  return vk_dict_of_tp_phrases

# %%
def add_dict_of_story_quiz (df_quiz_ext, vk_quiz_cols, filter_language, filter_story):
  vk_dict_story_quiz = []    # on crée un vecteur (liste) pour recevoir les phrases
  df_story_quiz_filtered = df_quiz_ext.loc[(df_quiz_ext['quiz_language']==filter_language) & (df_quiz_ext['quiz_rel_story']==filter_story)]
  # on créé un vecteur de tuples sur cette liste filtrée
  vk_story_quiz_vals = df_story_quiz_filtered.groupby(["quiz_language","quiz_name"])[vk_quiz_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()
  # on itère le vecteur de tp (singleton !) => transforme le vecteur de tuples en liste de dicts
  for vk_quiz in vk_story_quiz_vals:
    vk_quiz_dict = list(map(lambda x: dict(zip(vk_quiz_cols,x)), vk_quiz))
    for vk_quiz_kv in vk_quiz_dict:
      d_quiz = {}
      d_quiz['quiz_name'] = vk_quiz_kv['quiz_name']
      d_quiz['quiz_translation'] = vk_quiz_kv['quiz_translation']

      # quiz form
      d_quiz['quiz_form'] = vk_quiz_kv['quiz_form']

      # quiz form translation
      d_quiz['quiz_form_translation'] = vk_quiz_kv['quiz_form_translation']

      vk_dict_story_quiz.append(d_quiz)

  return vk_dict_story_quiz

# %%
def add_dict_of_story_tp (df_tps_ext, vk_tps_cols, filter_language, filter_story):
  vk_dict_story_tp = []    # on crée un vecteur (liste) pour recevoir les phrases
  df_story_tp_filtered = df_tps_ext.loc[(df_tps_ext['tp_language']==filter_language) & (df_tps_ext['tp_rel_story']==filter_story)]
  # on créé un vecteur de tuples sur cette liste filtrée
  vk_story_tp_vals = df_story_tp_filtered.groupby(["tp_language","tp_name"])[vk_tps_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()
  # on itère le vecteur de tp (singleton !) => transforme le vecteur de tuples en liste de dicts
  for vk_tp in vk_story_tp_vals:
    vk_tp_dict = list(map(lambda x: dict(zip(vk_tps_cols,x)), vk_tp))
    for vk_tp_kv in vk_tp_dict:
      d_tp = {}
      d_tp['tp_name'] = vk_tp_kv['tp_name']
      d_tp['tp_translation'] = vk_tp_kv['tp_translation']
      d_tp['tp_phrases'] = add_dict_of_tp_phrases(
          df_tp_p_ext,
          vk_col_tp_p_ext,
          filter_language,
          d_tp['tp_name']
          )
      vk_dict_story_tp.append(d_tp)

  return vk_dict_story_tp

# %% [markdown]
# ## Niveau Stories

# %%
def add_dict_of_stories (df_stories, vk_stories_cols, filter_language, filter_lesson):
  debug = True
  vk_dict_stories = []

  df_stories_filtered = df_stories.loc[(df_stories['story_language']==filter_language) & (df_stories['story_related_lesson']==filter_lesson)]
  vk_stories_vals = df_stories_filtered.groupby(["story_rec_id"])[vk_stories_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()
  for vk_s in vk_stories_vals:
    vk_s_dict = list(map(lambda x: dict(zip(vk_stories_cols,x)), vk_s))
    d_story = {}
    d_story["story"] = list(dict.fromkeys(map(
      lambda x:x["story_name"],
      sorted(vk_s_dict, key=lambda x: x["story_rec_id"]))))[0]
    if not debug:
      ## colonnes story
      for vkcol in vk_stories_cols:
        d_story[vkcol] = list(dict.fromkeys(map(
          lambda x:x[vkcol],
          sorted(vk_s_dict, key=lambda x: x["story_rec_id"]))))[0]
    ## on ajoute les phrases
    d_story['phrases'] = add_dict_of_story_phrases (
        df_phr_ext,
        vk_phrases_cols,
        filter_language,
        d_story["story"]
        )
    ## on ajoute le TP
    d_story['tps'] = add_dict_of_story_tp (
        df_tps_ext,
        vk_tps_cols,
        filter_language,
        d_story["story"]
        )
    ## on ajoute le Quiz
    d_story['quiz'] = add_dict_of_story_quiz (
        df_quiz_ext,
        vk_quiz_cols,
        filter_language,
        d_story["story"]
        )
    vk_dict_stories.append(d_story)
  return vk_dict_stories

# %% [markdown]
# ## Niveau Lesson

# %%
def add_dict_of_lessons (df, vk_cols, filter_language, filter_theme):
  debug = True
  print (f'>> add_dict_of_lessons : {filter_language} {filter_theme}')
  vk_dict_returned = []
  df_filtered = df.loc[(df['lesson_language']==filter_language) & (df['lesson_related_theme']==filter_theme)]
  # si thème possède des lessons
  if len(df_filtered) > 0:
    vk_vals = df_filtered.groupby(["lesson_rec_id"])[vk_cols].apply(
        lambda x: list(map(tuple, x.values.tolist()))).to_list()
    for vk in vk_vals:
      vk_dict = list(map(lambda x: dict(zip(vk_cols,x)), vk))
      d_lesson = {}
      d_lesson["lesson"] = list(dict.fromkeys(map(
        lambda x:x["lesson"],
        sorted(vk_dict, key=lambda x: x["lesson_rec_id"]))))[0]
      d_lesson["language"] = filter_language
      d_lesson["lesson_rec_id"] = list(dict.fromkeys(map(
        lambda x:x["lesson_rec_id"],
        sorted(vk_dict, key=lambda x: x["lesson_rec_id"]))))[0]

      # on ajoute les stories
      d_lesson['stories'] = add_dict_of_stories (
        df_stories,
        vk_stories_cols,
        d_lesson['language'],
        d_lesson["lesson_rec_id"])

    vk_dict_returned.append(d_lesson)

  return vk_dict_returned

# %% [markdown]
# ## Niveau Thème

# %%
def add_dict_of_themes (df, vk_cols, filter_language):
  print (f'>> add_dict_of_themes : {filter_language}')
  vk_dict_returned = []
  df_filtered = df.loc[df['theme_language']==filter_language]
  vk_vals = df_filtered.groupby(["theme_rec_id"])[vk_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()
  for vk in vk_vals:
    vk_dict = list(map(lambda x: dict(zip(vk_cols,x)), vk))
    d_key = {}

    ## colonnes suppl.
    for vkcol in vk_cols:
      d_key[vkcol] = list(dict.fromkeys(map(
        lambda x:x[vkcol],
        sorted(vk_dict, key=lambda x: x["theme_rec_id"]))))[0]

    # on ajoute les lessons
    d_key['lessons'] = add_dict_of_lessons (
        df_lessons,
        vk_lessons_cols,
        d_key['theme_language'],
        d_key["theme_rec_id"]
        )

    vk_dict_returned.append(d_key)

  return vk_dict_returned

# %%
vk_langdeck = []
### languages
for vk_l in vk_lang_vals:
  vk_l_dict = list(map(lambda x: dict(zip(vk_language_cols,x)), vk_l))
  d_lang = {}
  d_lang["language"] = list(dict.fromkeys(map(
      lambda x:x["lang_id"],
      sorted(vk_l_dict, key=lambda x: x["lang_id"]))))[0]

  ### stories
  #d_lang['stories']=[]
  d_lang['themes'] = add_dict_of_themes (
      df_themes,
      vk_themes_cols,
      d_lang['language'])
  vk_langdeck.append (d_lang)
  """
  d_lang['stories'] = add_dict_of_stories (
      df_stories,
      vk_stories_cols,
      d_lang['language'])
  vk_langdeck.append (d_lang)
  """
# Out:
# >> add_dict_of_themes : dut
# >> add_dict_of_lessons : dut recXrgjiwJhADauYJ
# phrase=[('recY1tS2A6OPdUYvP', 'Savourez un copieux petit-déjeuner pendant votre séjour à Tours', 'Savourez un copieux <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> pendant votre séjour à Tours', 'Savourez un copieux <kw>recrYaJMdw31vgPT5<kw> pendant votre séjour à Tours', 'Savourez un copieux <kw>petit-déjeuner<kw> pendant votre séjour à Tours', 'Le buffet', 'recolhmJ3G9UQuKPi-dut', '1', 'dut', 'recY1tS2A6OPdUYvP-dut', 'Geniet van een stevig ontbijt tijdens uw verblijf in Tours', 'assets/audio/ai/dut/recY1tS2A6OPdUYvP-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709092/langdeck/assets/audio/ai/dut/recY1tS2A6OPdUYvP-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709101/langdeck/assets/audio/ai/fre/recY1tS2A6OPdUYvP-fre.mp3', ['recrYaJMdw31vgPT5'], "['Petit-déjeuner']", "['recrYaJMdw31vgPT5-dut']", "['Ontbijt']", "['Het buffet']", 'recolhmJ3G9UQuKPi', 'Le buffet', 'dut', 'Le petit-déjeuner', 'recYrnBviiGa6SErr', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Het buffet', 'recolhmJ3G9UQuKPi-dut', 'assets/audio/ai/dut/recolhmJ3G9UQuKPi-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706853/langdeck/assets/audio/ai/dut/recolhmJ3G9UQuKPi-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.", 'De te bestuderen tekst is afkomstig van de website van een hotel dat een ontbijtbuffet aanbiedt. De tekst bevat veel woordenschat. Bestudeer het menu zin \u200b\u200bvoor zin en probeer de woorden te onthouden.', "['recrYaJMdw31vgPT5-dut']", "['Ontbijt']", 'recYrnBviiGa6SErr-dut'), ('recv2FOuvXA4FdkHn', "Le petit-déjeuner est servi sous forme de buffet dans la salle des petits-déjeuners située au rez-de-chaussée de l'hôtel.", 'Le <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> est servi sous forme de <span id="rec3chhixknslcAHa">buffet</span> dans la salle des petits-déjeuners située au <span id="rec7USMFcyeCZLyRj">rez-de-chaussée</span> de l\'hôtel.', "Le <kw>recrYaJMdw31vgPT5<kw> est servi sous forme de <kw>rec3chhixknslcAHa<kw> dans la salle des petits-déjeuners située au <kw>rec7USMFcyeCZLyRj<kw> de l'hôtel.", "Le <kw>petit-déjeuner<kw> est servi sous forme de <kw>buffet<kw> dans la salle des petits-déjeuners située au <kw>rez-de-chaussée<kw> de l'hôtel.", 'Le buffet', 'recolhmJ3G9UQuKPi-dut', '2', 'dut', 'recv2FOuvXA4FdkHn-dut', 'Het ontbijt wordt in buffetvorm geserveerd in de ontbijtzaal op de begane grond van het hotel.', 'assets/audio/ai/dut/recv2FOuvXA4FdkHn-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709092/langdeck/assets/audio/ai/dut/recv2FOuvXA4FdkHn-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709102/langdeck/assets/audio/ai/fre/recv2FOuvXA4FdkHn-fre.mp3', ['recrYaJMdw31vgPT5', 'rec3chhixknslcAHa', 'rec7USMFcyeCZLyRj'], "['Petit-déjeuner', 'Buffet', 'Rez-de-chaussée']", "['recrYaJMdw31vgPT5-dut', 'rec3chhixknslcAHa-dut', 'rec7USMFcyeCZLyRj-dut']", "['Ontbijt', 'Buffet', 'Begane grond']", "['Het buffet']", 'recolhmJ3G9UQuKPi', 'Le buffet', 'dut', 'Le petit-déjeuner', 'recYrnBviiGa6SErr', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Het buffet', 'recolhmJ3G9UQuKPi-dut', 'assets/audio/ai/dut/recolhmJ3G9UQuKPi-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706853/langdeck/assets/audio/ai/dut/recolhmJ3G9UQuKPi-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'https://res.cloudinary.com/dhc7o ...
# >> add_dict_of_lessons : dut recY3WUJq96PZuRPK
# phrase=[('recHPZM2bhuSgikRX', "Quel est votre motif de consultation aujourd'hui ?", 'Quel est votre motif de <span id="recRUrPp0aC5oNvVc">consultation</span> aujourd\'hui ?', "Quel est votre motif de <kw>recRUrPp0aC5oNvVc<kw> aujourd'hui ?", "Quel est votre motif de <kw>consultation<kw> aujourd'hui ?", 'Chez le médecin', 'recvRKKiTZIwwawCt-dut', '1', 'dut', 'recHPZM2bhuSgikRX-dut', 'Wat is de reden van uw consultatie vandaag?', 'assets/audio/ai/dut/recHPZM2bhuSgikRX-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293077/langdeck/assets/audio/ai/dut/recHPZM2bhuSgikRX-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293082/langdeck/assets/audio/ai/fre/recHPZM2bhuSgikRX-fre.mp3', ['recRUrPp0aC5oNvVc'], "['Consultation']", "['recRUrPp0aC5oNvVc-dut']", "['Overleg']", "['Bij de dokter']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'dut', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Bij de dokter', 'recvRKKiTZIwwawCt-dut', 'assets/audio/ai/dut/recvRKKiTZIwwawCt-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209947/langdeck/assets/audio/ai/dut/recvRKKiTZIwwawCt-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', 'à faire', 'Te doen', "['recRUrPp0aC5oNvVc-dut']", "['Overleg']", 'rec7lQw6DtIJP45dn-dut'), ('rec8WSW27ktZD4Gcw', 'Veuillez préciser le sujet relatif à votre problème', '', '', 'Veuillez préciser le sujet relatif à votre problème', 'Chez le médecin', 'recvRKKiTZIwwawCt-dut', '2', 'dut', 'rec8WSW27ktZD4Gcw-dut', 'Specificeer het onderwerp dat betrekking heeft op uw probleem', 'assets/audio/ai/dut/rec8WSW27ktZD4Gcw-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293078/langdeck/assets/audio/ai/dut/rec8WSW27ktZD4Gcw-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/rec8WSW27ktZD4Gcw-fre.mp3', [], '', '', '', "['Bij de dokter']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'dut', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Bij de dokter', 'recvRKKiTZIwwawCt-dut', 'assets/audio/ai/dut/recvRKKiTZIwwawCt-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209947/langdeck/assets/audio/ai/dut/recvRKKiTZIwwawCt-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', 'à faire', 'Te doen', '', '', 'rec7lQw6DtIJP45dn-dut'), ('recAFEMFQvJXhOxJn', 'Où avez-vous mal ?', '', '', 'Où avez-vous mal ?', 'Chez le médecin', 'recvRKKiTZIwwawCt-dut', '3', 'dut', 'recAFEMFQvJXhOxJn-dut', 'Waar doet het pijn ?', 'assets/audio/ai/dut/recAFEMFQvJXhOxJn-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293078/langdeck/assets/audio/ai/dut/recAFEMFQvJXhOxJn-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/recAFEMFQvJXhOxJn-fre.mp3', [], '', '', '', "['Bij de dokter']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'dut', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Bij de dokter', 'recvRKKiTZIwwawCt-dut', 'assets/audio/ai/dut/recvRKKiTZIwwawCt-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209947/langdeck/assets/audio/ai/dut/recvRKKiTZIwwawCt-dut.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v170266048 ...
# >> add_dict_of_lessons : dut recf39GupDsTKKLjP
# >> add_dict_of_lessons : dut recyy4SzPX0NWAx4n
# >> add_dict_of_themes : eng
# >> add_dict_of_lessons : eng recXrgjiwJhADauYJ
# phrase=[('recY1tS2A6OPdUYvP', 'Savourez un copieux petit-déjeuner pendant votre séjour à Tours', 'Savourez un copieux <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> pendant votre séjour à Tours', 'Savourez un copieux <kw>recrYaJMdw31vgPT5<kw> pendant votre séjour à Tours', 'Savourez un copieux <kw>petit-déjeuner<kw> pendant votre séjour à Tours', 'Le buffet', 'recolhmJ3G9UQuKPi-eng', '1', 'eng', 'recY1tS2A6OPdUYvP-eng', 'Savor a hearty breakfast during your stay in Tours', 'assets/audio/ai/eng/recY1tS2A6OPdUYvP-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709096/langdeck/assets/audio/ai/eng/recY1tS2A6OPdUYvP-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709101/langdeck/assets/audio/ai/fre/recY1tS2A6OPdUYvP-fre.mp3', ['recrYaJMdw31vgPT5'], "['Petit-déjeuner']", "['recrYaJMdw31vgPT5-eng']", "['Breakfast']", "['The buffet']", 'recolhmJ3G9UQuKPi', 'Le buffet', 'eng', 'Le petit-déjeuner', 'recYrnBviiGa6SErr', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'The buffet', 'recolhmJ3G9UQuKPi-eng', 'assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.", 'The text to study is taken from the website of a hotel which offers a breakfast buffet. The text contains a lot of vocabulary. Study the menu sentence by sentence and try to remember the words.', "['recrYaJMdw31vgPT5-eng']", "['Breakfast']", 'recYrnBviiGa6SErr-eng'), ('recv2FOuvXA4FdkHn', "Le petit-déjeuner est servi sous forme de buffet dans la salle des petits-déjeuners située au rez-de-chaussée de l'hôtel.", 'Le <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> est servi sous forme de <span id="rec3chhixknslcAHa">buffet</span> dans la salle des petits-déjeuners située au <span id="rec7USMFcyeCZLyRj">rez-de-chaussée</span> de l\'hôtel.', "Le <kw>recrYaJMdw31vgPT5<kw> est servi sous forme de <kw>rec3chhixknslcAHa<kw> dans la salle des petits-déjeuners située au <kw>rec7USMFcyeCZLyRj<kw> de l'hôtel.", "Le <kw>petit-déjeuner<kw> est servi sous forme de <kw>buffet<kw> dans la salle des petits-déjeuners située au <kw>rez-de-chaussée<kw> de l'hôtel.", 'Le buffet', 'recolhmJ3G9UQuKPi-eng', '2', 'eng', 'recv2FOuvXA4FdkHn-eng', 'Breakfast is served buffet style in the breakfast room located on the ground floor of the hotel.', 'assets/audio/ai/eng/recv2FOuvXA4FdkHn-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709097/langdeck/assets/audio/ai/eng/recv2FOuvXA4FdkHn-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709102/langdeck/assets/audio/ai/fre/recv2FOuvXA4FdkHn-fre.mp3', ['recrYaJMdw31vgPT5', 'rec3chhixknslcAHa', 'rec7USMFcyeCZLyRj'], "['Petit-déjeuner', 'Buffet', 'Rez-de-chaussée']", "['recrYaJMdw31vgPT5-eng', 'rec3chhixknslcAHa-eng', 'rec7USMFcyeCZLyRj-eng']", "['Breakfast', 'Buffet', 'Ground floor']", "['The buffet']", 'recolhmJ3G9UQuKPi', 'Le buffet', 'eng', 'Le petit-déjeuner', 'recYrnBviiGa6SErr', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'The buffet', 'recolhmJ3G9UQuKPi-eng', 'assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload ...
# >> add_dict_of_lessons : eng recY3WUJq96PZuRPK
# phrase=[('recHPZM2bhuSgikRX', "Quel est votre motif de consultation aujourd'hui ?", 'Quel est votre motif de <span id="recRUrPp0aC5oNvVc">consultation</span> aujourd\'hui ?', "Quel est votre motif de <kw>recRUrPp0aC5oNvVc<kw> aujourd'hui ?", "Quel est votre motif de <kw>consultation<kw> aujourd'hui ?", 'Chez le médecin', 'recvRKKiTZIwwawCt-eng', '1', 'eng', 'recHPZM2bhuSgikRX-eng', 'What is your reason for consultation today?', 'assets/audio/ai/eng/recHPZM2bhuSgikRX-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293079/langdeck/assets/audio/ai/eng/recHPZM2bhuSgikRX-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293082/langdeck/assets/audio/ai/fre/recHPZM2bhuSgikRX-fre.mp3', ['recRUrPp0aC5oNvVc'], "['Consultation']", "['recRUrPp0aC5oNvVc-eng']", "['Consultation']", "['At the doctor']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'eng', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'At the doctor', 'recvRKKiTZIwwawCt-eng', 'assets/audio/ai/eng/recvRKKiTZIwwawCt-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/eng/recvRKKiTZIwwawCt-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', 'à faire', 'to do', "['recRUrPp0aC5oNvVc-eng']", "['Consultation']", 'rec7lQw6DtIJP45dn-eng'), ('rec8WSW27ktZD4Gcw', 'Veuillez préciser le sujet relatif à votre problème', '', '', 'Veuillez préciser le sujet relatif à votre problème', 'Chez le médecin', 'recvRKKiTZIwwawCt-eng', '2', 'eng', 'rec8WSW27ktZD4Gcw-eng', 'Please specify the topic relating to your problem', 'assets/audio/ai/eng/rec8WSW27ktZD4Gcw-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293080/langdeck/assets/audio/ai/eng/rec8WSW27ktZD4Gcw-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/rec8WSW27ktZD4Gcw-fre.mp3', [], '', '', '', "['At the doctor']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'eng', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'At the doctor', 'recvRKKiTZIwwawCt-eng', 'assets/audio/ai/eng/recvRKKiTZIwwawCt-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/eng/recvRKKiTZIwwawCt-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', 'à faire', 'to do', '', '', 'rec7lQw6DtIJP45dn-eng'), ('recAFEMFQvJXhOxJn', 'Où avez-vous mal ?', '', '', 'Où avez-vous mal ?', 'Chez le médecin', 'recvRKKiTZIwwawCt-eng', '3', 'eng', 'recAFEMFQvJXhOxJn-eng', 'Where does it hurt ?', 'assets/audio/ai/eng/recAFEMFQvJXhOxJn-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293081/langdeck/assets/audio/ai/eng/recAFEMFQvJXhOxJn-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/recAFEMFQvJXhOxJn-fre.mp3', [], '', '', '', "['At the doctor']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'eng', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'At the doctor', 'recvRKKiTZIwwawCt-eng', 'assets/audio/ai/eng/recvRKKiTZIwwawCt-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/eng/recvRKKiTZIwwawCt-eng.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/lang ...
# >> add_dict_of_lessons : eng recf39GupDsTKKLjP
# >> add_dict_of_lessons : eng recyy4SzPX0NWAx4n
# >> add_dict_of_themes : fre
# >> add_dict_of_lessons : fre recXrgjiwJhADauYJ
# phrase=[('recY1tS2A6OPdUYvP', 'Savourez un copieux petit-déjeuner pendant votre séjour à Tours', 'Savourez un copieux <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> pendant votre séjour à Tours', 'Savourez un copieux <kw>recrYaJMdw31vgPT5<kw> pendant votre séjour à Tours', 'Savourez un copieux <kw>petit-déjeuner<kw> pendant votre séjour à Tours', 'Le buffet', 'recolhmJ3G9UQuKPi-fre', '1', 'fre', 'recY1tS2A6OPdUYvP-fre', 'Savourez un copieux petit-déjeuner pendant votre séjour à Tours', 'assets/audio/ai/fre/recY1tS2A6OPdUYvP-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709101/langdeck/assets/audio/ai/fre/recY1tS2A6OPdUYvP-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709101/langdeck/assets/audio/ai/fre/recY1tS2A6OPdUYvP-fre.mp3', ['recrYaJMdw31vgPT5'], "['Petit-déjeuner']", "['recrYaJMdw31vgPT5-fre']", "['Petit-déjeuner']", "['Le buffet']", 'recolhmJ3G9UQuKPi', 'Le buffet', 'fre', 'Le petit-déjeuner', 'recYrnBviiGa6SErr', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Le buffet', 'recolhmJ3G9UQuKPi-fre', 'assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.", "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.", "['recrYaJMdw31vgPT5-fre']", "['Petit-déjeuner']", 'recYrnBviiGa6SErr-fre'), ('recv2FOuvXA4FdkHn', "Le petit-déjeuner est servi sous forme de buffet dans la salle des petits-déjeuners située au rez-de-chaussée de l'hôtel.", 'Le <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> est servi sous forme de <span id="rec3chhixknslcAHa">buffet</span> dans la salle des petits-déjeuners située au <span id="rec7USMFcyeCZLyRj">rez-de-chaussée</span> de l\'hôtel.', "Le <kw>recrYaJMdw31vgPT5<kw> est servi sous forme de <kw>rec3chhixknslcAHa<kw> dans la salle des petits-déjeuners située au <kw>rec7USMFcyeCZLyRj<kw> de l'hôtel.", "Le <kw>petit-déjeuner<kw> est servi sous forme de <kw>buffet<kw> dans la salle des petits-déjeuners située au <kw>rez-de-chaussée<kw> de l'hôtel.", 'Le buffet', 'recolhmJ3G9UQuKPi-fre', '2', 'fre', 'recv2FOuvXA4FdkHn-fre', "Le petit-déjeuner est servi sous forme de buffet dans la salle des petits-déjeuners située au rez-de-chaussée de l'hôtel.", 'assets/audio/ai/fre/recv2FOuvXA4FdkHn-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709102/langdeck/assets/audio/ai/fre/recv2FOuvXA4FdkHn-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709102/langdeck/assets/audio/ai/fre/recv2FOuvXA4FdkHn-fre.mp3', ['recrYaJMdw31vgPT5', 'rec3chhixknslcAHa', 'rec7USMFcyeCZLyRj'], "['Petit-déjeuner', 'Buffet', 'Rez-de-chaussée']", "['recrYaJMdw31vgPT5-fre', 'rec3chhixknslcAHa-fre', 'rec7USMFcyeCZLyRj-fre']", "['Petit-déjeuner', 'Buffet', 'Rez-de-chaussée']", "['Le buffet']", 'recolhmJ3G9UQuKPi', 'Le buffet', 'fre', 'Le petit-déjeuner', 'recYrnBviiGa6SErr', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Le buffet', 'recolhmJ3G9UQuKPi-fre', 'assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9 ...
# >> add_dict_of_lessons : fre recY3WUJq96PZuRPK
# phrase=[('recHPZM2bhuSgikRX', "Quel est votre motif de consultation aujourd'hui ?", 'Quel est votre motif de <span id="recRUrPp0aC5oNvVc">consultation</span> aujourd\'hui ?', "Quel est votre motif de <kw>recRUrPp0aC5oNvVc<kw> aujourd'hui ?", "Quel est votre motif de <kw>consultation<kw> aujourd'hui ?", 'Chez le médecin', 'recvRKKiTZIwwawCt-fre', '1', 'fre', 'recHPZM2bhuSgikRX-fre', "Quel est votre motif de consultation aujourd'hui ?", 'assets/audio/ai/fre/recHPZM2bhuSgikRX-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293082/langdeck/assets/audio/ai/fre/recHPZM2bhuSgikRX-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293082/langdeck/assets/audio/ai/fre/recHPZM2bhuSgikRX-fre.mp3', ['recRUrPp0aC5oNvVc'], "['Consultation']", "['recRUrPp0aC5oNvVc-fre']", "['Consultation']", "['Chez le médecin']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'fre', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Chez le médecin', 'recvRKKiTZIwwawCt-fre', 'assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', 'à faire', 'à faire', "['recRUrPp0aC5oNvVc-fre']", "['Consultation']", 'rec7lQw6DtIJP45dn-fre'), ('rec8WSW27ktZD4Gcw', 'Veuillez préciser le sujet relatif à votre problème', '', '', 'Veuillez préciser le sujet relatif à votre problème', 'Chez le médecin', 'recvRKKiTZIwwawCt-fre', '2', 'fre', 'rec8WSW27ktZD4Gcw-fre', 'Veuillez préciser le sujet relatif à votre problème', 'assets/audio/ai/fre/rec8WSW27ktZD4Gcw-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/rec8WSW27ktZD4Gcw-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/rec8WSW27ktZD4Gcw-fre.mp3', [], '', '', '', "['Chez le médecin']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'fre', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Chez le médecin', 'recvRKKiTZIwwawCt-fre', 'assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', 'à faire', 'à faire', '', '', 'rec7lQw6DtIJP45dn-fre'), ('recAFEMFQvJXhOxJn', 'Où avez-vous mal ?', '', '', 'Où avez-vous mal ?', 'Chez le médecin', 'recvRKKiTZIwwawCt-fre', '3', 'fre', 'recAFEMFQvJXhOxJn-fre', 'Où avez-vous mal ?', 'assets/audio/ai/fre/recAFEMFQvJXhOxJn-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/recAFEMFQvJXhOxJn-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/recAFEMFQvJXhOxJn-fre.mp3', [], '', '', '', "['Chez le médecin']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'fre', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Chez le médecin', 'recvRKKiTZIwwawCt-fre', 'assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/ ...
# >> add_dict_of_lessons : fre recf39GupDsTKKLjP
# >> add_dict_of_lessons : fre recyy4SzPX0NWAx4n
# >> add_dict_of_themes : ger
# >> add_dict_of_lessons : ger recXrgjiwJhADauYJ
# phrase=[('recY1tS2A6OPdUYvP', 'Savourez un copieux petit-déjeuner pendant votre séjour à Tours', 'Savourez un copieux <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> pendant votre séjour à Tours', 'Savourez un copieux <kw>recrYaJMdw31vgPT5<kw> pendant votre séjour à Tours', 'Savourez un copieux <kw>petit-déjeuner<kw> pendant votre séjour à Tours', 'Le buffet', 'recolhmJ3G9UQuKPi-ger', '1', 'ger', 'recY1tS2A6OPdUYvP-ger', 'Genießen Sie während Ihres Aufenthalts in Tours ein herzhaftes Frühstück', 'assets/audio/ai/ger/recY1tS2A6OPdUYvP-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709105/langdeck/assets/audio/ai/ger/recY1tS2A6OPdUYvP-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709101/langdeck/assets/audio/ai/fre/recY1tS2A6OPdUYvP-fre.mp3', ['recrYaJMdw31vgPT5'], "['Petit-déjeuner']", "['recrYaJMdw31vgPT5-ger']", "['Frühstück']", "['Das Buffet']", 'recolhmJ3G9UQuKPi', 'Le buffet', 'ger', 'Le petit-déjeuner', 'recYrnBviiGa6SErr', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Das Buffet', 'recolhmJ3G9UQuKPi-ger', 'assets/audio/ai/ger/recolhmJ3G9UQuKPi-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706855/langdeck/assets/audio/ai/ger/recolhmJ3G9UQuKPi-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.", 'Der zu studierende Text ist der Website eines Hotels entnommen, das ein Frühstücksbuffet anbietet. Der Text enthält viel Vokabular. Studieren Sie das Menü Satz für Satz und versuchen Sie, sich die Wörter zu merken.', "['recrYaJMdw31vgPT5-ger']", "['Frühstück']", 'recYrnBviiGa6SErr-ger'), ('recv2FOuvXA4FdkHn', "Le petit-déjeuner est servi sous forme de buffet dans la salle des petits-déjeuners située au rez-de-chaussée de l'hôtel.", 'Le <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> est servi sous forme de <span id="rec3chhixknslcAHa">buffet</span> dans la salle des petits-déjeuners située au <span id="rec7USMFcyeCZLyRj">rez-de-chaussée</span> de l\'hôtel.', "Le <kw>recrYaJMdw31vgPT5<kw> est servi sous forme de <kw>rec3chhixknslcAHa<kw> dans la salle des petits-déjeuners située au <kw>rec7USMFcyeCZLyRj<kw> de l'hôtel.", "Le <kw>petit-déjeuner<kw> est servi sous forme de <kw>buffet<kw> dans la salle des petits-déjeuners située au <kw>rez-de-chaussée<kw> de l'hôtel.", 'Le buffet', 'recolhmJ3G9UQuKPi-ger', '2', 'ger', 'recv2FOuvXA4FdkHn-ger', 'Das Frühstück wird in Buffetform im Frühstücksraum im Erdgeschoss des Hotels serviert.', 'assets/audio/ai/ger/recv2FOuvXA4FdkHn-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709106/langdeck/assets/audio/ai/ger/recv2FOuvXA4FdkHn-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709102/langdeck/assets/audio/ai/fre/recv2FOuvXA4FdkHn-fre.mp3', ['recrYaJMdw31vgPT5', 'rec3chhixknslcAHa', 'rec7USMFcyeCZLyRj'], "['Petit-déjeuner', 'Buffet', 'Rez-de-chaussée']", "['recrYaJMdw31vgPT5-ger', 'rec3chhixknslcAHa-ger', 'rec7USMFcyeCZLyRj-ger']", "['Frühstück', 'Büfett', 'Erdgeschoss']", "['Das Buffet']", 'recolhmJ3G9UQuKPi', 'Le buffet', 'ger', 'Le petit-déjeuner', 'recYrnBviiGa6SErr', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Das Buffet', 'recolhmJ3G9UQuKPi-ger', 'assets/audio/ai/ger/recolhmJ3G9UQuKPi-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706855/langdeck/assets/audio/ai/ger/recolhmJ3G9UQuKPi-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3', 'https://res.cloud ...
# >> add_dict_of_lessons : ger recY3WUJq96PZuRPK
# phrase=[('recHPZM2bhuSgikRX', "Quel est votre motif de consultation aujourd'hui ?", 'Quel est votre motif de <span id="recRUrPp0aC5oNvVc">consultation</span> aujourd\'hui ?', "Quel est votre motif de <kw>recRUrPp0aC5oNvVc<kw> aujourd'hui ?", "Quel est votre motif de <kw>consultation<kw> aujourd'hui ?", 'Chez le médecin', 'recvRKKiTZIwwawCt-ger', '1', 'ger', 'recHPZM2bhuSgikRX-ger', 'Was ist Ihr Grund für die heutige Beratung?', 'assets/audio/ai/ger/recHPZM2bhuSgikRX-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293085/langdeck/assets/audio/ai/ger/recHPZM2bhuSgikRX-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293082/langdeck/assets/audio/ai/fre/recHPZM2bhuSgikRX-fre.mp3', ['recRUrPp0aC5oNvVc'], "['Consultation']", "['recRUrPp0aC5oNvVc-ger']", "['Beratung']", "['Beim Arzt']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'ger', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Beim Arzt', 'recvRKKiTZIwwawCt-ger', 'assets/audio/ai/ger/recvRKKiTZIwwawCt-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209949/langdeck/assets/audio/ai/ger/recvRKKiTZIwwawCt-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', 'à faire', 'machen', "['recRUrPp0aC5oNvVc-ger']", "['Beratung']", 'rec7lQw6DtIJP45dn-ger'), ('rec8WSW27ktZD4Gcw', 'Veuillez préciser le sujet relatif à votre problème', '', '', 'Veuillez préciser le sujet relatif à votre problème', 'Chez le médecin', 'recvRKKiTZIwwawCt-ger', '2', 'ger', 'rec8WSW27ktZD4Gcw-ger', 'Bitte geben Sie das Thema an, das zu Ihrem Problem passt', 'assets/audio/ai/ger/rec8WSW27ktZD4Gcw-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293085/langdeck/assets/audio/ai/ger/rec8WSW27ktZD4Gcw-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/rec8WSW27ktZD4Gcw-fre.mp3', [], '', '', '', "['Beim Arzt']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'ger', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Beim Arzt', 'recvRKKiTZIwwawCt-ger', 'assets/audio/ai/ger/recvRKKiTZIwwawCt-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209949/langdeck/assets/audio/ai/ger/recvRKKiTZIwwawCt-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png', 'à faire', 'machen', '', '', 'rec7lQw6DtIJP45dn-ger'), ('recAFEMFQvJXhOxJn', 'Où avez-vous mal ?', '', '', 'Où avez-vous mal ?', 'Chez le médecin', 'recvRKKiTZIwwawCt-ger', '3', 'ger', 'recAFEMFQvJXhOxJn-ger', 'Wo tut es weh ?', 'assets/audio/ai/ger/recAFEMFQvJXhOxJn-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293086/langdeck/assets/audio/ai/ger/recAFEMFQvJXhOxJn-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704293083/langdeck/assets/audio/ai/fre/recAFEMFQvJXhOxJn-fre.mp3', [], '', '', '', "['Beim Arzt']", 'recvRKKiTZIwwawCt', 'Chez le médecin', 'ger', 'Chez le médecin', 'rec7lQw6DtIJP45dn', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png', 'Beim Arzt', 'recvRKKiTZIwwawCt-ger', 'assets/audio/ai/ger/recvRKKiTZIwwawCt-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209949/langdeck/assets/audio/ai/ger/recvRKKiTZIwwawCt-ger.mp3', 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209948/langdeck/assets/audio/ai/fre/recvRKKiTZIwwawCt-fre.mp3', 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/ ...
# >> add_dict_of_lessons : ger recf39GupDsTKKLjP
# >> add_dict_of_lessons : ger recyy4SzPX0NWAx4n

# %% [markdown]
# Ensuite, on itère sur les stories filtrées sur une langue

# %%
vk_langdeck[3]
# Out:
# {'language': 'ger',
#  'themes': [{'theme_rec_id': 'recXrgjiwJhADauYJ',
#    'theme_name': 'Alimentation',
#    'theme_language': 'ger',
#    'theme_translation': 'Essen',
#    'theme_audio': 'assets/audio/ai/ger/recXrgjiwJhADauYJ-ger.mp3',
#    'theme_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697032749/langdeck/assets/audio/ai/ger/recXrgjiwJhADauYJ-ger.mp3',
#    'theme_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697032747/langdeck/assets/audio/ai/fre/recXrgjiwJhADauYJ-fre.mp3',
#    'theme_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1704534134/langdeck/assets/images/themes/sfjtgfprbbnepf3ty1mw.jpg',
#    'lessons': [{'lesson': 'Le petit-déjeuner',
#      'language': 'ger',
#      'lesson_rec_id': 'recXmlJ9UxenIi1gr',
#      'stories': [{'story': 'Le petit-déjeuner',
#        'phrases': [{'phrase_rec_id': 'recUTxQtXiufCX1Nt',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '1',
#          'phrase_position': '1',
#          'phrase': 'Bonjour, tu veux du café ?',
#          'phrase_words': "['Café']",
#          'phrase_words_rec_id': "['recgLzTREq2YHlWn9']",
#          'phrase_words_tr': "['Kaffee']",
#          'phrase_words_tr_rec_id': "['recgLzTREq2YHlWn9-ger']",
#          'phrase_html': 'Bonjour, tu veux du <span id="recgLzTREq2YHlWn9">café</span> ?',
#          'phrase_html_rec_id': 'Bonjour, tu veux du <kw>recgLzTREq2YHlWn9<kw> ?',
#          'phrase_html_kw': 'Bonjour, tu veux du <kw>café<kw> ?',
#          'phrase_translation': 'Hallo, möchtest du einen Kaffee?',
#          'phrase_audio': 'assets/audio/ai/ger/recUTxQtXiufCX1Nt-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947299/langdeck/assets/audio/ai/ger/recUTxQtXiufCX1Nt-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947286/langdeck/assets/audio/ai/fre/recUTxQtXiufCX1Nt-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': "En français, il y a deux façons de s’adresser à des personnes, en fonction du type de relation : en utilisant tu ou vous.Dans une relation amicale ou familiale, on utilise tu (Quel âge as-tu ? Comment t’appelles-tu ? D’où viens-tu ?). Pour s’adresser à des personnes que l'on ne connaît pas, dans les lieux publics comme les magasins, les services ou les administrations, on utilise le pluriel de politesse vous (Quel âge avez-vous ? Comment vous appelez-vous ? Qui êtes-vous ?).Dans les premiers temps d’une relation de travail, on se dit vous, même si on a le même âge.",
#          'phrase_notes_2': "Tu veux, c’est le verbe vouloir conjugué au présent. Son sujet est tu, la deuxième personne du singulier. La terminaison -x s’utilise avec les sujets je et tu : je veux, tu veux.Quand on inverse l’ordre du sujet et du verbe, notamment dans les questions, on écrit veux-tu avec un trait d’union. Exemple : veux-tu du café ?Pour s’adresser poliment à des personnes que l'on ne connaît pas, on utilise le pluriel de politesse « vous »  et on met le verbe en premier (Voulez-vous du café ?). Dans le langage familier, il est courant d'inverser l'ordre (Tu veux du café ? Vous voulez du thé ?).",
#          'phrase_notes_translation': 'Im Französischen gibt es je nach Art der Beziehung zwei Möglichkeiten, Menschen anzusprechen: tu oder vous. In einer freundschaftlichen oder familiären Beziehung verwenden wir tu (Wie alt bist du? Wie heißt du – du? Woher kommst du?) ). Um Personen anzusprechen, die Sie nicht kennen, verwenden Sie an öffentlichen Orten wie Geschäften, Dienstleistungen oder Verwaltungen den höflichen Plural „Sie“ (Wie alt sind Sie? Wie heißt Sie? Wer sind Sie?). In der Anfangsphase einer Arbeit In einer Beziehung nennen wir uns Du, auch wenn wir gleich alt sind.',
#          'phrase_notes_2_translation': 'You want ist das im Präsens konjugierte Verb want. Sein Subjekt ist tu, die zweite Person Singular. Die Endung -x wird bei den Subjekten I und You verwendet: I want, you want. Wenn wir die Reihenfolge von Subjekt und Verb vertauschen, insbesondere bei Fragen, schreiben wir do you want mit einem Bindestrich. Beispiel: Möchten Sie einen Kaffee? Um Menschen, die Sie nicht kennen, höflich anzusprechen, verwenden wir den höflichen Plural „Sie“ und setzen das Verb an die erste Stelle (Möchten Sie einen Kaffee?). In der Umgangssprache ist es üblich, die Reihenfolge umzukehren (Möchten Sie Kaffee? Möchten Sie Tee?).',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recgLzTREq2YHlWn9',
#            'word': 'Café',
#            'word_translation': 'Kaffee'}]},
#         {'phrase_rec_id': 'recpAU9fi9gQyq77C',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '10',
#          'phrase_position': '10',
#          'phrase': 'Je veux bien du pain avec du beurre et de la confiture',
#          'phrase_words': "['Pain', 'Beurre', 'Confiture']",
#          'phrase_words_rec_id': "['recpFeoCwi15UyOe3', 'recroMWe3PJCSMVIq', 'reccrviLRZ5rhpjqf']",
#          'phrase_words_tr': "['Brot', 'Butter', 'Marmelade']",
#          'phrase_words_tr_rec_id': "['recpFeoCwi15UyOe3-ger', 'recroMWe3PJCSMVIq-ger', 'reccrviLRZ5rhpjqf-ger']",
#          'phrase_html': 'Je veux bien du <span id="recpFeoCwi15UyOe3">pain</span> avec du <span id="recroMWe3PJCSMVIq">beurre</span> et de la <span id="reccrviLRZ5rhpjqf">confiture</span>',
#          'phrase_html_rec_id': 'Je veux bien du <kw>recpFeoCwi15UyOe3<kw> avec du <kw>recroMWe3PJCSMVIq<kw> et de la <kw>reccrviLRZ5rhpjqf<kw>',
#          'phrase_html_kw': 'Je veux bien du <kw>pain<kw> avec du <kw>beurre<kw> et de la <kw>confiture<kw>',
#          'phrase_translation': 'Ich hätte gerne etwas Brot mit Butter und Marmelade',
#          'phrase_audio': 'assets/audio/ai/ger/recpAU9fi9gQyq77C-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697635327/langdeck/assets/audio/ai/ger/recpAU9fi9gQyq77C-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697634758/langdeck/assets/audio/ai/fre/recpAU9fi9gQyq77C-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recroMWe3PJCSMVIq',
#            'word': 'Beurre',
#            'word_translation': 'Butter'},
#           {'word_rec_id': 'reccrviLRZ5rhpjqf',
#            'word': 'Confiture',
#            'word_translation': 'Marmelade'},
#           {'word_rec_id': 'recpFeoCwi15UyOe3',
#            'word': 'Pain',
#            'word_translation': 'Brot'}]},
#         {'phrase_rec_id': 'recF1VeoSgj59xmnf',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '11',
#          'phrase_position': '11',
#          'phrase': 'Tu veux du fromage ?',
#          'phrase_words': "['Fromage']",
#          'phrase_words_rec_id': "['recoUyEv4BuTkl2Jy']",
#          'phrase_words_tr': "['Käse']",
#          'phrase_words_tr_rec_id': "['recoUyEv4BuTkl2Jy-ger']",
#          'phrase_html': 'Tu veux du <span id="recoUyEv4BuTkl2Jy">fromage</span> ?',
#          'phrase_html_rec_id': 'Tu veux du <kw>recoUyEv4BuTkl2Jy<kw> ?',
#          'phrase_html_kw': 'Tu veux du <kw>fromage<kw> ?',
#          'phrase_translation': 'Willst du etwas Käse?',
#          'phrase_audio': 'assets/audio/ai/ger/recF1VeoSgj59xmnf-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947309/langdeck/assets/audio/ai/ger/recF1VeoSgj59xmnf-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947294/langdeck/assets/audio/ai/fre/recF1VeoSgj59xmnf-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recoUyEv4BuTkl2Jy',
#            'word': 'Fromage',
#            'word_translation': 'Käse'}]},
#         {'phrase_rec_id': 'reciTOL2fmbj9noVi',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '12',
#          'phrase_position': '12',
#          'phrase': "Non merci, je n'aime pas le fromage",
#          'phrase_words': "['Fromage']",
#          'phrase_words_rec_id': "['recoUyEv4BuTkl2Jy']",
#          'phrase_words_tr': "['Käse']",
#          'phrase_words_tr_rec_id': "['recoUyEv4BuTkl2Jy-ger']",
#          'phrase_html': 'Non merci, je n\'aime pas le <span id="recoUyEv4BuTkl2Jy">fromage</span>',
#          'phrase_html_rec_id': "Non merci, je n'aime pas le <kw>recoUyEv4BuTkl2Jy<kw>",
#          'phrase_html_kw': "Non merci, je n'aime pas le <kw>fromage<kw>",
#          'phrase_translation': 'Nein danke, ich mag keinen Käse',
#          'phrase_audio': 'assets/audio/ai/ger/reciTOL2fmbj9noVi-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697635328/langdeck/assets/audio/ai/ger/reciTOL2fmbj9noVi-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697634759/langdeck/assets/audio/ai/fre/reciTOL2fmbj9noVi-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recoUyEv4BuTkl2Jy',
#            'word': 'Fromage',
#            'word_translation': 'Käse'}]},
#         {'phrase_rec_id': 'recK4R0maJbkoChIL',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '13',
#          'phrase_position': '13',
#          'phrase': 'Tu veux un œuf ?',
#          'phrase_words': "['Œuf']",
#          'phrase_words_rec_id': "['recoSeRIZS7t92XIR']",
#          'phrase_words_tr': "['Ei']",
#          'phrase_words_tr_rec_id': "['recoSeRIZS7t92XIR-ger']",
#          'phrase_html': 'Tu veux un <span id="recoSeRIZS7t92XIR">œuf</span> ?',
#          'phrase_html_rec_id': 'Tu veux un <kw>recoSeRIZS7t92XIR<kw> ?',
#          'phrase_html_kw': 'Tu veux un <kw>œuf<kw> ?',
#          'phrase_translation': 'Willst du ein Ei?',
#          'phrase_audio': 'assets/audio/ai/ger/recK4R0maJbkoChIL-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697634764/langdeck/assets/audio/ai/ger/recK4R0maJbkoChIL-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697634760/langdeck/assets/audio/ai/fre/recK4R0maJbkoChIL-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recoSeRIZS7t92XIR',
#            'word': 'Œuf',
#            'word_translation': 'Ei'}]},
#         {'phrase_rec_id': 'rec1FT308NgPpEpoo',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '14',
#          'phrase_position': '14',
#          'phrase': "S'il te plait, je veux bien un œuf au plat",
#          'phrase_words': "['Œuf au plat']",
#          'phrase_words_rec_id': "['recT4pYfb6prJ2atR']",
#          'phrase_words_tr': "['Spiegelei']",
#          'phrase_words_tr_rec_id': "['recT4pYfb6prJ2atR-ger']",
#          'phrase_html': 'S\'il te plait, je veux bien un <span id="recT4pYfb6prJ2atR">œuf au plat</span>',
#          'phrase_html_rec_id': "S'il te plait, je veux bien un <kw>recT4pYfb6prJ2atR<kw>",
#          'phrase_html_kw': "S'il te plait, je veux bien un <kw>œuf au plat<kw>",
#          'phrase_translation': 'Bitte, ich hätte gerne ein Spiegelei',
#          'phrase_audio': 'assets/audio/ai/ger/rec1FT308NgPpEpoo-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697635329/langdeck/assets/audio/ai/ger/rec1FT308NgPpEpoo-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697634761/langdeck/assets/audio/ai/fre/rec1FT308NgPpEpoo-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recT4pYfb6prJ2atR',
#            'word': 'Œuf au plat',
#            'word_translation': 'Spiegelei'}]},
#         {'phrase_rec_id': 'recYyHnx1RW6rkDQH',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '15',
#          'phrase_position': '15',
#          'phrase': 'Tu veux de la bière ?',
#          'phrase_words': "['Bière']",
#          'phrase_words_rec_id': "['recrjtZ5EXbIiGEMX']",
#          'phrase_words_tr': "['Bier']",
#          'phrase_words_tr_rec_id': "['recrjtZ5EXbIiGEMX-ger']",
#          'phrase_html': 'Tu veux de la <span id="recrjtZ5EXbIiGEMX">bière</span> ?',
#          'phrase_html_rec_id': 'Tu veux de la <kw>recrjtZ5EXbIiGEMX<kw> ?',
#          'phrase_html_kw': 'Tu veux de la <kw>bière<kw> ?',
#          'phrase_translation': 'Willst du etwas Bier?',
#          'phrase_audio': 'assets/audio/ai/ger/recYyHnx1RW6rkDQH-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947313/langdeck/assets/audio/ai/ger/recYyHnx1RW6rkDQH-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947297/langdeck/assets/audio/ai/fre/recYyHnx1RW6rkDQH-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recrjtZ5EXbIiGEMX',
#            'word': 'Bière',
#            'word_translation': 'Bier'}]},
#         {'phrase_rec_id': 'reckJNZKgpFLe91gG',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '16',
#          'phrase_position': '16',
#          'phrase': 'Haha ! Non merci, pas de bière au petit-déjeuner',
#          'phrase_words': "['Bière', 'Petit-déjeuner']",
#          'phrase_words_rec_id': "['recrjtZ5EXbIiGEMX', 'recrYaJMdw31vgPT5']",
#          'phrase_words_tr': "['Bier', 'Frühstück']",
#          'phrase_words_tr_rec_id': "['recrjtZ5EXbIiGEMX-ger', 'recrYaJMdw31vgPT5-ger']",
#          'phrase_html': 'Haha ! Non merci, pas de <span id="recrjtZ5EXbIiGEMX">bière</span> au <span id="recrYaJMdw31vgPT5">petit-déjeuner</span>.',
#          'phrase_html_rec_id': 'Haha ! Non merci, pas de <kw>recrjtZ5EXbIiGEMX<kw> au <kw>recrYaJMdw31vgPT5<kw>.',
#          'phrase_html_kw': 'Haha ! Non merci, pas de <kw>bière<kw> au <kw>petit-déjeuner<kw>.',
#          'phrase_translation': 'Haha! Nein danke, kein Bier zum Frühstück',
#          'phrase_audio': 'assets/audio/ai/ger/reckJNZKgpFLe91gG-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947313/langdeck/assets/audio/ai/ger/reckJNZKgpFLe91gG-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947298/langdeck/assets/audio/ai/fre/reckJNZKgpFLe91gG-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recrjtZ5EXbIiGEMX',
#            'word': 'Bière',
#            'word_translation': 'Bier'},
#           {'word_rec_id': 'recrYaJMdw31vgPT5',
#            'word': 'Petit-déjeuner',
#            'word_translation': 'Frühstück'}]},
#         {'phrase_rec_id': 'recUA7LJgIjxS3OGI',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '2',
#          'phrase_position': '2',
#          'phrase': 'Non merci, pas de café',
#          'phrase_words': "['Café']",
#          'phrase_words_rec_id': "['recgLzTREq2YHlWn9']",
#          'phrase_words_tr': "['Kaffee']",
#          'phrase_words_tr_rec_id': "['recgLzTREq2YHlWn9-ger']",
#          'phrase_html': 'Non merci, pas de <span id="recgLzTREq2YHlWn9">café</span>',
#          'phrase_html_rec_id': 'Non merci, pas de <kw>recgLzTREq2YHlWn9<kw>',
#          'phrase_html_kw': 'Non merci, pas de <kw>café<kw>',
#          'phrase_translation': 'Nein danke, kein Kaffee',
#          'phrase_audio': 'assets/audio/ai/ger/recUA7LJgIjxS3OGI-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947300/langdeck/assets/audio/ai/ger/recUA7LJgIjxS3OGI-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947286/langdeck/assets/audio/ai/fre/recUA7LJgIjxS3OGI-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recgLzTREq2YHlWn9',
#            'word': 'Café',
#            'word_translation': 'Kaffee'}]},
#         {'phrase_rec_id': 'recYdPsDVah50TVed',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '3',
#          'phrase_position': '3',
#          'phrase': 'Tu veux du thé ?',
#          'phrase_words': "['Thé']",
#          'phrase_words_rec_id': "['recHBKIcghkS1g1yr']",
#          'phrase_words_tr': "['Tee']",
#          'phrase_words_tr_rec_id': "['recHBKIcghkS1g1yr-ger']",
#          'phrase_html': 'Tu veux du <span id="recHBKIcghkS1g1yr">thé</span> ?',
#          'phrase_html_rec_id': 'Tu veux du <kw>recHBKIcghkS1g1yr<kw> ?',
#          'phrase_html_kw': 'Tu veux du <kw>thé<kw> ?',
#          'phrase_translation': 'Willst du Tee ?',
#          'phrase_audio': 'assets/audio/ai/ger/recYdPsDVah50TVed-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1699705974/langdeck/assets/audio/ai/ger/recYdPsDVah50TVed-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1699705970/langdeck/assets/audio/ai/fre/recYdPsDVah50TVed-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recHBKIcghkS1g1yr',
#            'word': 'Thé',
#            'word_translation': 'Tee'}]},
#         {'phrase_rec_id': 'recfZufpH4ggLyvr1',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '4',
#          'phrase_position': '4',
#          'phrase': 'Non merci, pas de thé',
#          'phrase_words': "['Thé']",
#          'phrase_words_rec_id': "['recHBKIcghkS1g1yr']",
#          'phrase_words_tr': "['Tee']",
#          'phrase_words_tr_rec_id': "['recHBKIcghkS1g1yr-ger']",
#          'phrase_html': 'Non merci, pas de <span id="recHBKIcghkS1g1yr">thé</span>',
#          'phrase_html_rec_id': 'Non merci, pas de <kw>recHBKIcghkS1g1yr<kw>',
#          'phrase_html_kw': 'Non merci, pas de <kw>thé<kw>',
#          'phrase_translation': 'Nein danke, kein Tee',
#          'phrase_audio': 'assets/audio/ai/ger/recfZufpH4ggLyvr1-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1699705975/langdeck/assets/audio/ai/ger/recfZufpH4ggLyvr1-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1699705971/langdeck/assets/audio/ai/fre/recfZufpH4ggLyvr1-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'recHBKIcghkS1g1yr',
#            'word': 'Thé',
#            'word_translation': 'Tee'}]},
#         {'phrase_rec_id': 'recTAFl7XLOpY2uF8',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '5',
#          'phrase_position': '5',
#          'phrase': 'Tu préfères un verre de lait ?',
#          'phrase_words': "['Préférer', 'Verre', 'Lait']",
#          'phrase_words_rec_id': "['recjrYmMQwRgvVtHW', 'rec2uNVme8oXFMxsB', 'rec828nPZgEYyy3OS']",
#          'phrase_words_tr': "['Bevorzugen', 'Glas', 'Milch']",
#          'phrase_words_tr_rec_id': "['recjrYmMQwRgvVtHW-ger', 'rec2uNVme8oXFMxsB-ger', 'rec828nPZgEYyy3OS-ger']",
#          'phrase_html': 'Tu <span id="recjrYmMQwRgvVtHW">préfères</span> un <span id="rec2uNVme8oXFMxsB">verre</span> de <span id="rec828nPZgEYyy3OS">lait</span> ?',
#          'phrase_html_rec_id': 'Tu <kw>recjrYmMQwRgvVtHW<kw> un <kw>rec2uNVme8oXFMxsB<kw> de <kw>rec828nPZgEYyy3OS<kw> ?',
#          'phrase_html_kw': 'Tu <kw>préfères<kw> un <kw>verre<kw> de <kw>lait<kw> ?',
#          'phrase_translation': 'Möchten Sie lieber ein Glas Milch?',
#          'phrase_audio': 'assets/audio/ai/ger/recTAFl7XLOpY2uF8-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1699705975/langdeck/assets/audio/ai/ger/recTAFl7XLOpY2uF8-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1699705971/langdeck/assets/audio/ai/fre/recTAFl7XLOpY2uF8-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': "Notez la différence entre les accents. Pour l'instant, retenez seulement que é se prononce comme dans le mot thé et è se prononce comme dans le mot lait.",
#          'phrase_notes_2': '',
#          'phrase_notes_translation': 'Beachten Sie den Unterschied zwischen den Akzenten. Denken Sie vorerst daran, dass é wie im Wort „Tee“ und è wie im Wort „Milch“ ausgesprochen wird.',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'rec828nPZgEYyy3OS',
#            'word': 'Lait',
#            'word_translation': 'Milch'},
#           {'word_rec_id': 'recjrYmMQwRgvVtHW',
#            'word': 'Préférer',
#            'word_translation': 'Bevorzugen'},
#           {'word_rec_id': 'rec2uNVme8oXFMxsB',
#            'word': 'Verre',
#            'word_translation': 'Glas'}]},
#         {'phrase_rec_id': 'reczV4nmMx5SMRpub',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '6',
#          'phrase_position': '6',
#          'phrase': "Je veux bien du jus de fruit, s'il te plait",
#          'phrase_words': "['Jus de fruit']",
#          'phrase_words_rec_id': "['rect8hj7MI7YIXGAl']",
#          'phrase_words_tr': "['Fruchtsaft']",
#          'phrase_words_tr_rec_id': "['rect8hj7MI7YIXGAl-ger']",
#          'phrase_html': 'Je veux bien du <span id="rect8hj7MI7YIXGAl">jus de fruit,</span> s\'il te plait',
#          'phrase_html_rec_id': "Je veux bien du <kw>rect8hj7MI7YIXGAl<kw> s'il te plait",
#          'phrase_html_kw': "Je veux bien du <kw>jus de fruit,<kw> s'il te plait",
#          'phrase_translation': 'Ich hätte gerne etwas Fruchtsaft, bitte',
#          'phrase_audio': 'assets/audio/ai/ger/reczV4nmMx5SMRpub-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1699948082/langdeck/assets/audio/ai/ger/reczV4nmMx5SMRpub-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1700043636/langdeck/assets/audio/ai/fre/reczV4nmMx5SMRpub-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
#          'story_desc': "Une leçon de niveau facile pour débuter. Démarrons la journée par un petit-déjeuner pour apprendre les premiers mots et quelques règles simples de l'usage du français dans la vie courante.",
#          'story_desc_translation': 'Eine einfache Lektion für den Anfang. Beginnen wir den Tag mit einem Frühstück, um die ersten Wörter und einige einfache Regeln für die Verwendung der französischen Sprache im Alltag zu lernen.',
#          'story_synopsis': 'Ecoutez bien ce dialogue et apprenez les mots importants.\n',
#          'story_synopsis_translation': 'Hören Sie diesem Dialog aufmerksam zu und lernen Sie die wichtigen Wörter.',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recXmlJ9UxenIi1gr',
#          'words': [{'word_rec_id': 'rect8hj7MI7YIXGAl',
#            'word': 'Jus de fruit',
#            'word_translation': 'Fruchtsaft'}]},
#         {'phrase_rec_id': 'recxzZPbQkLXRT59s',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Le petit-déjeuner',
#          'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#          'phrase_paragraph': '7',
#          'phrase_position': '7',
#          'phrase': "Voici un verre de jus d'orange",
#          'phrase_words': '[\'Verre\', "Jus d\'orange"]',
#          'phrase_words_rec_id': "['rec2uNVme8oXFMxsB', 'receNtWmFuccPjgYU']",
#          'phrase_words_tr': "['Glas', 'Orangensaft']",
#          'phrase_words_tr_rec_id': "['rec2uNVme8oXFMxsB-ger', 'receNtWmFuccPjgYU-ger']",
#          'phrase_html': 'Voici un <span id="rec2uNVme8oXFMxsB">verre</span> de <span id="receNtWmFuccPjgYU">jus d\'orange</span>',
#          'phrase_html_rec_id': 'Voici un <kw>rec2uNVme8oXFMxsB<kw> de <kw>receNtWmFuccPjgYU<kw>',
#          'phrase_html_kw': "Voici un <kw>verre<kw> de <kw>jus d'orange<kw>",
#          'phrase_translation': 'Hier ist ein Glas Orangensaft',
#          'phrase_audio': 'assets/audio/ai/ger/recxzZPbQkLXRT59s-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1699705977/langdeck/assets/audio/ai/ger/recxzZPbQkLXRT59s-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1699705973/langdeck/assets/audio/ai/fre/recxzZPbQkLXRT59s-fre.mp3',
#          'phrase_related_story_tr': 'Frühstück',
#          'phrase_notes': '',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': '',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'recYrnBviiGa6SErr',
#          'story_translation_id': 'recYrnBviiGa6SErr-ger',
#          'story_name': 'Le petit-déjeuner',
#          'story_language': 'ger',
#          'story_translation': 'Frühstück',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030276/langdeck/assets/audio/ai/ger/recYrnBviiGa6SErr-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697030274/langdeck/assets/audio/ai/fre/recYrnBviiGa6SErr-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702393683/langdeck/assets/images/saynetes/aqfhrk9ves19zri8sxoo.jpg',
# ...
#              'word_translation': 'Schokoladengetränk'},
#             {'word_rec_id': 'recgLzTREq2YHlWn9',
#              'word': 'Café',
#              'word_translation': 'Kaffee'},
#             {'word_rec_id': 'recy2rHBcjzSbvbdA',
#              'word': 'Infusion',
#              'word_translation': 'Infusion'},
#             {'word_rec_id': 'recHBKIcghkS1g1yr',
#              'word': 'Thé',
#              'word_translation': 'Tee'}]},
#           {'tp_phrase_rec_id': 'reczhukMZwWSnSRPv',
#            'tp_phrase_words_rec_id': ['rec6tEMn22FIa81P3',
#             'receNtWmFuccPjgYU',
#             'rec1y9aJTbpDT95Zu',
#             'rect8hj7MI7YIXGAl',
#             'rec828nPZgEYyy3OS',
#             'recZ60jraTcknWnBY',
#             'reczpKG1V1BBoy9D0',
#             'recsxgYfJjh3wp8pl',
#             'recoUyEv4BuTkl2Jy',
#             'reccrviLRZ5rhpjqf',
#             'rec9QOxGbTXGwh6ny'],
#            'words': [{'word_rec_id': 'reczpKG1V1BBoy9D0',
#              'word': 'Allégé',
#              'word_translation': 'Aufgehellt'},
#             {'word_rec_id': 'recZ60jraTcknWnBY',
#              'word': 'Bio',
#              'word_translation': 'Bio'},
#             {'word_rec_id': 'rec6tEMn22FIa81P3',
#              'word': 'Boisson',
#              'word_translation': 'Getränk'},
#             {'word_rec_id': 'rec9QOxGbTXGwh6ny',
#              'word': 'Compote',
#              'word_translation': 'Kompott'},
#             {'word_rec_id': 'reccrviLRZ5rhpjqf',
#              'word': 'Confiture',
#              'word_translation': 'Marmelade'},
#             {'word_rec_id': 'recoUyEv4BuTkl2Jy',
#              'word': 'Fromage',
#              'word_translation': 'Käse'},
#             {'word_rec_id': 'receNtWmFuccPjgYU',
#              'word': "Jus d'orange",
#              'word_translation': 'Orangensaft'},
#             {'word_rec_id': 'rect8hj7MI7YIXGAl',
#              'word': 'Jus de fruit',
#              'word_translation': 'Fruchtsaft'},
#             {'word_rec_id': 'rec1y9aJTbpDT95Zu',
#              'word': 'Jus de pomme',
#              'word_translation': 'Apfelsaft'},
#             {'word_rec_id': 'rec828nPZgEYyy3OS',
#              'word': 'Lait',
#              'word_translation': 'Milch'},
#             {'word_rec_id': 'recsxgYfJjh3wp8pl',
#              'word': 'Yaourt',
#              'word_translation': 'Joghurt'}]}]}],
#        'quiz': [{'quiz_name': 'Le quiz du buffet du petit-déjeuner',
#          'quiz_translation': 'Das Frühstücksbuffet-Quiz',
#          'quiz_form': {'quizTitle': 'Le quiz du buffet du petit-déjeuner',
#           'quizSynopsis': "Un petit quiz pour évaluer votre niveau de connaissance à l'issue de cette leçon.",
#           'questions': [{'question': 'Le petit-déjeuner express peut être servi dans la chambre ?',
#             'questionType': 'text',
#             'answers': ['Oui', 'Non'],
#             'correctAnswer': '1'},
#            {'question': 'Le plateau de fromage est compris dans le petit-déjeuner express ?',
#             'questionType': 'text',
#             'answers': ['Oui', 'Non'],
#             'correctAnswer': '2'},
#            {'question': 'Le buffet ne propose pas : ',
#             'questionType': 'text',
#             'answers': ['Pâtisseries',
#              'Boissons',
#              'Fontaine à soda',
#              'Confiture allégée'],
#             'correctAnswer': '3'}]},
#          'quiz_form_translation': {'quizTitle': 'Das Frühstücksbuffet-Quiz',
#           'quizSynopsis': 'Ein kurzes Quiz zur Beurteilung Ihres Wissensstandes am Ende dieser Lektion.',
#           'questions': [{'question': 'Kann ein Express-Frühstück auf dem Zimmer serviert werden?',
#             'questionType': 'text',
#             'answers': ['Ja', 'NEIN'],
#             'correctAnswer': '1'},
#            {'question': 'Ist die Käseplatte im Express-Frühstück inbegriffen?',
#             'questionType': 'text',
#             'answers': ['Ja', 'NEIN'],
#             'correctAnswer': '2'},
#            {'question': 'Das Buffet bietet nicht:',
#             'questionType': 'text',
#             'answers': ['Gebäck',
#              'Getränke',
#              'Soda-Brunnen',
#              'leichte Marmelade'],
#             'correctAnswer': '3'}]}}]}]}]},
#   {'theme_rec_id': 'recY3WUJq96PZuRPK',
#    'theme_name': 'Médical-Santé',
#    'theme_language': 'ger',
#    'theme_translation': 'Gesundheit',
#    'theme_audio': 'assets/audio/ai/ger/recY3WUJq96PZuRPK-ger.mp3',
#    'theme_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697032750/langdeck/assets/audio/ai/ger/recY3WUJq96PZuRPK-ger.mp3',
#    'theme_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697032748/langdeck/assets/audio/ai/fre/recY3WUJq96PZuRPK-fre.mp3',
#    'theme_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1704534392/langdeck/assets/images/themes/tob84meeswwvq9ru0ufs.jpg',
#    'lessons': [{'lesson': 'Le diabète',
#      'language': 'ger',
#      'lesson_rec_id': 'recyI11Lc7cqVNH12',
#      'stories': [{'story': 'Chez le médecin',
#        'phrases': [{'phrase_rec_id': 'recRB9BNBRTq6HWxX',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Chez le médecin',
#          'phrase_related_story_rec_id': 'rec7lQw6DtIJP45dn',
#          'phrase_paragraph': '1',
#          'phrase_position': '1',
#          'phrase': 'Bonjour Docteur, je viens vous voir parce qu’on m’a trouvé du diabète aux Urgences.',
#          'phrase_words': "['Docteur', 'Diabète', 'Urgences']",
#          'phrase_words_rec_id': "['recj9MhYyjip5FZql', 'recmhUC9Wr0zn4i0o', 'recG98jIMPajZVHte']",
#          'phrase_words_tr': "['Arzt', 'Diabetes', 'NOTFÄLLE']",
#          'phrase_words_tr_rec_id': "['recj9MhYyjip5FZql-ger', 'recmhUC9Wr0zn4i0o-ger', 'recG98jIMPajZVHte-ger']",
#          'phrase_html': 'Bonjour <span id="recj9MhYyjip5FZql">Docteur</span>, je viens vous voir parce qu’on m’a trouvé du <span id="recmhUC9Wr0zn4i0o">diabète</span> aux <span id="recG98jIMPajZVHte">Urgences</span>.',
#          'phrase_html_rec_id': 'Bonjour <kw>recj9MhYyjip5FZql<kw>, je viens vous voir parce qu’on m’a trouvé du <kw>recmhUC9Wr0zn4i0o<kw> aux <kw>recG98jIMPajZVHte<kw>.',
#          'phrase_html_kw': 'Bonjour <kw>Docteur<kw>, je viens vous voir parce qu’on m’a trouvé du <kw>diabète<kw> aux <kw>Urgences<kw>.',
#          'phrase_translation': 'Hallo Doktor, ich bin zu Ihnen gekommen, weil in der Notaufnahme bei mir Diabetes festgestellt wurde.',
#          'phrase_audio': 'assets/audio/ai/ger/recRB9BNBRTq6HWxX-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209921/langdeck/assets/audio/ai/ger/recRB9BNBRTq6HWxX-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209920/langdeck/assets/audio/ai/fre/recRB9BNBRTq6HWxX-fre.mp3',
#          'phrase_related_story_tr': 'Beim Arzt',
#          'phrase_notes': "En France, quand on s'adresse à un Médecin, on l'appelle couramment Docteur.",
#          'phrase_notes_2': "En France, on appelle urgences le service hospitalier où sont dirigés les blessés et les malades dont l'état nécessite un traitement immédiat.",
#          'phrase_notes_translation': 'Wenn wir in Frankreich einen Arzt ansprechen, nennen wir ihn üblicherweise „Doktor“.',
#          'phrase_notes_2_translation': 'In Frankreich nennen wir Notfälle die Krankenhausabteilung, in die Verletzte und Kranke geschickt werden, deren Zustand eine sofortige Behandlung erfordert.',
#          'story_rec_id': 'rec7lQw6DtIJP45dn',
#          'story_translation_id': 'rec7lQw6DtIJP45dn-ger',
#          'story_name': 'Chez le médecin',
#          'story_language': 'ger',
#          'story_translation': 'Beim Arzt',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209452/langdeck/assets/audio/ai/ger/rec7lQw6DtIJP45dn-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209451/langdeck/assets/audio/ai/fre/rec7lQw6DtIJP45dn-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1704207183/langdeck/assets/images/medecin-principal-patient-malade-assistant-visite-controle-sante-dans-cabinet-recevant-ordonnance-pour-acheter-traitement-medicaments-apres-rendez-vous-declaration-maladie-lors-consultation.jpg',
#          'story_desc': 'Annonce de la maladie chez le Médecin traitant',
#          'story_desc_translation': 'Meldung der Erkrankung an den behandelnden Arzt',
#          'story_synopsis': "Cette saynète illustre l'annonce de la maladie du diabète chez le Médecin traitant\n",
#          'story_synopsis_translation': 'Diese Skizze veranschaulicht die Meldung einer Diabetes-Erkrankung an den behandelnden Arzt',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recyI11Lc7cqVNH12',
#          'words': [{'word_rec_id': 'recmhUC9Wr0zn4i0o',
#            'word': 'Diabète',
#            'word_translation': 'Diabetes'},
#           {'word_rec_id': 'recj9MhYyjip5FZql',
#            'word': 'Docteur',
#            'word_translation': 'Arzt'},
#           {'word_rec_id': 'recG98jIMPajZVHte',
#            'word': 'Urgences',
#            'word_translation': 'NOTFÄLLE'}]},
#         {'phrase_rec_id': 'recRZ8LbCClL5AW4j',
#          'phrase_language': 'ger',
#          'phrase_related_story': 'Chez le médecin',
#          'phrase_related_story_rec_id': 'rec7lQw6DtIJP45dn',
#          'phrase_paragraph': '2',
#          'phrase_position': '2',
#          'phrase': 'Cela me fait peur car ma mère a été amputée à cause de çà.',
#          'phrase_words': "['Peur', 'Amputer']",
#          'phrase_words_rec_id': "['recwOljHBUC4KIYRh', 'rec073yH2c2jwAMlb']",
#          'phrase_words_tr': "['Furcht', 'Amputieren']",
#          'phrase_words_tr_rec_id': "['recwOljHBUC4KIYRh-ger', 'rec073yH2c2jwAMlb-ger']",
#          'phrase_html': 'Cela me fait <span id="recwOljHBUC4KIYRh">peur</span> car ma mère a été <span id="rec073yH2c2jwAMlb">amputée</span> à cause de çà.',
#          'phrase_html_rec_id': 'Cela me fait <kw>recwOljHBUC4KIYRh<kw> car ma mère a été <kw>rec073yH2c2jwAMlb<kw> à cause de çà.',
#          'phrase_html_kw': 'Cela me fait <kw>peur<kw> car ma mère a été <kw>amputée<kw> à cause de çà.',
#          'phrase_translation': 'Das macht mir Angst, weil meine Mutter deswegen eine Amputation erlitten hat.',
#          'phrase_audio': 'assets/audio/ai/ger/recRZ8LbCClL5AW4j-ger.mp3',
#          'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209921/langdeck/assets/audio/ai/ger/recRZ8LbCClL5AW4j-ger.mp3',
#          'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209920/langdeck/assets/audio/ai/fre/recRZ8LbCClL5AW4j-fre.mp3',
#          'phrase_related_story_tr': 'Beim Arzt',
#          'phrase_notes': 'Cela me fait peur signifie avoir peur.',
#          'phrase_notes_2': '',
#          'phrase_notes_translation': 'Das macht mir Angst, das heißt, ich habe Angst.',
#          'phrase_notes_2_translation': '',
#          'story_rec_id': 'rec7lQw6DtIJP45dn',
#          'story_translation_id': 'rec7lQw6DtIJP45dn-ger',
#          'story_name': 'Chez le médecin',
#          'story_language': 'ger',
#          'story_translation': 'Beim Arzt',
#          'story_level': 'Beginner',
#          'story_episode': 'Part 1',
#          'story_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209452/langdeck/assets/audio/ai/ger/rec7lQw6DtIJP45dn-ger.mp3',
#          'story_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1704209451/langdeck/assets/audio/ai/fre/rec7lQw6DtIJP45dn-fre.mp3',
#          'story_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1704207183/langdeck/assets/images/medecin-principal-patient-malade-assistant-visite-controle-sante-dans-cabinet-recevant-ordonnance-pour-acheter-traitement-medicaments-apres-rendez-vous-declaration-maladie-lors-consultation.jpg',
#          'story_desc': 'Annonce de la maladie chez le Médecin traitant',
#          'story_desc_translation': 'Meldung der Erkrankung an den behandelnden Arzt',
#          'story_synopsis': "Cette saynète illustre l'annonce de la maladie du diabète chez le Médecin traitant\n",
#          'story_synopsis_translation': 'Diese Skizze veranschaulicht die Meldung einer Diabetes-Erkrankung an den behandelnden Arzt',
#          'story_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660478/langdeck/assets/images/saynetes/langdeck-lesson-header-1.png',
#          'story_related_lesson': 'recyI11Lc7cqVNH12',
#          'words': [{'word_rec_id': 'rec073yH2c2jwAMlb',
#            'word': 'Amputer',
#            'word_translation': 'Amputieren'},
#           {'word_rec_id': 'recwOljHBUC4KIYRh',
#            'word': 'Peur',
#            'word_translation': 'Furcht'}]}],
#        'tps': [{'tp_name': 'Chez le médecin',
#          'tp_translation': 'Beim Arzt',
#          'tp_phrases': [{'tp_phrase_rec_id': 'recHPZM2bhuSgikRX',
#            'tp_phrase_words_rec_id': ['recRUrPp0aC5oNvVc'],
#            'words': [{'word_rec_id': 'recRUrPp0aC5oNvVc',
#              'word': 'Consultation',
#              'word_translation': 'Beratung'}]},
#           {'tp_phrase_rec_id': 'rec8WSW27ktZD4Gcw',
#            'tp_phrase_words_rec_id': [],
#            'words': []},
#           {'tp_phrase_rec_id': 'recAFEMFQvJXhOxJn',
#            'tp_phrase_words_rec_id': [],
#            'words': []}]}],
#        'quiz': [{'quiz_name': 'Chez le médecin',
#          'quiz_translation': 'Beim Arzt',
#          'quiz_form': {'quizTitle': 'Chez le médecin',
#           'quizSynopsis': 'Annonce de la maladie du diabète chez le Médecin traitant',
#           'questions': [{'question': "Le diabète c'est quand : ",
#             'questionType': 'text',
#             'answers': ['On a trop de sucre dans le sang',
#              'On a pas assez de sucre dans le sang'],
#             'correctAnswer': '1'},
#            {'question': 'Quel proche du patient a été amputé ?',
#             'questionType': 'text',
#             'answers': ['Le père', 'La mère', 'La grand-mère', 'La soeur'],
#             'correctAnswer': '2'}]},
#          'quiz_form_translation': {'quizTitle': 'Beim Arzt',
#           'quizSynopsis': 'Meldung einer Diabetes-Erkrankung an den behandelnden Arzt',
#           'questions': [{'question': 'Diabetes liegt vor, wenn:',
#             'questionType': 'text',
#             'answers': ['Wir haben zu viel Zucker im Blut',
#              'Wir haben nicht genug Zucker im Blut'],
#             'correctAnswer': '1'},
#            {'question': 'Welcher Angehöriger des Patienten wurde amputiert?',
#             'questionType': 'text',
#             'answers': ['Der Vater', 'Die Mutter', 'Oma', 'Schwester'],
#             'correctAnswer': '2'}]}}]}]}]},
#   {'theme_rec_id': 'recf39GupDsTKKLjP',
#    'theme_name': 'Sport',
#    'theme_language': 'ger',
#    'theme_translation': 'Sport',
#    'theme_audio': 'assets/audio/ai/ger/recf39GupDsTKKLjP-ger.mp3',
#    'theme_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697034088/langdeck/assets/audio/ai/ger/recf39GupDsTKKLjP-ger.mp3',
#    'theme_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697034088/langdeck/assets/audio/ai/fre/recf39GupDsTKKLjP-fre.mp3',
#    'theme_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1704534401/langdeck/assets/images/themes/xqfew3e33jmyrlgyri03.jpg',
#    'lessons': []},
#   {'theme_rec_id': 'recyy4SzPX0NWAx4n',
#    'theme_name': 'Société',
#    'theme_language': 'ger',
#    'theme_translation': 'Unternehmen',
#    'theme_audio': 'assets/audio/ai/ger/recyy4SzPX0NWAx4n-ger.mp3',
#    'theme_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697032751/langdeck/assets/audio/ai/ger/recyy4SzPX0NWAx4n-ger.mp3',
#    'theme_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697032748/langdeck/assets/audio/ai/fre/recyy4SzPX0NWAx4n-fre.mp3',
#    'theme_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1704534106/langdeck/assets/images/themes/cl5kqf6mdcpjwjybqsch.jpg',
#    'lessons': []}]}

# %%
with open('themesdeck.txt', 'w') as f:
  json.dump(vk_langdeck, f, ensure_ascii=False)

# %%
def get_tps (language, story, vk_tuple_tps, vk_tps_cols):
  vk_lang_tp_dict = []
  for vk in vk_tuple_tps:
    # on transforme le tuple en dict
    vk_temp = list(map(lambda x: dict(zip(vk_tps_cols,x)), vk))
    #print (vk_temp[0]["tp_language"])
    if vk_temp[0]["tp_language"] == language and vk_temp[0]["tp_rel_story"] == story:
      vk_lang_tp_dict = vk_temp
  return vk_lang_tp_dict

# %%
for vk_s in vk_stories_vals:
  vk_s_dict = list(map(lambda x: dict(zip(vk_stories_cols,x)), vk_s))
  d_story = {}
  d_story["story"] = list(dict.fromkeys(map(
    lambda x:x["story_name"],
    sorted(vk_s_dict, key=lambda x: x["story_name"]))))[0]
  print (d_story)
# Out:
# {'story': 'Chez le médecin'}
# {'story': 'Le petit-déjeuner'}

# %% [markdown]
# ## Themes

# %%
df_themes = py_modules.load_df_from_gsheet(wb_intgr, "tbl_themes")
df_themes.sort_values (
    by=["theme_name",
        "theme_language",
        ],
    inplace=True)

vk_themes_cols = [
    "theme_rec_id",
    "theme_name",
    "theme_language",
    "theme_translation",
    "theme_audio",
    "theme_audio_url",
    "theme_audio_url_fr",
    ]

vk_themes_vals = df_themes.groupby(["theme_rec_id"])[vk_themes_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Lessons

# %%
df_lessons = py_modules.load_df_from_gsheet(wb_intgr, "tbl_lessons")
df_lessons.sort_values (
    by=["lesson_number",
        "lesson_language",
        ],
    inplace=True)

vk_lessons_cols = [
    "lesson_rec_id",
    "lesson",
    "lesson_language",
    "lesson_story",
    "lesson_pictorial",
    "lesson_quiz",
    "lesson_number",
    "lesson_translation",
    "lesson_audio",
    "lesson_audio_url",
    "lesson_audio_url_fr",
    "lesson_illustration",
    "lesson_related_theme",
    ]

vk_lessons_vals = df_lessons.groupby(["lesson_rec_id"])[vk_lessons_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Stories

# %%
df_stories = py_modules.load_df_from_gsheet(wb_intgr, "tbl_stories")
df_stories.sort_values (
    by=["story_language",
        "story_level",
        "story_name",
        "story_episode",],
    inplace=True)
vk_stories_cols = [
    "story_rec_id",
    "story_translation_id",
    "story_name",
    "story_translation",
    "story_level",
    "story_episode",
    "story_audio_url",
    "story_audio_url_fr",
    "story_illustration",
    "story_desc",
    "story_desc_translation",
    "story_synopsis",
    "story_synopsis_translation",
    "story_lesson_header",
    "story_related_lesson",
    ]

vk_stories_vals = df_stories.groupby(["story_rec_id"])[vk_stories_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## TPs

# %%
def get_tps (language, story, vk_tuple_tps, vk_tps_cols):
  vk_lang_tp_dict = []
  for vk in vk_tuple_tps:
    # on transforme le tuple en dict
    vk_temp = list(map(lambda x: dict(zip(vk_tps_cols,x)), vk))
    #print (vk_temp[0]["tp_language"])
    if vk_temp[0]["tp_language"] == language and vk_temp[0]["tp_rel_story"] == story:
      vk_lang_tp_dict = vk_temp
  return vk_lang_tp_dict

df_tps = py_modules.load_df_from_gsheet(wb_intgr, "tbl_tps")
df_tps.sort_values (
    by=["tp_name",
        "tp_language",
        ],
    inplace=True)

vk_tps_cols = [
    "tp_rec_id",
    "tp_name",
    "tp_language",
    "tp_rel_story",
    "tp_rel_story_rec_id",
    "tp_illustration",
    "tp_translation",
    "tp_translation_id",
    "tp_audio",
    "tp_audio_url",
    "tp_audio_url_fr",
    "tp_lesson_header",
    "tp_summary",
    "tp_summary_translation",
    ]

#vk_tps_vals = df_tps.groupby(["tp_rec_id"])[vk_tps_cols].apply(
#      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# on passe le string contenant le vecteur en un vrai vecteur puis en string (ouf...)
df_tps["tp_rel_story_rec_id"] = df_tps['tp_rel_story_rec_id'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_tps["tp_rel_story"] = df_tps['tp_rel_story'].map(lambda x: "".join(map(str, ast.literal_eval(x))))

df_tps["tp_rel_story_tr_rec_id"] = df_tps[['tp_rel_story_rec_id', 'tp_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)

# merge phrases + story => vue à plat avec les données étendues
df_tps_ext = pd.merge(df_tps, df_stories[vk_stories_cols],
         left_on="tp_rel_story_tr_rec_id",
         right_on="story_translation_id",
         how="left")

# vector of values grouped by language
vk_tps_vals = df_tps_ext.groupby(["tp_language","tp_name"])[vk_tps_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ### Phrases des TPs

# %%
def get_tp_phrases (language, tp, vk_tuple_tps, vk_tps_cols):
  vk_lang_tp_dict = []
  for vk in vk_tuple_tps:
    # on transforme le tuple en dict
    vk_temp = list(map(lambda x: dict(zip(vk_tps_cols,x)), vk))
    #print (vk_temp[0]["tp_language"])
    if vk_temp[0]["tp_phrase_language"] == language and vk_temp[0]["tp_rec_id"] == tp:
      vk_lang_tp_dict = vk_temp
  return vk_lang_tp_dict


df_tp_phrases = py_modules.load_df_from_gsheet(wb_intgr, "tbl_tp_phrases")
df_tp_phrases.sort_values (
    by=["tp_phrase_language",
        "tp_phrase_order",
        ],
    inplace=True)

vk_tp_p_cols = [
    "tp_phrase_rec_id",
    "tp_phrase",
    "tp_phrase_html",
    "tp_phrase_html_rec_id",
    "tp_phrase_html_kw",
    "tp_phrase_rel_tp",
    "tp_phrase_rel_tp_rec_id",
    "tp_phrase_order",
    "tp_phrase_language",
    "tp_phrase_translation_id",
    "tp_phrase_translation",
    "tp_phrase_audio",
    "tp_phrase_audio_url",
    "tp_phrase_audio_url_fr",
    "tp_phrase_words_rec_id",
    "tp_phrase_words",
    "tp_phrase_words_tr_rec_id",
    "tp_phrase_words_tr",
    "phrase_related_tp_tr",
    ]

vk_tp_p_vals = df_tp_phrases.groupby(["tp_phrase_rec_id"])[vk_tp_p_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# on passe le string contenant le vecteur en un vrai vecteur puis en string (ouf...)
df_tp_phrases["tp_phrase_rel_tp_rec_id"] = df_tp_phrases['tp_phrase_rel_tp_rec_id'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_tp_phrases["tp_phrase_rel_tp"] = df_tp_phrases['tp_phrase_rel_tp'].map(lambda x: "".join(map(str, ast.literal_eval(x))))

# merge phrases + story => vue à plat avec les données étendues
df_tp_p_ext = pd.merge(df_tp_phrases, df_tps,
         left_on="tp_phrase_rel_tp_rec_id",
         right_on="tp_translation_id",
         how="left")

vk_col_tp_p_ext = vk_tp_p_cols + vk_tps_cols + [
  "tp_phrase_words_tr_rec_id",
  "tp_phrase_words_tr",
  "tp_rel_story_tr_rec_id",
  ]

# vector of values grouped by language
vk_tp_p_vals = df_tp_p_ext.groupby(["tp_phrase_language","tp_phrase_rel_tp"])[vk_col_tp_p_ext].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# #### Mots des phrases des TPs

# %%
def get_tp_phrase_words (vk_tp_phrases):
  for tp_phrase in vk_tp_phrases:
    print (tp_phrase["tp_phrase_words_tr_rec_id"])
    vk_words = []
    if len(tp_phrase["tp_phrase_words_tr_rec_id"])>0:
      list_words = ast.literal_eval(tp_phrase["tp_phrase_words_tr_rec_id"])
      for word in list_words:
        #------W O R D S----------
        d_word = {}
        # on récupère la valeur pour chaque attribut de mot
        for field in vk_word_cols:
          d_word[field] = f_words_get_value_by_col(
              df_words,
              "word_translation_id",
              field,
              word)

        d_word["word_tr_rec_id"] = word
        vk_words.append(d_word)
    tp_phrase["words"] = vk_words

  return vk_tp_phrases

"""
vk_tp_phrases = get_tp_phrases(
    d_lang["language"],
    vk_tps[0]["tp_rec_id"],
    vk_tp_p_vals,
    vk_col_tp_p_ext,
    )
get_tp_phrase_words (vk_tp_phrases)
"""
# Out:
# '\nvk_tp_phrases = get_tp_phrases(\n    d_lang["language"],\n    vk_tps[0]["tp_rec_id"],\n    vk_tp_p_vals,\n    vk_col_tp_p_ext,\n    )\nget_tp_phrase_words (vk_tp_phrases)\n'

# %% [markdown]
# ## Quiz

# %%
def get_quiz (language, tp, vk_tuple_quiz, vk_quiz_cols):
  vk_lang_quiz_dict = []
  for vk in vk_tuple_quiz:
    # on transforme le tuple en dict
    vk_temp = list(map(lambda x: dict(zip(vk_quiz_cols,x)), vk))
    if vk_temp[0]["quiz_language"] == language and vk_temp[0]["quiz_rel_tp"] == tp:
      vk_lang_quiz_dict = vk_temp
  return vk_lang_quiz_dict

def get_quiz_by_story (language, story, vk_tuple_quiz, vk_quiz_cols):
  vk_lang_quiz_dict = []
  for vk in vk_tuple_quiz:
    # on transforme le tuple en dict
    vk_temp = list(map(lambda x: dict(zip(vk_quiz_cols,x)), vk))
    if vk_temp[0]["quiz_language"] == language and vk_temp[0]["quiz_rel_story"] == story:
      vk_lang_quiz_dict = vk_temp
  return vk_lang_quiz_dict

# %%
df_quiz = py_modules.load_df_from_gsheet(wb_intgr, "tbl_quiz")
df_quiz.sort_values (
    by=["quiz_name",
        "quiz_language",
        ],
    inplace=True)

# %%
vk_quiz_cols = [
    "quiz_rec_id",
    "quiz_name",
    "quiz_language",
    "quiz_rel_tp",
    "quiz_rel_tp_rec_id",
    "quiz_rel_story",
    "quiz_rel_story_rec_id",
    "quiz_illustration",
    "quiz_translation",
    "quiz_translation_id",
    "quiz_audio",
    "quiz_audio_url",
    "quiz_audio_url_fr",
    "quiz_summary_translation",
    "quiz_form",
    "quiz_form_translation",
    "quiz_lesson_header",
    ] + vk_stories_cols

# %%
#vk_quiz_vals = df_quiz.groupby(["quiz_rec_id"])[vk_quiz_cols].apply(
#      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# on passe le string contenant le vecteur en un vrai vecteur puis en string (ouf...)
df_quiz["quiz_rel_tp_rec_id"] = df_quiz['quiz_rel_tp_rec_id'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_quiz["quiz_rel_tp"] = df_quiz['quiz_rel_tp'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_quiz["quiz_rel_story_rec_id"] = df_quiz['quiz_rel_story_rec_id'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_quiz["quiz_rel_story"] = df_quiz['quiz_rel_story'].map(lambda x: "".join(map(str, ast.literal_eval(x))))
df_quiz["quiz_form"] = df_quiz["quiz_form"].map (lambda x:ast.literal_eval(x))
df_quiz["quiz_form_translation"] = df_quiz["quiz_form_translation"].map (lambda x:ast.literal_eval(x))

df_quiz["quiz_rel_tp_tr_rec_id"] = df_quiz[['quiz_rel_tp_rec_id', 'quiz_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)
df_quiz["quiz_rel_story_tr_rec_id"] = df_quiz[['quiz_rel_story_rec_id', 'quiz_language']].apply(
    lambda x: "{}-{}".format(x[0],x[1]),
    axis=1)

# %%
# merge phrases + story => vue à plat avec les données étendues
df_quiz_ext = pd.merge(df_quiz, df_stories[vk_stories_cols],
         left_on="quiz_rel_story_tr_rec_id",
         right_on="story_translation_id",
         how="left")

# %%
# vector of values grouped by language
vk_quiz_vals = df_quiz_ext.groupby(["quiz_language"])[vk_quiz_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Words and keywords

# %%
df_words = py_modules.load_df_from_gsheet(wb_intgr, "tbl_words")
df_words["order"] = df_words["word_type"].map(lambda x:1 if x=="Lemma" else 2 if x=="Expression" else 3)
df_words.sort_values(by=['word_language','word','order',], inplace=True)
vk_word_cols = [
    "word_language",
    "word",
    "word_rec_id",
    "order",
    "word_type",
    "word_translation_id",
    "word_translation",
    "word_lemmas",
    "word_lemmas_rec_id",
    "word_audio",
    "word_audio_url",
    "word_audio_url_fr",
    "word_lemmas_tr_rec_id",
    "word_lemmas_tr",
    "word_notes",
    "word_nutri_notes",
    "word_notes_translation",
    "word_nutri_notes_translation",
    ] # fields (columns)

vk_word_vals = df_words.groupby(["word_language"])[vk_word_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %% [markdown]
# ## Keywords

# %%
def f_phrases_list_to_dict_by_col(col_name, vkp):
  vkf = list(dict.fromkeys(list(map(
        lambda x: x[col_name],
        filter(lambda d: d['phrase_rec_id'] in vkp,
               sorted(vk_lang_dict, key=lambda x: x["phrase_paragraph"]))))))[0]
  return vkf

def f_words_get_value_by_col (df, col_key, col_name, key):
  cval = df.loc[df[col_key]==key][col_name].values.item()
  return cval

# %% [markdown]
# ## Languages

# %%
df_languages = py_modules.load_df_from_gsheet (wb_intgr, "tbl_languages")
df_languages["lang_is_tts"] = df_languages["lang_is_tts"].map(lambda x:True if x=="TRUE" else False)
df_languages["lang_is_available"] = df_languages["lang_is_available"].map(lambda x:True if x=="TRUE" else False)
df_ref_lang = py_modules.load_df_from_gsheet (wb_intgr, "ref_languages")
# merge pour récupérer des infos de référentiels
df_languages = pd.merge (df_languages,
          df_ref_lang[["language_uid","country_ref","flag_icon"]],
          left_on="lang_id",
          right_on="language_uid",
          how="left")
df_languages.drop(columns=["language_uid",], axis=1, inplace=True)
df_languages.rename(
    columns={"country_ref":"lang_country_ref",
             "flag_icon":"lang_flag_icon"},
    inplace=True)
# merge pour récupérer des infos de référentiels
df_ref_lang = py_modules.load_df_from_gsheet (wb_intgr, "ref_languages_countries")
df_languages = pd.merge (df_languages,
          df_ref_lang[["language_uid","language_countries",]],
          left_on="lang_id",
          right_on="language_uid",
          how="left")
df_languages.drop(columns=["language_uid","lang_countries_vk",], axis=1, inplace=True)
df_languages.rename(
    columns={"language_countries":"lang_countries_vk",},
    inplace=True)
# Liste des colonnes pour le dict
vk_language_cols = [
    "lang_id",
    "lang_alpha3",
    "lang_alpha2_google",
    "lang_alpha2",
    "lang_wals",
    "lang_name_native",
    "lang_name_en",
    "lang_name_fr",
    "lang_is_available",
    "lang_is_tts",
    "lang_countries_vk",
    "lang_country_ref",
    "lang_flag_icon",
]
vk_lang_vals = df_languages.groupby(["lang_id"])[vk_language_cols].apply(
      lambda x: list(map(tuple, x.values.tolist()))).to_list()

# %%
# Out:
# {'story': 'Chez le médecin'}
# {'story': 'Le petit-déjeuner'}

# %%
vk_lang = []
# pour chaque phrase : on itère
for vk_lang_tuple in vk_phrases_vals:
  # on transforme le tuple en dict
  vk_lang_dict = list(map(lambda x: dict(zip(vk_phrases_cols,x)), vk_lang_tuple))
  d_lang = {}
  #------L A N G U A G E S----------
  d_lang["language"] = list(dict.fromkeys(map(
      lambda x:x["phrase_language"],
      sorted(vk_lang_dict, key=lambda x: x["phrase_language"]))))[0]
  # get all language cols by key
  for field in vk_language_cols:
    d_lang[field] = df_languages.loc[df_languages["lang_id"]==d_lang["language"]][field].values.item()
  # ce vecteur est dans un format string, il faut le caster en array
  d_lang["lang_countries_vk"] = ast.literal_eval(d_lang["lang_countries_vk"])
  # pour chaque story
  vk_stories = []
  for el_story in list(dict.fromkeys(list(map(
      lambda x: x["phrase_related_story"],
      sorted(vk_lang_dict, key=lambda x: x["phrase_related_story"]))))):
    d_story = {}
    #------S T O R I E S----------
    d_story["story"] = el_story

    #------ T P S----------
    # pour chaque TP
    vk_tps = get_tps(d_lang["language"],
                     el_story,
                     vk_tps_vals,
                     vk_tps_cols,
                     )



    # on ajoute les phrases associées
    vk_tps[0]["tp_phrases"] = get_tp_phrases(
        d_lang["language"],
        vk_tps[0]["tp_rec_id"],
        vk_tp_p_vals,
        vk_col_tp_p_ext,
        )
    # on ajoute les mots récursivement
    vk_tp_phrases = get_tp_phrases(
      d_lang["language"],
      vk_tps[0]["tp_rec_id"],
      vk_tp_p_vals,
      vk_col_tp_p_ext,
      )

    vk_tps = get_tp_phrase_words (vk_tp_phrases)


    d_story["tp_name"] = vk_tps[0]["tp_name"]
    d_story["tp_illustration"] = vk_tps[0]["tp_illustration"]
    d_story["tp_language"] = vk_tps[0]["tp_language"]
    d_story["tp_translation"] = vk_tps[0]["tp_translation"]
    d_story["tp_audio"] = vk_tps[0]["tp_audio"]
    d_story["tp_audio_url"] = vk_tps[0]["tp_audio_url"]
    d_story["tp_audio_url_fr"] = vk_tps[0]["tp_audio_url_fr"]
    d_story["tp_lesson_header"] = vk_tps[0]["tp_lesson_header"]
    d_story["tp_summary"] = vk_tps[0]["tp_summary"]
    d_story["tp_summary_translation"] = vk_tps[0]["tp_summary_translation"]

    d_story["tps"] = vk_tps
    d_story["tp_quiz"] = get_quiz_by_story(d_lang["language"],
              d_story["story"],
              vk_quiz_vals,
              vk_quiz_cols,
              )
    # d_story["tps"]["tp_phrases"] = vk_tps
    # pour chaque phrase
    vk_phrases = []
    for phrase_rec_id in list(dict.fromkeys(list(map(
        lambda x: x["phrase_rec_id"],
        filter(lambda d: d['phrase_related_story'] == el_story,
               sorted(vk_lang_dict, key=lambda x: int(x["phrase_paragraph"]))))))):
      d_phrase = {}
      #------P H R A S E S----------
      # pour chaque colonne, on tranforme en dict
      for field in vk_phrases_cols:
        d_phrase[field] = f_phrases_list_to_dict_by_col(
            field,
            phrase_rec_id)
      d_phrase["phrase_rec_id"] = phrase_rec_id
      # rendons à story ce qui appartient à story...
      for field in vk_stories_cols:
        d_story[field] = d_phrase[field]
        d_phrase.pop(field)

      # pour chaque mot
      vk_words = []
      if len(d_phrase["phrase_words_tr_rec_id"])>0:
        list_words = ast.literal_eval(d_phrase["phrase_words_tr_rec_id"])
        for word in list_words:
          #------W O R D S----------
          d_word = {}
          # on récupère la valeur pour chaque attribut de mot
          for field in vk_word_cols:
            d_word[field] = f_words_get_value_by_col(
                df_words,
                "word_translation_id",
                field,
                word)

          d_word["word_tr_rec_id"] = word
          # lemmes et expressions
          vk_lem_exp = []
          # si lemmes : on itère le vecteur
          if len(d_word["word_lemmas_rec_id"])>0:
            list_lems = ast.literal_eval(d_word["word_lemmas_rec_id"])
            for lem in list_lems:
              #---K E Y W O R D S---
              d_lem = {}
              # on construit la clé de recherche id + langue
              lemkey = lem + "-" + d_word["word_language"]
              # pour chaque colonne (idem words) : on récupère la valeur à partir de la clé
              for field in vk_word_cols:
                d_lem[field] = f_words_get_value_by_col(
                  df_words,
                  "word_translation_id",
                  field,
                  lemkey)
              #----------------------
              d_lem["keyword"] = lem
              vk_lem_exp.append(d_lem)
              #----------------------

          #----------------------
          d_word["keywords"] = vk_lem_exp
          vk_words.append(d_word)
          #----------------------

      #----------------------
      d_phrase["words"] = vk_words
      vk_phrases.append(d_phrase)
      #----------------------

    #----------------------
    d_story["phrases"] = vk_phrases
    #----------------------
    vk_stories.append(d_story)


  #----------------------
  d_lang["stories"] = vk_stories
  #----------------------

  vk_lang.append(d_lang)

# %%
len(vk_stories)
# Out:
# 1

# %%
vk_lang[0]

# %%
vk_tp_phrases
# Out:
# []

# %%
vk_lang[3]['stories']
# Out:
# [{'story': 'Le petit-déjeuner',
#   'tp_name': 'Le buffet',
#   'tp_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png',
#   'tp_language': 'eng',
#   'tp_translation': 'The buffet',
#   'tp_audio': 'assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#   'tp_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#   'tp_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3',
#   'tp_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png',
#   'tp_summary': "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.",
#   'tp_summary_translation': 'The text to study is taken from the website of a hotel which offers a breakfast buffet. The text contains a lot of vocabulary. Study the menu sentence by sentence and try to remember the words.',
#   'tps': [{'tp_phrase_rec_id': 'recY1tS2A6OPdUYvP',
#     'tp_phrase': 'Savourez un copieux petit-déjeuner pendant votre séjour à Tours',
#     'tp_phrase_html': 'Savourez un copieux <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> pendant votre séjour à Tours',
#     'tp_phrase_html_rec_id': 'Savourez un copieux <kw>recrYaJMdw31vgPT5<kw> pendant votre séjour à Tours',
#     'tp_phrase_html_kw': 'Savourez un copieux <kw>petit-déjeuner<kw> pendant votre séjour à Tours',
#     'tp_phrase_rel_tp': 'Le buffet',
#     'tp_phrase_rel_tp_rec_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_phrase_order': '1',
#     'tp_phrase_language': 'eng',
#     'tp_phrase_translation_id': 'recY1tS2A6OPdUYvP-eng',
#     'tp_phrase_translation': 'Savor a hearty breakfast during your stay in Tours',
#     'tp_phrase_audio': 'assets/audio/ai/eng/recY1tS2A6OPdUYvP-eng.mp3',
#     'tp_phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709096/langdeck/assets/audio/ai/eng/recY1tS2A6OPdUYvP-eng.mp3',
#     'tp_phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709101/langdeck/assets/audio/ai/fre/recY1tS2A6OPdUYvP-fre.mp3',
#     'tp_phrase_words_rec_id': "['recrYaJMdw31vgPT5']",
#     'tp_phrase_words': "['Petit-déjeuner']",
#     'tp_phrase_words_tr_rec_id': "['recrYaJMdw31vgPT5-eng']",
#     'tp_phrase_words_tr': "['Breakfast']",
#     'phrase_related_tp_tr': "['The buffet']",
#     'tp_rec_id': 'recolhmJ3G9UQuKPi',
#     'tp_name': 'Le buffet',
#     'tp_language': 'eng',
#     'tp_rel_story': 'Le petit-déjeuner',
#     'tp_rel_story_rec_id': 'recYrnBviiGa6SErr',
#     'tp_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png',
#     'tp_translation': 'The buffet',
#     'tp_translation_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_audio': 'assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3',
#     'tp_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png',
#     'tp_summary': "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.",
#     'tp_summary_translation': 'The text to study is taken from the website of a hotel which offers a breakfast buffet. The text contains a lot of vocabulary. Study the menu sentence by sentence and try to remember the words.',
#     'tp_rel_story_tr_rec_id': 'recYrnBviiGa6SErr-eng',
#     'words': [{'word_language': 'eng',
#       'word': 'Petit-déjeuner',
#       'word_rec_id': 'recrYaJMdw31vgPT5',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recrYaJMdw31vgPT5-eng',
#       'word_translation': 'Breakfast',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recrYaJMdw31vgPT5-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679451/langdeck/assets/audio/ai/eng/recrYaJMdw31vgPT5-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679464/langdeck/assets/audio/ai/fre/recrYaJMdw31vgPT5-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Le petit-déjeuner est le premier repas de la journée. Il se prend le matin et se compose souvent de café, de thé, de lait, de jus de fruits, accompagné de pain, de céréales ou de brioche avec de la confiture. Mais il peut également se composer d'aliments salés comme les oeufs, le bacon, les saucisses, etc.",
#       'word_nutri_notes': 'Il faut savoir qu’au réveil la glycémie est normale (1g/l) et que l’organisme n’a pas besoin de sucres rapides au réveil.\nSi vous prenez du sucre, de la confiture, du miel, du pain blanc, qui sont tous des sucres rapides (ou à index glycémique élevé) alors vous risquez de déclencher une hyperglycémie.\nCela sera suivi d’une production d’insuline qui induira la mise en réserve des sucres et des graisses (prise de poids).\nEnsuite vous allez être en hypoglycémie en fin de matinée et avoir une sensation de faim et l’envie de grignoter sucré.\n\nLe petit déjeuner idéal est donc celui qui associe un peu de glucides à index glycémique bas (pain complet, pain de seigle, galette de sarrasin, flocons d’avoine) avec des protéines (jambon, fromage, oeuf, viande des grisons…) et du gras (beurre, gras du fromage ou d’une charcuterie).\nLe petit déjeuner assure une excellente satiété pour toute la matinée, une grande forme physique et intellectuelle.',
#       'word_notes_translation': 'Breakfast is the first meal of the day. It is taken in the morning and often consists of coffee, tea, milk, fruit juice, accompanied by bread, cereals or brioche with jam. But it can also consist of salty foods like eggs, bacon, sausages, etc.',
#       'word_nutri_notes_translation': 'You should know that when you wake up, your blood sugar level is normal (1g/l) and that the body does not need quick sugars when you wake up.\nIf you take sugar, jam, honey, white bread, which are all fast sugars (or high glycemic index) then you risk triggering hyperglycemia.\nThis will be followed by insulin production which will induce the storage of sugars and fats (weight gain).\nThen you will be hypoglycemic at the end of the morning and have a feeling of hunger and the desire to snack on something sweet.\n\nThe ideal breakfast is therefore one which combines a few carbohydrates with a low glycemic index (wholemeal bread, rye bread, buckwheat pancakes, oatmeal) with proteins (ham, cheese, egg, grisons meat, etc.) and fat (butter, fat from cheese or cold meats).\nBreakfast ensures excellent satiety for the whole morning, great physical and intellectual fitness.',
#       'word_tr_rec_id': 'recrYaJMdw31vgPT5-eng'}]},
#    {'tp_phrase_rec_id': 'recv2FOuvXA4FdkHn',
#     'tp_phrase': "Le petit-déjeuner est servi sous forme de buffet dans la salle des petits-déjeuners située au rez-de-chaussée de l'hôtel.",
#     'tp_phrase_html': 'Le <span id="recrYaJMdw31vgPT5">petit-déjeuner</span> est servi sous forme de <span id="rec3chhixknslcAHa">buffet</span> dans la salle des petits-déjeuners située au <span id="rec7USMFcyeCZLyRj">rez-de-chaussée</span> de l\'hôtel.',
#     'tp_phrase_html_rec_id': "Le <kw>recrYaJMdw31vgPT5<kw> est servi sous forme de <kw>rec3chhixknslcAHa<kw> dans la salle des petits-déjeuners située au <kw>rec7USMFcyeCZLyRj<kw> de l'hôtel.",
#     'tp_phrase_html_kw': "Le <kw>petit-déjeuner<kw> est servi sous forme de <kw>buffet<kw> dans la salle des petits-déjeuners située au <kw>rez-de-chaussée<kw> de l'hôtel.",
#     'tp_phrase_rel_tp': 'Le buffet',
#     'tp_phrase_rel_tp_rec_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_phrase_order': '2',
#     'tp_phrase_language': 'eng',
#     'tp_phrase_translation_id': 'recv2FOuvXA4FdkHn-eng',
#     'tp_phrase_translation': 'Breakfast is served buffet style in the breakfast room located on the ground floor of the hotel.',
#     'tp_phrase_audio': 'assets/audio/ai/eng/recv2FOuvXA4FdkHn-eng.mp3',
#     'tp_phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709097/langdeck/assets/audio/ai/eng/recv2FOuvXA4FdkHn-eng.mp3',
#     'tp_phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709102/langdeck/assets/audio/ai/fre/recv2FOuvXA4FdkHn-fre.mp3',
#     'tp_phrase_words_rec_id': "['recrYaJMdw31vgPT5', 'rec3chhixknslcAHa', 'rec7USMFcyeCZLyRj']",
#     'tp_phrase_words': "['Petit-déjeuner', 'Buffet', 'Rez-de-chaussée']",
#     'tp_phrase_words_tr_rec_id': "['recrYaJMdw31vgPT5-eng', 'rec3chhixknslcAHa-eng', 'rec7USMFcyeCZLyRj-eng']",
#     'tp_phrase_words_tr': "['Breakfast', 'Buffet', 'Ground floor']",
#     'phrase_related_tp_tr': "['The buffet']",
#     'tp_rec_id': 'recolhmJ3G9UQuKPi',
#     'tp_name': 'Le buffet',
#     'tp_language': 'eng',
#     'tp_rel_story': 'Le petit-déjeuner',
#     'tp_rel_story_rec_id': 'recYrnBviiGa6SErr',
#     'tp_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png',
#     'tp_translation': 'The buffet',
#     'tp_translation_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_audio': 'assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3',
#     'tp_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png',
#     'tp_summary': "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.",
#     'tp_summary_translation': 'The text to study is taken from the website of a hotel which offers a breakfast buffet. The text contains a lot of vocabulary. Study the menu sentence by sentence and try to remember the words.',
#     'tp_rel_story_tr_rec_id': 'recYrnBviiGa6SErr-eng',
#     'words': [{'word_language': 'eng',
#       'word': 'Petit-déjeuner',
#       'word_rec_id': 'recrYaJMdw31vgPT5',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recrYaJMdw31vgPT5-eng',
#       'word_translation': 'Breakfast',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recrYaJMdw31vgPT5-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679451/langdeck/assets/audio/ai/eng/recrYaJMdw31vgPT5-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679464/langdeck/assets/audio/ai/fre/recrYaJMdw31vgPT5-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Le petit-déjeuner est le premier repas de la journée. Il se prend le matin et se compose souvent de café, de thé, de lait, de jus de fruits, accompagné de pain, de céréales ou de brioche avec de la confiture. Mais il peut également se composer d'aliments salés comme les oeufs, le bacon, les saucisses, etc.",
#       'word_nutri_notes': 'Il faut savoir qu’au réveil la glycémie est normale (1g/l) et que l’organisme n’a pas besoin de sucres rapides au réveil.\nSi vous prenez du sucre, de la confiture, du miel, du pain blanc, qui sont tous des sucres rapides (ou à index glycémique élevé) alors vous risquez de déclencher une hyperglycémie.\nCela sera suivi d’une production d’insuline qui induira la mise en réserve des sucres et des graisses (prise de poids).\nEnsuite vous allez être en hypoglycémie en fin de matinée et avoir une sensation de faim et l’envie de grignoter sucré.\n\nLe petit déjeuner idéal est donc celui qui associe un peu de glucides à index glycémique bas (pain complet, pain de seigle, galette de sarrasin, flocons d’avoine) avec des protéines (jambon, fromage, oeuf, viande des grisons…) et du gras (beurre, gras du fromage ou d’une charcuterie).\nLe petit déjeuner assure une excellente satiété pour toute la matinée, une grande forme physique et intellectuelle.',
#       'word_notes_translation': 'Breakfast is the first meal of the day. It is taken in the morning and often consists of coffee, tea, milk, fruit juice, accompanied by bread, cereals or brioche with jam. But it can also consist of salty foods like eggs, bacon, sausages, etc.',
#       'word_nutri_notes_translation': 'You should know that when you wake up, your blood sugar level is normal (1g/l) and that the body does not need quick sugars when you wake up.\nIf you take sugar, jam, honey, white bread, which are all fast sugars (or high glycemic index) then you risk triggering hyperglycemia.\nThis will be followed by insulin production which will induce the storage of sugars and fats (weight gain).\nThen you will be hypoglycemic at the end of the morning and have a feeling of hunger and the desire to snack on something sweet.\n\nThe ideal breakfast is therefore one which combines a few carbohydrates with a low glycemic index (wholemeal bread, rye bread, buckwheat pancakes, oatmeal) with proteins (ham, cheese, egg, grisons meat, etc.) and fat (butter, fat from cheese or cold meats).\nBreakfast ensures excellent satiety for the whole morning, great physical and intellectual fitness.',
#       'word_tr_rec_id': 'recrYaJMdw31vgPT5-eng'},
#      {'word_language': 'eng',
#       'word': 'Buffet',
#       'word_rec_id': 'rec3chhixknslcAHa',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'rec3chhixknslcAHa-eng',
#       'word_translation': 'Buffet',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/rec3chhixknslcAHa-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704294/langdeck/assets/audio/ai/eng/rec3chhixknslcAHa-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704301/langdeck/assets/audio/ai/fre/rec3chhixknslcAHa-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': 'Table ou présentoir garni de mets sucrés et salés, et de boissons, pour un repas ou une réception ; ensemble de ces mets et boissons.',
#       'word_nutri_notes': '',
#       'word_notes_translation': 'Table or display filled with sweet and savory dishes, and drinks, for a meal or reception; all of these foods and drinks.',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'rec3chhixknslcAHa-eng'},
#      {'word_language': 'eng',
#       'word': 'Rez-de-chaussée',
#       'word_rec_id': 'rec7USMFcyeCZLyRj',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'rec7USMFcyeCZLyRj-eng',
#       'word_translation': 'Ground floor',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/rec7USMFcyeCZLyRj-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704299/langdeck/assets/audio/ai/eng/rec7USMFcyeCZLyRj-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704306/langdeck/assets/audio/ai/fre/rec7USMFcyeCZLyRj-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Partie d'un bâtiment dont le sol se trouve au niveau du terrain environnant. Habiter au rez-de-chaussée. En France, le rez-de-chaussée correspond à l'étage zéro.",
#       'word_nutri_notes': '',
#       'word_notes_translation': 'Part of a building whose floor is at the level of the surrounding land. Live on the ground floor. In France, the ground floor corresponds to floor zero.',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'rec7USMFcyeCZLyRj-eng'}]},
#    {'tp_phrase_rec_id': 'rec0bBrG20pIsCVSt',
#     'tp_phrase': 'Il peut également vous être apporté en chambre si vous en faites la demande.',
#     'tp_phrase_html': 'Il peut également vous être apporté en <span id="recuokEseR3K6lQoC">chambre</span> si vous en faites la demande.',
#     'tp_phrase_html_rec_id': 'Il peut également vous être apporté en <kw>recuokEseR3K6lQoC<kw> si vous en faites la demande.',
#     'tp_phrase_html_kw': 'Il peut également vous être apporté en <kw>chambre<kw> si vous en faites la demande.',
#     'tp_phrase_rel_tp': 'Le buffet',
#     'tp_phrase_rel_tp_rec_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_phrase_order': '3',
#     'tp_phrase_language': 'eng',
#     'tp_phrase_translation_id': 'rec0bBrG20pIsCVSt-eng',
#     'tp_phrase_translation': 'It can also be brought to your room if you request it.',
#     'tp_phrase_audio': 'assets/audio/ai/eng/rec0bBrG20pIsCVSt-eng.mp3',
#     'tp_phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709098/langdeck/assets/audio/ai/eng/rec0bBrG20pIsCVSt-eng.mp3',
#     'tp_phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709102/langdeck/assets/audio/ai/fre/rec0bBrG20pIsCVSt-fre.mp3',
#     'tp_phrase_words_rec_id': "['recuokEseR3K6lQoC']",
#     'tp_phrase_words': "['Chambre']",
#     'tp_phrase_words_tr_rec_id': "['recuokEseR3K6lQoC-eng']",
#     'tp_phrase_words_tr': "['Bedroom']",
#     'phrase_related_tp_tr': "['The buffet']",
#     'tp_rec_id': 'recolhmJ3G9UQuKPi',
#     'tp_name': 'Le buffet',
#     'tp_language': 'eng',
#     'tp_rel_story': 'Le petit-déjeuner',
#     'tp_rel_story_rec_id': 'recYrnBviiGa6SErr',
#     'tp_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png',
#     'tp_translation': 'The buffet',
#     'tp_translation_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_audio': 'assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3',
#     'tp_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png',
#     'tp_summary': "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.",
#     'tp_summary_translation': 'The text to study is taken from the website of a hotel which offers a breakfast buffet. The text contains a lot of vocabulary. Study the menu sentence by sentence and try to remember the words.',
#     'tp_rel_story_tr_rec_id': 'recYrnBviiGa6SErr-eng',
#     'words': [{'word_language': 'eng',
#       'word': 'Chambre',
#       'word_rec_id': 'recuokEseR3K6lQoC',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recuokEseR3K6lQoC-eng',
#       'word_translation': 'Bedroom',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recuokEseR3K6lQoC-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704294/langdeck/assets/audio/ai/eng/recuokEseR3K6lQoC-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704302/langdeck/assets/audio/ai/fre/recuokEseR3K6lQoC-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Pièce d'une habitation où l'on dort. Chambre d'amis, chambre d'hôtel.",
#       'word_nutri_notes': '',
#       'word_notes_translation': 'Room in a house where people sleep. Guest room, hotel room.',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'recuokEseR3K6lQoC-eng'}]},
#    {'tp_phrase_rec_id': 'recpCIHyWMDex50cq',
#     'tp_phrase': 'Vous retrouverez sur notre buffet les produits suivants :',
#     'tp_phrase_html': 'Vous retrouverez sur notre <span id="rec3chhixknslcAHa">buffet</span> les produits suivants :',
#     'tp_phrase_html_rec_id': 'Vous retrouverez sur notre <kw>rec3chhixknslcAHa<kw> les produits suivants :',
#     'tp_phrase_html_kw': 'Vous retrouverez sur notre <kw>buffet<kw> les produits suivants :',
#     'tp_phrase_rel_tp': 'Le buffet',
#     'tp_phrase_rel_tp_rec_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_phrase_order': '4',
#     'tp_phrase_language': 'eng',
#     'tp_phrase_translation_id': 'recpCIHyWMDex50cq-eng',
#     'tp_phrase_translation': 'You will find the following products on our buffet:',
#     'tp_phrase_audio': 'assets/audio/ai/eng/recpCIHyWMDex50cq-eng.mp3',
#     'tp_phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709099/langdeck/assets/audio/ai/eng/recpCIHyWMDex50cq-eng.mp3',
#     'tp_phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709103/langdeck/assets/audio/ai/fre/recpCIHyWMDex50cq-fre.mp3',
#     'tp_phrase_words_rec_id': "['rec3chhixknslcAHa']",
#     'tp_phrase_words': "['Buffet']",
#     'tp_phrase_words_tr_rec_id': "['rec3chhixknslcAHa-eng']",
#     'tp_phrase_words_tr': "['Buffet']",
#     'phrase_related_tp_tr': "['The buffet']",
#     'tp_rec_id': 'recolhmJ3G9UQuKPi',
#     'tp_name': 'Le buffet',
#     'tp_language': 'eng',
#     'tp_rel_story': 'Le petit-déjeuner',
#     'tp_rel_story_rec_id': 'recYrnBviiGa6SErr',
#     'tp_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png',
#     'tp_translation': 'The buffet',
#     'tp_translation_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_audio': 'assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3',
#     'tp_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png',
#     'tp_summary': "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.",
#     'tp_summary_translation': 'The text to study is taken from the website of a hotel which offers a breakfast buffet. The text contains a lot of vocabulary. Study the menu sentence by sentence and try to remember the words.',
#     'tp_rel_story_tr_rec_id': 'recYrnBviiGa6SErr-eng',
#     'words': [{'word_language': 'eng',
#       'word': 'Buffet',
#       'word_rec_id': 'rec3chhixknslcAHa',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'rec3chhixknslcAHa-eng',
#       'word_translation': 'Buffet',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/rec3chhixknslcAHa-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704294/langdeck/assets/audio/ai/eng/rec3chhixknslcAHa-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704301/langdeck/assets/audio/ai/fre/rec3chhixknslcAHa-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': 'Table ou présentoir garni de mets sucrés et salés, et de boissons, pour un repas ou une réception ; ensemble de ces mets et boissons.',
#       'word_nutri_notes': '',
#       'word_notes_translation': 'Table or display filled with sweet and savory dishes, and drinks, for a meal or reception; all of these foods and drinks.',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'rec3chhixknslcAHa-eng'}]},
#    {'tp_phrase_rec_id': 'reclQq3YULYyVi2LP',
#     'tp_phrase': 'Boissons chaudes : café expresso, café filtre, thé, infusion, chocolat chaud, cappuccino, thé, infusion',
#     'tp_phrase_html': '<span id="rec6tEMn22FIa81P3">Boissons</span> chaudes : <span id="recgLzTREq2YHlWn9">café</span> expresso, café filtre, <span id="recHBKIcghkS1g1yr">thé</span>, <span id="recy2rHBcjzSbvbdA">infusion</span>, <span id="recm76dGxSUogAOKW">chocolat</span> chaud, cappuccino, thé, infusion',
#     'tp_phrase_html_rec_id': '<kw>rec6tEMn22FIa81P3<kw> chaudes : <kw>recgLzTREq2YHlWn9<kw> expresso, café filtre, <kw>recHBKIcghkS1g1yr<kw>, <kw>recy2rHBcjzSbvbdA<kw>, <kw>recm76dGxSUogAOKW<kw> chaud, cappuccino, thé, infusion',
#     'tp_phrase_html_kw': '<kw>Boissons<kw> chaudes : <kw>café<kw> expresso, café filtre, <kw>thé<kw>, <kw>infusion<kw>, <kw>chocolat<kw> chaud, cappuccino, thé, infusion',
#     'tp_phrase_rel_tp': 'Le buffet',
#     'tp_phrase_rel_tp_rec_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_phrase_order': '5',
#     'tp_phrase_language': 'eng',
#     'tp_phrase_translation_id': 'reclQq3YULYyVi2LP-eng',
#     'tp_phrase_translation': 'Hot drinks: espresso coffee, filter coffee, tea, infusion, hot chocolate, cappuccino, tea, infusion',
#     'tp_phrase_audio': 'assets/audio/ai/eng/reclQq3YULYyVi2LP-eng.mp3',
#     'tp_phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709099/langdeck/assets/audio/ai/eng/reclQq3YULYyVi2LP-eng.mp3',
#     'tp_phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709104/langdeck/assets/audio/ai/fre/reclQq3YULYyVi2LP-fre.mp3',
#     'tp_phrase_words_rec_id': "['rec6tEMn22FIa81P3', 'recgLzTREq2YHlWn9', 'recHBKIcghkS1g1yr', 'recy2rHBcjzSbvbdA', 'recm76dGxSUogAOKW']",
#     'tp_phrase_words': "['Boisson', 'Café', 'Thé', 'Infusion', 'Boisson au chocolat']",
#     'tp_phrase_words_tr_rec_id': "['rec6tEMn22FIa81P3-eng', 'recgLzTREq2YHlWn9-eng', 'recHBKIcghkS1g1yr-eng', 'recy2rHBcjzSbvbdA-eng', 'recm76dGxSUogAOKW-eng']",
#     'tp_phrase_words_tr': "['Beverage', 'Coffee', 'Tea', 'Infusion', 'Chocolate drink']",
#     'phrase_related_tp_tr': "['The buffet']",
#     'tp_rec_id': 'recolhmJ3G9UQuKPi',
#     'tp_name': 'Le buffet',
#     'tp_language': 'eng',
#     'tp_rel_story': 'Le petit-déjeuner',
#     'tp_rel_story_rec_id': 'recYrnBviiGa6SErr',
#     'tp_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png',
#     'tp_translation': 'The buffet',
#     'tp_translation_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_audio': 'assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3',
#     'tp_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png',
#     'tp_summary': "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.",
#     'tp_summary_translation': 'The text to study is taken from the website of a hotel which offers a breakfast buffet. The text contains a lot of vocabulary. Study the menu sentence by sentence and try to remember the words.',
#     'tp_rel_story_tr_rec_id': 'recYrnBviiGa6SErr-eng',
#     'words': [{'word_language': 'eng',
#       'word': 'Boisson',
#       'word_rec_id': 'rec6tEMn22FIa81P3',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'rec6tEMn22FIa81P3-eng',
#       'word_translation': 'Beverage',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/rec6tEMn22FIa81P3-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704293/langdeck/assets/audio/ai/eng/rec6tEMn22FIa81P3-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704301/langdeck/assets/audio/ai/fre/rec6tEMn22FIa81P3-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Tout liquide que l'on boit : Boisson chaude, froide, avec ou sans alcool.",
#       'word_nutri_notes': '',
#       'word_notes_translation': 'Any liquid you drink: Hot or cold drink, with or without alcohol.',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'rec6tEMn22FIa81P3-eng'},
#      {'word_language': 'eng',
#       'word': 'Café',
#       'word_rec_id': 'recgLzTREq2YHlWn9',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recgLzTREq2YHlWn9-eng',
#       'word_translation': 'Coffee',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recgLzTREq2YHlWn9-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679444/langdeck/assets/audio/ai/eng/recgLzTREq2YHlWn9-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679456/langdeck/assets/audio/ai/fre/recgLzTREq2YHlWn9-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': 'En France, au petit-déjeuner, on boit surtout du café, avec ou sans lait.',
#       'word_nutri_notes': 'Le café ne contient presque pas de calories, mais le sucre et la crème qu’on lui ajoute peuvent être très riches. Pour pleinement profiter de ses bienfaits, mieux vaut boire son café noir.',
#       'word_notes_translation': 'In France, for breakfast, we mainly drink coffee, with or without milk.',
#       'word_nutri_notes_translation': 'Coffee contains almost no calories, but the sugar and cream added to it can be very rich. To fully benefit from its benefits, it is better to drink your coffee black.',
#       'word_tr_rec_id': 'recgLzTREq2YHlWn9-eng'},
#      {'word_language': 'eng',
#       'word': 'Thé',
#       'word_rec_id': 'recHBKIcghkS1g1yr',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recHBKIcghkS1g1yr-eng',
#       'word_translation': 'Tea',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recHBKIcghkS1g1yr-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679452/langdeck/assets/audio/ai/eng/recHBKIcghkS1g1yr-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679465/langdeck/assets/audio/ai/fre/recHBKIcghkS1g1yr-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': '',
#       'word_nutri_notes': '',
#       'word_notes_translation': '',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'recHBKIcghkS1g1yr-eng'},
#      {'word_language': 'eng',
#       'word': 'Infusion',
#       'word_rec_id': 'recy2rHBcjzSbvbdA',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recy2rHBcjzSbvbdA-eng',
#       'word_translation': 'Infusion',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recy2rHBcjzSbvbdA-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704297/langdeck/assets/audio/ai/eng/recy2rHBcjzSbvbdA-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704303/langdeck/assets/audio/ai/fre/recy2rHBcjzSbvbdA-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Préparation liquide buvable, obtenue par l'action de l'eau bouillante sur une substance (souvent une plante) dont les principes solubles actifs se diffusent dans l'eau par macération. Synonyme : tisane.",
#       'word_nutri_notes': '',
#       'word_notes_translation': 'Drinkable liquid preparation, obtained by the action of boiling water on a substance (often a plant) whose active soluble principles diffuse into the water by maceration. Synonym: herbal tea.',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'recy2rHBcjzSbvbdA-eng'},
#      {'word_language': 'eng',
#       'word': 'Boisson au chocolat',
#       'word_rec_id': 'recm76dGxSUogAOKW',
#       'order': 2,
#       'word_type': 'Expression',
#       'word_translation_id': 'recm76dGxSUogAOKW-eng',
#       'word_translation': 'Chocolate drink',
#       'word_lemmas': "['Boisson', 'Chocolat']",
#       'word_lemmas_rec_id': "['rec6tEMn22FIa81P3', 'rec93ywAAvujm2vwy']",
#       'word_audio': 'assets/audio/ai/eng/recm76dGxSUogAOKW-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701792391/langdeck/assets/audio/ai/eng/recm76dGxSUogAOKW-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701792394/langdeck/assets/audio/ai/fre/recm76dGxSUogAOKW-fre.mp3',
#       'word_lemmas_tr_rec_id': "['rec6tEMn22FIa81P3-eng', 'rec93ywAAvujm2vwy-eng']",
#       'word_lemmas_tr': "['Beverage', 'Chocolate']",
#       'word_notes': 'Les boissons au chocolat sont des préparations liquides à base de cacao en poudre mélangé avec du lait ou de l’eau. ',
#       'word_nutri_notes': 'Contrairement aux idées véhiculées, les boissons au chocolat ne sont pas seulement bues pour le plaisir. En effet, la présence d’antioxydants, d’oligo-éléments et d’acides aminés dans le cacao est bénéfique pour la santé.',
#       'word_notes_translation': 'Chocolate drinks are liquid preparations made from cocoa powder mixed with milk or water.',
#       'word_nutri_notes_translation': 'Contrary to popular belief, chocolate drinks are not just drunk for pleasure. Indeed, the presence of antioxidants, trace elements and amino acids in cocoa is beneficial for health.',
#       'word_tr_rec_id': 'recm76dGxSUogAOKW-eng'}]},
#    {'tp_phrase_rec_id': 'reczhukMZwWSnSRPv',
#     'tp_phrase': 'Boissons froides : jus d’orange, jus de pomme, multifruits, lait, lait végétal (sur demande), produits bio et allégés (yaourts, fromage, confiture, compote)',
#     'tp_phrase_html': '<span id="rec6tEMn22FIa81P3">Boissons</span> froides : <span id="receNtWmFuccPjgYU">jus d’orange</span>, <span id="rec1y9aJTbpDT95Zu">jus de pomme</span>, <span id="rect8hj7MI7YIXGAl">multifruits</span>, <span id="rec828nPZgEYyy3OS">lait</span>, lait végétal (sur demande), produits <span id="recZ60jraTcknWnBY">bio</span> et <span id="reczpKG1V1BBoy9D0">allégés</span> (<span id="recsxgYfJjh3wp8pl">yaourts</span>, <span id="recoUyEv4BuTkl2Jy">fromage</span>, <span id="reccrviLRZ5rhpjqf">confiture</span>, <span id="rec9QOxGbTXGwh6ny">compote</span>)',
#     'tp_phrase_html_rec_id': '<kw>rec6tEMn22FIa81P3<kw> froides : <kw>receNtWmFuccPjgYU<kw>, <kw>rec1y9aJTbpDT95Zu<kw>, <kw>rect8hj7MI7YIXGAl<kw>, <kw>rec828nPZgEYyy3OS<kw>, lait végétal (sur demande), produits <kw>recZ60jraTcknWnBY<kw> et <kw>reczpKG1V1BBoy9D0<kw> (<kw>recsxgYfJjh3wp8pl<kw>, <kw>recoUyEv4BuTkl2Jy<kw>, <kw>reccrviLRZ5rhpjqf<kw>, <kw>rec9QOxGbTXGwh6ny<kw>)',
#     'tp_phrase_html_kw': '<kw>Boissons<kw> froides : <kw>jus d’orange<kw>, <kw>jus de pomme<kw>, <kw>multifruits<kw>, <kw>lait<kw>, lait végétal (sur demande), produits <kw>bio<kw> et <kw>allégés<kw> (<kw>yaourts<kw>, <kw>fromage<kw>, <kw>confiture<kw>, <kw>compote<kw>)',
#     'tp_phrase_rel_tp': 'Le buffet',
#     'tp_phrase_rel_tp_rec_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_phrase_order': '6',
#     'tp_phrase_language': 'eng',
#     'tp_phrase_translation_id': 'reczhukMZwWSnSRPv-eng',
#     'tp_phrase_translation': 'Cold drinks: orange juice, apple juice, multifruit, milk, vegetable milk (on request), organic and low-fat products (yogurt, cheese, jam, compote)',
#     'tp_phrase_audio': 'assets/audio/ai/eng/reczhukMZwWSnSRPv-eng.mp3',
#     'tp_phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709100/langdeck/assets/audio/ai/eng/reczhukMZwWSnSRPv-eng.mp3',
#     'tp_phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701709105/langdeck/assets/audio/ai/fre/reczhukMZwWSnSRPv-fre.mp3',
#     'tp_phrase_words_rec_id': "['rec6tEMn22FIa81P3', 'receNtWmFuccPjgYU', 'rec1y9aJTbpDT95Zu', 'rect8hj7MI7YIXGAl', 'rec828nPZgEYyy3OS', 'recZ60jraTcknWnBY', 'reczpKG1V1BBoy9D0', 'recsxgYfJjh3wp8pl', 'recoUyEv4BuTkl2Jy', 'reccrviLRZ5rhpjqf', 'rec9QOxGbTXGwh6ny']",
#     'tp_phrase_words': '[\'Boisson\', "Jus d\'orange", \'Jus de pomme\', \'Jus de fruit\', \'Lait\', \'Bio\', \'allégé\', \'Yaourt\', \'Fromage\', \'Confiture\', \'Compote\']',
#     'tp_phrase_words_tr_rec_id': "['rec6tEMn22FIa81P3-eng', 'receNtWmFuccPjgYU-eng', 'rec1y9aJTbpDT95Zu-eng', 'rect8hj7MI7YIXGAl-eng', 'rec828nPZgEYyy3OS-eng', 'recZ60jraTcknWnBY-eng', 'reczpKG1V1BBoy9D0-eng', 'recsxgYfJjh3wp8pl-eng', 'recoUyEv4BuTkl2Jy-eng', 'reccrviLRZ5rhpjqf-eng', 'rec9QOxGbTXGwh6ny-eng']",
#     'tp_phrase_words_tr': "['Beverage', 'Orange juice', 'Apple juice', 'Fruit juice', 'Milk', 'Organic', 'Lightened', 'Yogurt', 'Cheese', 'Jam', 'Compote']",
#     'phrase_related_tp_tr': "['The buffet']",
#     'tp_rec_id': 'recolhmJ3G9UQuKPi',
#     'tp_name': 'Le buffet',
#     'tp_language': 'eng',
#     'tp_rel_story': 'Le petit-déjeuner',
#     'tp_rel_story_rec_id': 'recYrnBviiGa6SErr',
#     'tp_illustration': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702561868/langdeck/assets/images/saynetes/%C3%A9tude-bleu.png',
#     'tp_translation': 'The buffet',
#     'tp_translation_id': 'recolhmJ3G9UQuKPi-eng',
#     'tp_audio': 'assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/eng/recolhmJ3G9UQuKPi-eng.mp3',
#     'tp_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701706854/langdeck/assets/audio/ai/fre/recolhmJ3G9UQuKPi-fre.mp3',
#     'tp_lesson_header': 'https://res.cloudinary.com/dhc7ovnwk/image/upload/v1702660486/langdeck/assets/images/saynetes/langdeck-lesson-header-2.png',
#     'tp_summary': "Le texte à étudier est extrait du site web d'un hôtel qui propose un buffet pour le petit-déjeuner. Le texte contient beaucoup de vocabulaire. Etudiez le menu phrase par phrase et essayez de retenir les mots.",
#     'tp_summary_translation': 'The text to study is taken from the website of a hotel which offers a breakfast buffet. The text contains a lot of vocabulary. Study the menu sentence by sentence and try to remember the words.',
#     'tp_rel_story_tr_rec_id': 'recYrnBviiGa6SErr-eng',
#     'words': [{'word_language': 'eng',
#       'word': 'Boisson',
#       'word_rec_id': 'rec6tEMn22FIa81P3',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'rec6tEMn22FIa81P3-eng',
#       'word_translation': 'Beverage',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/rec6tEMn22FIa81P3-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704293/langdeck/assets/audio/ai/eng/rec6tEMn22FIa81P3-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704301/langdeck/assets/audio/ai/fre/rec6tEMn22FIa81P3-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Tout liquide que l'on boit : Boisson chaude, froide, avec ou sans alcool.",
#       'word_nutri_notes': '',
#       'word_notes_translation': 'Any liquid you drink: Hot or cold drink, with or without alcohol.',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'rec6tEMn22FIa81P3-eng'},
#      {'word_language': 'eng',
#       'word': "Jus d'orange",
#       'word_rec_id': 'receNtWmFuccPjgYU',
#       'order': 2,
#       'word_type': 'Expression',
#       'word_translation_id': 'receNtWmFuccPjgYU-eng',
#       'word_translation': 'Orange juice',
#       'word_lemmas': "['Jus', 'Orange']",
#       'word_lemmas_rec_id': "['rec5rbfb20TFOpn5s', 'rechRvQixgB1N3337']",
#       'word_audio': 'assets/audio/ai/eng/receNtWmFuccPjgYU-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679448/langdeck/assets/audio/ai/eng/receNtWmFuccPjgYU-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679460/langdeck/assets/audio/ai/fre/receNtWmFuccPjgYU-fre.mp3',
#       'word_lemmas_tr_rec_id': "['rec5rbfb20TFOpn5s-eng', 'rechRvQixgB1N3337-eng']",
#       'word_lemmas_tr': "['Juice', 'Orange']",
#       'word_notes': '',
#       'word_nutri_notes': '',
#       'word_notes_translation': '',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'receNtWmFuccPjgYU-eng'},
#      {'word_language': 'eng',
#       'word': 'Jus de pomme',
#       'word_rec_id': 'rec1y9aJTbpDT95Zu',
#       'order': 2,
#       'word_type': 'Expression',
#       'word_translation_id': 'rec1y9aJTbpDT95Zu-eng',
#       'word_translation': 'Apple juice',
#       'word_lemmas': "['Jus', 'Pomme']",
#       'word_lemmas_rec_id': "['rec5rbfb20TFOpn5s', 'recgS8XzoLFlvU3xE']",
#       'word_audio': 'assets/audio/ai/eng/rec1y9aJTbpDT95Zu-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704297/langdeck/assets/audio/ai/eng/rec1y9aJTbpDT95Zu-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704304/langdeck/assets/audio/ai/fre/rec1y9aJTbpDT95Zu-fre.mp3',
#       'word_lemmas_tr_rec_id': "['rec5rbfb20TFOpn5s-eng', 'recgS8XzoLFlvU3xE-eng']",
#       'word_lemmas_tr': "['Juice', 'Apple']",
#       'word_notes': '',
#       'word_nutri_notes': '',
#       'word_notes_translation': '',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'rec1y9aJTbpDT95Zu-eng'},
#      {'word_language': 'eng',
#       'word': 'Jus de fruit',
#       'word_rec_id': 'rect8hj7MI7YIXGAl',
#       'order': 2,
#       'word_type': 'Expression',
#       'word_translation_id': 'rect8hj7MI7YIXGAl-eng',
#       'word_translation': 'Fruit juice',
#       'word_lemmas': "['Jus', 'Fruit']",
#       'word_lemmas_rec_id': "['rec5rbfb20TFOpn5s', 'recxMserKVL7AnVFh']",
#       'word_audio': 'assets/audio/ai/eng/rect8hj7MI7YIXGAl-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679448/langdeck/assets/audio/ai/eng/rect8hj7MI7YIXGAl-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679460/langdeck/assets/audio/ai/fre/rect8hj7MI7YIXGAl-fre.mp3',
#       'word_lemmas_tr_rec_id': "['rec5rbfb20TFOpn5s-eng', 'recxMserKVL7AnVFh-eng']",
#       'word_lemmas_tr': "['Juice', 'Fruit']",
#       'word_notes': '',
#       'word_nutri_notes': '',
#       'word_notes_translation': '',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'rect8hj7MI7YIXGAl-eng'},
#      {'word_language': 'eng',
#       'word': 'Lait',
#       'word_rec_id': 'rec828nPZgEYyy3OS',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'rec828nPZgEYyy3OS-eng',
#       'word_translation': 'Milk',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/rec828nPZgEYyy3OS-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679449/langdeck/assets/audio/ai/eng/rec828nPZgEYyy3OS-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679461/langdeck/assets/audio/ai/fre/rec828nPZgEYyy3OS-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': '',
#       'word_nutri_notes': '',
#       'word_notes_translation': '',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'rec828nPZgEYyy3OS-eng'},
#      {'word_language': 'eng',
#       'word': 'Bio',
#       'word_rec_id': 'recZ60jraTcknWnBY',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recZ60jraTcknWnBY-eng',
#       'word_translation': 'Organic',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recZ60jraTcknWnBY-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701793315/langdeck/assets/audio/ai/eng/recZ60jraTcknWnBY-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701793316/langdeck/assets/audio/ai/fre/recZ60jraTcknWnBY-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Issu de l'agriculture biologique. Naturel, sans engrais, ni pesticides de synthèse.",
#       'word_nutri_notes': 'Le mode de production et de transformation des produits bio apporte de réels atouts nutritionnels :\n– une teneur supérieure en antioxydants dans les fruits et légumes,\n– une richesse naturelle du lait en Oméga-3 car les vaches sont nourries essentiellement avec de l’herbe,\n– des teneurs plus fortes en acides gras poly-insaturés (oméga-3 et oméga-6) dans la viande bio car les rythmes naturels sont mieux respectés et la croissance des animaux est plus lente.',
#       'word_notes_translation': 'From organic farming. Natural, without fertilizers or synthetic pesticides.',
#       'word_nutri_notes_translation': 'The method of production and processing of organic products provides real nutritional benefits:\n– a higher content of antioxidants in fruits and vegetables,\n– a natural richness of milk in Omega-3 because the cows are fed mainly with grass,\n– higher levels of polyunsaturated fatty acids (omega-3 and omega-6) in organic meat because natural rhythms are better respected and animal growth is slower.',
#       'word_tr_rec_id': 'recZ60jraTcknWnBY-eng'},
#      {'word_language': 'eng',
#       'word': 'Allégé',
#       'word_rec_id': 'reczpKG1V1BBoy9D0',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'reczpKG1V1BBoy9D0-eng',
#       'word_translation': 'Lightened',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/reczpKG1V1BBoy9D0-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704292/langdeck/assets/audio/ai/eng/reczpKG1V1BBoy9D0-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704300/langdeck/assets/audio/ai/fre/reczpKG1V1BBoy9D0-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Se dit d'un produit alimentaire qui a été débarrassé de tout ou partie de ses graisses ou de ses sucres.",
#       'word_nutri_notes': '',
#       'word_notes_translation': 'Refers to a food product that has been stripped of all or part of its fats or sugars.',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'reczpKG1V1BBoy9D0-eng'},
#      {'word_language': 'eng',
#       'word': 'Yaourt',
#       'word_rec_id': 'recsxgYfJjh3wp8pl',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recsxgYfJjh3wp8pl-eng',
#       'word_translation': 'Yogurt',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recsxgYfJjh3wp8pl-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704300/langdeck/assets/audio/ai/eng/recsxgYfJjh3wp8pl-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1701704306/langdeck/assets/audio/ai/fre/recsxgYfJjh3wp8pl-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': 'Lait caillé ayant subi une fermentation acide.',
#       'word_nutri_notes': '',
#       'word_notes_translation': 'Curdled milk which has undergone acid fermentation.',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'recsxgYfJjh3wp8pl-eng'},
#      {'word_language': 'eng',
#       'word': 'Fromage',
#       'word_rec_id': 'recoUyEv4BuTkl2Jy',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recoUyEv4BuTkl2Jy-eng',
#       'word_translation': 'Cheese',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recoUyEv4BuTkl2Jy-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679445/langdeck/assets/audio/ai/eng/recoUyEv4BuTkl2Jy-eng.mp3',
# ...
#       'word_nutri_notes': 'Le fromage est un aliment calorique en totalisant 338 Cal/100 g, essentiellement dû à ses lipides. C’est un bon fournisseur de protéines, de calcium, de phosphore, de vitamine A et de zinc.\nLe fromage n’est pas à bannir de l’alimentation car il est riche de bienfaits sur le plan nutritionnel.',
#       'word_notes_translation': 'Cheese is above all a fermentation of milk activated by lactic acid bacteria. There are hundreds of types around the world and France has at least 400. It is eaten alone or used in the preparation of many dishes.',
#       'word_nutri_notes_translation': 'Cheese is a high-calorie food, totaling 338 Cal/100 g, mainly due to its lipids. It is a good supplier of protein, calcium, phosphorus, vitamin A and zinc.\nCheese should not be banned from the diet because it is rich in nutritional benefits.',
#       'word_tr_rec_id': 'recoUyEv4BuTkl2Jy-eng',
#       'keywords': []}]},
#    {'phrase_language': 'eng',
#     'phrase_related_story': 'Le petit-déjeuner',
#     'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#     'phrase_paragraph': '13',
#     'phrase_position': '13',
#     'phrase_rec_id': 'recK4R0maJbkoChIL',
#     'phrase': 'Tu veux un œuf ?',
#     'phrase_words': "['Œuf']",
#     'phrase_words_rec_id': "['recoSeRIZS7t92XIR']",
#     'phrase_words_tr': "['Egg']",
#     'phrase_words_tr_rec_id': "['recoSeRIZS7t92XIR-eng']",
#     'phrase_html': 'Tu veux un <span id="recoSeRIZS7t92XIR">œuf</span> ?',
#     'phrase_html_rec_id': 'Tu veux un <kw>recoSeRIZS7t92XIR<kw> ?',
#     'phrase_html_kw': 'Tu veux un <kw>œuf<kw> ?',
#     'phrase_translation': 'Do you want an egg?',
#     'phrase_audio': 'assets/audio/ai/eng/recK4R0maJbkoChIL-eng.mp3',
#     'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697634756/langdeck/assets/audio/ai/eng/recK4R0maJbkoChIL-eng.mp3',
#     'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697634760/langdeck/assets/audio/ai/fre/recK4R0maJbkoChIL-fre.mp3',
#     'phrase_related_story_tr': 'Breakfast',
#     'phrase_notes': '',
#     'phrase_notes_2': '',
#     'phrase_notes_translation': '',
#     'phrase_notes_2_translation': '',
#     'words': [{'word_language': 'eng',
#       'word': 'Œuf',
#       'word_rec_id': 'recoSeRIZS7t92XIR',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recoSeRIZS7t92XIR-eng',
#       'word_translation': 'Egg',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recoSeRIZS7t92XIR-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679450/langdeck/assets/audio/ai/eng/recoSeRIZS7t92XIR-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679462/langdeck/assets/audio/ai/fre/recoSeRIZS7t92XIR-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': 'Consommé partout dans le monde depuis des millénaires, l’œuf est apprécié pour ses qualités nutritionnelles, notamment sa richesse en protéines, vitamines et oligo-éléments, sa facilité et diversité d’utilisation et son faible coût.',
#       'word_nutri_notes': 'L’œuf est peu calorique, avec 150 Kcal pour deux œufs, soit 7% de l’apport énergétique total recommandé chez une femme (2 000 Kcal/jour), ce qui en fait un aliment très apprécié dans les régimes amaigrissants.',
#       'word_notes_translation': 'Consumed all over the world for millennia, the egg is appreciated for its nutritional qualities, notably its richness in proteins, vitamins and trace elements, its ease and diversity of use and its low cost.',
#       'word_nutri_notes_translation': 'The egg is low in calories, with 150 Kcal for two eggs, or 7% of the total recommended energy intake for a woman (2,000 Kcal/day), which makes it a very popular food in weight loss diets.',
#       'word_tr_rec_id': 'recoSeRIZS7t92XIR-eng',
#       'keywords': []}]},
#    {'phrase_language': 'eng',
#     'phrase_related_story': 'Le petit-déjeuner',
#     'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#     'phrase_paragraph': '14',
#     'phrase_position': '14',
#     'phrase_rec_id': 'rec1FT308NgPpEpoo',
#     'phrase': "S'il te plait, je veux bien un œuf au plat",
#     'phrase_words': "['Œuf au plat']",
#     'phrase_words_rec_id': "['recT4pYfb6prJ2atR']",
#     'phrase_words_tr': "['Fried egg']",
#     'phrase_words_tr_rec_id': "['recT4pYfb6prJ2atR-eng']",
#     'phrase_html': 'S\'il te plait, je veux bien un <span id="recT4pYfb6prJ2atR">œuf au plat</span>',
#     'phrase_html_rec_id': "S'il te plait, je veux bien un <kw>recT4pYfb6prJ2atR<kw>",
#     'phrase_html_kw': "S'il te plait, je veux bien un <kw>œuf au plat<kw>",
#     'phrase_translation': 'Please, I would like a fried egg',
#     'phrase_audio': 'assets/audio/ai/eng/rec1FT308NgPpEpoo-eng.mp3',
#     'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697634757/langdeck/assets/audio/ai/eng/rec1FT308NgPpEpoo-eng.mp3',
#     'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697634761/langdeck/assets/audio/ai/fre/rec1FT308NgPpEpoo-fre.mp3',
#     'phrase_related_story_tr': 'Breakfast',
#     'phrase_notes': '',
#     'phrase_notes_2': '',
#     'phrase_notes_translation': '',
#     'phrase_notes_2_translation': '',
#     'words': [{'word_language': 'eng',
#       'word': 'Œuf au plat',
#       'word_rec_id': 'recT4pYfb6prJ2atR',
#       'order': 2,
#       'word_type': 'Expression',
#       'word_translation_id': 'recT4pYfb6prJ2atR-eng',
#       'word_translation': 'Fried egg',
#       'word_lemmas': "['Œuf']",
#       'word_lemmas_rec_id': "['recoSeRIZS7t92XIR']",
#       'word_audio': 'assets/audio/ai/eng/recT4pYfb6prJ2atR-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697635178/langdeck/assets/audio/ai/eng/recT4pYfb6prJ2atR-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1697635179/langdeck/assets/audio/ai/fre/recT4pYfb6prJ2atR-fre.mp3',
#       'word_lemmas_tr_rec_id': "['recoSeRIZS7t92XIR-eng']",
#       'word_lemmas_tr': "['Egg']",
#       'word_notes': '',
#       'word_nutri_notes': '',
#       'word_notes_translation': '',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'recT4pYfb6prJ2atR-eng',
#       'keywords': [{'word_language': 'eng',
#         'word': 'Œuf',
#         'word_rec_id': 'recoSeRIZS7t92XIR',
#         'order': 1,
#         'word_type': 'Lemma',
#         'word_translation_id': 'recoSeRIZS7t92XIR-eng',
#         'word_translation': 'Egg',
#         'word_lemmas': '',
#         'word_lemmas_rec_id': '',
#         'word_audio': 'assets/audio/ai/eng/recoSeRIZS7t92XIR-eng.mp3',
#         'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679450/langdeck/assets/audio/ai/eng/recoSeRIZS7t92XIR-eng.mp3',
#         'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679462/langdeck/assets/audio/ai/fre/recoSeRIZS7t92XIR-fre.mp3',
#         'word_lemmas_tr_rec_id': '',
#         'word_lemmas_tr': '',
#         'word_notes': 'Consommé partout dans le monde depuis des millénaires, l’œuf est apprécié pour ses qualités nutritionnelles, notamment sa richesse en protéines, vitamines et oligo-éléments, sa facilité et diversité d’utilisation et son faible coût.',
#         'word_nutri_notes': 'L’œuf est peu calorique, avec 150 Kcal pour deux œufs, soit 7% de l’apport énergétique total recommandé chez une femme (2 000 Kcal/jour), ce qui en fait un aliment très apprécié dans les régimes amaigrissants.',
#         'word_notes_translation': 'Consumed all over the world for millennia, the egg is appreciated for its nutritional qualities, notably its richness in proteins, vitamins and trace elements, its ease and diversity of use and its low cost.',
#         'word_nutri_notes_translation': 'The egg is low in calories, with 150 Kcal for two eggs, or 7% of the total recommended energy intake for a woman (2,000 Kcal/day), which makes it a very popular food in weight loss diets.',
#         'keyword': 'recoSeRIZS7t92XIR'}]}]},
#    {'phrase_language': 'eng',
#     'phrase_related_story': 'Le petit-déjeuner',
#     'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#     'phrase_paragraph': '15',
#     'phrase_position': '15',
#     'phrase_rec_id': 'recYyHnx1RW6rkDQH',
#     'phrase': 'Tu veux de la bière ?',
#     'phrase_words': "['Bière']",
#     'phrase_words_rec_id': "['recrjtZ5EXbIiGEMX']",
#     'phrase_words_tr': "['Beer']",
#     'phrase_words_tr_rec_id': "['recrjtZ5EXbIiGEMX-eng']",
#     'phrase_html': 'Tu veux de la <span id="recrjtZ5EXbIiGEMX">bière</span> ?',
#     'phrase_html_rec_id': 'Tu veux de la <kw>recrjtZ5EXbIiGEMX<kw> ?',
#     'phrase_html_kw': 'Tu veux de la <kw>bière<kw> ?',
#     'phrase_translation': 'Do you want some beer?',
#     'phrase_audio': 'assets/audio/ai/eng/recYyHnx1RW6rkDQH-eng.mp3',
#     'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947284/langdeck/assets/audio/ai/eng/recYyHnx1RW6rkDQH-eng.mp3',
#     'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947297/langdeck/assets/audio/ai/fre/recYyHnx1RW6rkDQH-fre.mp3',
#     'phrase_related_story_tr': 'Breakfast',
#     'phrase_notes': '',
#     'phrase_notes_2': '',
#     'phrase_notes_translation': '',
#     'phrase_notes_2_translation': '',
#     'words': [{'word_language': 'eng',
#       'word': 'Bière',
#       'word_rec_id': 'recrjtZ5EXbIiGEMX',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recrjtZ5EXbIiGEMX-eng',
#       'word_translation': 'Beer',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recrjtZ5EXbIiGEMX-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679442/langdeck/assets/audio/ai/eng/recrjtZ5EXbIiGEMX-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679455/langdeck/assets/audio/ai/fre/recrjtZ5EXbIiGEMX-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': '',
#       'word_nutri_notes': '',
#       'word_notes_translation': '',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'recrjtZ5EXbIiGEMX-eng',
#       'keywords': []}]},
#    {'phrase_language': 'eng',
#     'phrase_related_story': 'Le petit-déjeuner',
#     'phrase_related_story_rec_id': 'recYrnBviiGa6SErr',
#     'phrase_paragraph': '16',
#     'phrase_position': '16',
#     'phrase_rec_id': 'reckJNZKgpFLe91gG',
#     'phrase': 'Haha ! Non merci, pas de bière au petit-déjeuner',
#     'phrase_words': "['Bière', 'Petit-déjeuner']",
#     'phrase_words_rec_id': "['recrjtZ5EXbIiGEMX', 'recrYaJMdw31vgPT5']",
#     'phrase_words_tr': "['Beer', 'Breakfast']",
#     'phrase_words_tr_rec_id': "['recrjtZ5EXbIiGEMX-eng', 'recrYaJMdw31vgPT5-eng']",
#     'phrase_html': 'Haha ! Non merci, pas de <span id="recrjtZ5EXbIiGEMX">bière</span> au <span id="recrYaJMdw31vgPT5">petit-déjeuner</span>.',
#     'phrase_html_rec_id': 'Haha ! Non merci, pas de <kw>recrjtZ5EXbIiGEMX<kw> au <kw>recrYaJMdw31vgPT5<kw>.',
#     'phrase_html_kw': 'Haha ! Non merci, pas de <kw>bière<kw> au <kw>petit-déjeuner<kw>.',
#     'phrase_translation': 'Haha! No thanks, no beer for breakfast',
#     'phrase_audio': 'assets/audio/ai/eng/reckJNZKgpFLe91gG-eng.mp3',
#     'phrase_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947285/langdeck/assets/audio/ai/eng/reckJNZKgpFLe91gG-eng.mp3',
#     'phrase_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696947298/langdeck/assets/audio/ai/fre/reckJNZKgpFLe91gG-fre.mp3',
#     'phrase_related_story_tr': 'Breakfast',
#     'phrase_notes': '',
#     'phrase_notes_2': '',
#     'phrase_notes_translation': '',
#     'phrase_notes_2_translation': '',
#     'words': [{'word_language': 'eng',
#       'word': 'Bière',
#       'word_rec_id': 'recrjtZ5EXbIiGEMX',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recrjtZ5EXbIiGEMX-eng',
#       'word_translation': 'Beer',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recrjtZ5EXbIiGEMX-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679442/langdeck/assets/audio/ai/eng/recrjtZ5EXbIiGEMX-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679455/langdeck/assets/audio/ai/fre/recrjtZ5EXbIiGEMX-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': '',
#       'word_nutri_notes': '',
#       'word_notes_translation': '',
#       'word_nutri_notes_translation': '',
#       'word_tr_rec_id': 'recrjtZ5EXbIiGEMX-eng',
#       'keywords': []},
#      {'word_language': 'eng',
#       'word': 'Petit-déjeuner',
#       'word_rec_id': 'recrYaJMdw31vgPT5',
#       'order': 1,
#       'word_type': 'Lemma',
#       'word_translation_id': 'recrYaJMdw31vgPT5-eng',
#       'word_translation': 'Breakfast',
#       'word_lemmas': '',
#       'word_lemmas_rec_id': '',
#       'word_audio': 'assets/audio/ai/eng/recrYaJMdw31vgPT5-eng.mp3',
#       'word_audio_url': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679451/langdeck/assets/audio/ai/eng/recrYaJMdw31vgPT5-eng.mp3',
#       'word_audio_url_fr': 'http://res.cloudinary.com/dhc7ovnwk/video/upload/v1696679464/langdeck/assets/audio/ai/fre/recrYaJMdw31vgPT5-fre.mp3',
#       'word_lemmas_tr_rec_id': '',
#       'word_lemmas_tr': '',
#       'word_notes': "Le petit-déjeuner est le premier repas de la journée. Il se prend le matin et se compose souvent de café, de thé, de lait, de jus de fruits, accompagné de pain, de céréales ou de brioche avec de la confiture. Mais il peut également se composer d'aliments salés comme les oeufs, le bacon, les saucisses, etc.",
#       'word_nutri_notes': 'Il faut savoir qu’au réveil la glycémie est normale (1g/l) et que l’organisme n’a pas besoin de sucres rapides au réveil.\nSi vous prenez du sucre, de la confiture, du miel, du pain blanc, qui sont tous des sucres rapides (ou à index glycémique élevé) alors vous risquez de déclencher une hyperglycémie.\nCela sera suivi d’une production d’insuline qui induira la mise en réserve des sucres et des graisses (prise de poids).\nEnsuite vous allez être en hypoglycémie en fin de matinée et avoir une sensation de faim et l’envie de grignoter sucré.\n\nLe petit déjeuner idéal est donc celui qui associe un peu de glucides à index glycémique bas (pain complet, pain de seigle, galette de sarrasin, flocons d’avoine) avec des protéines (jambon, fromage, oeuf, viande des grisons…) et du gras (beurre, gras du fromage ou d’une charcuterie).\nLe petit déjeuner assure une excellente satiété pour toute la matinée, une grande forme physique et intellectuelle.',
#       'word_notes_translation': 'Breakfast is the first meal of the day. It is taken in the morning and often consists of coffee, tea, milk, fruit juice, accompanied by bread, cereals or brioche with jam. But it can also consist of salty foods like eggs, bacon, sausages, etc.',
#       'word_nutri_notes_translation': 'You should know that when you wake up, your blood sugar level is normal (1g/l) and that the body does not need quick sugars when you wake up.\nIf you take sugar, jam, honey, white bread, which are all fast sugars (or high glycemic index) then you risk triggering hyperglycemia.\nThis will be followed by insulin production which will induce the storage of sugars and fats (weight gain).\nThen you will be hypoglycemic at the end of the morning and have a feeling of hunger and the desire to snack on something sweet.\n\nThe ideal breakfast is therefore one which combines a few carbohydrates with a low glycemic index (wholemeal bread, rye bread, buckwheat pancakes, oatmeal) with proteins (ham, cheese, egg, grisons meat, etc.) and fat (butter, fat from cheese or cold meats).\nBreakfast ensures excellent satiety for the whole morning, great physical and intellectual fitness.',
#       'word_tr_rec_id': 'recrYaJMdw31vgPT5-eng',
#       'keywords': []}]}]}]

# %% [markdown]
# ## Sauvegarde au format JSON

# %%
with open('saynetes.txt', 'w') as f:
  json.dump(vk_lang, f, ensure_ascii=False)
